# %% [markdown]
# # Seattle Rental Properties

# %% [markdown]
# Objective: Match 2-3 people's workplace locations to an ideal rental property which has an equivalent commute in time and distance.
#
# To Do:
# - Clean Seattle Rental Properties dataset
# - Get longitude and latitude of Microsoft and Amazon offices
# - K means clustering? - Compare machine learning model
# - Use Travel Time API to find equdistance apartments.
#
# APIs used:
# - Time Travel
#
# Dataset source
# - https://catalog.data.gov/dataset/rental-property-registration updated 7/26/2019

# %% [markdown]
# ### Data Exploring - JSON
# Importing Libaries. The City of Seattle provided a JSON and CSV file.

# %%
#import libraries
import json
import pandas as pd
import geopandas as gpd #used for transforming geolocation data
import matplotlib.pyplot as plt

from datetime import datetime  #to convert data to datetime that does not fall within the pandas.to_datetime function timeframe
from shapely.geometry import Point  #transform latitude/longitude to geo-coordinate data
from geopandas.tools import geocode #get the latitude/longitude for a given address
from geopandas.tools import reverse_geocode  #get the address for a location using latitude/longitude

# %matplotlib inline

# %%
mapbox = "pk.eyJ1IjoidHBhc2FnIiwiYSI6ImNqeXRhZGIwMTAyMmkzaG4wZGNuaGZ3NTkifQ.WRpwsiq2m41ZgMJzO4NDvQ"

# %%
import sys
'geopandas' in sys.modules
# Out:
# True

# %%
import sys
'geopy' in sys.modules
# Out:
# False

# %%
#load json of seattle rental properties
with open("seattle.json", 'r') as read_file:
    seattleprops = json.load(read_file)

# %%
#seattleprops
# Out:
# {'meta': {'view': {'id': 'j2xh-c7vt',
#    'name': 'Rental Property Registration',
#    'attribution': 'City of Seattle',
#    'attributionLink': 'http://www.seattle.gov/sdci',
#    'averageRating': 0,
#    'category': 'Permitting',
#    'createdAt': 1524754568,
#    'description': 'A list of properties that have registered their rental units with the City of Seattle under the Rental Registration and Inspection Ordinance.',
#    'displayType': 'table',
#    'downloadCount': 313,
#    'hideFromCatalog': False,
#    'hideFromDataJson': False,
#    'indexUpdatedAt': 1562867880,
#    'licenseId': 'PUBLIC_DOMAIN',
#    'locale': 'en_US',
#    'newBackend': True,
#    'numberOfComments': 0,
#    'oid': 31914420,
#    'provenance': 'official',
#    'publicationAppendEnabled': False,
#    'publicationDate': 1562867928,
#    'publicationGroup': 15065876,
#    'publicationStage': 'published',
#    'rowsUpdatedAt': 1564242562,
#    'rowsUpdatedBy': '5wys-t5s3',
#    'tableId': 16352451,
#    'totalTimesRated': 0,
#    'viewCount': 2309,
#    'viewLastModified': 1562867928,
#    'viewType': 'tabular',
#    'approvals': [{'reviewedAt': 1529517213,
#      'reviewedAutomatically': True,
#      'state': 'approved',
#      'submissionId': 886413,
#      'submissionObject': 'public_audience_request',
#      'submissionOutcome': 'change_audience',
#      'submittedAt': 1529517213,
#      'workflowId': 623,
#      'submissionDetails': {'permissionType': 'READ'},
#      'submissionOutcomeApplication': {'failureCount': 0, 'status': 'success'},
#      'submitter': {'id': '5wys-t5s3', 'displayName': 'Seattle SDCI'}}],
#    'columns': [{'id': -1,
#      'name': 'sid',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':sid',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'id',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':id',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'position',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':position',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'created_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':created_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_at',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_at',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'updated_meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':updated_meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': -1,
#      'name': 'meta',
#      'dataTypeName': 'meta_data',
#      'fieldName': ':meta',
#      'position': 0,
#      'renderTypeName': 'meta_data',
#      'format': {},
#      'flags': ['hidden']},
#     {'id': 417383743,
#      'name': 'RegistrationNum',
#      'dataTypeName': 'text',
#      'description': "The tracking number used to refer to this registration in SDCI's tracking system.",
#      'fieldName': 'permitnum',
#      'position': 1,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145304,
#      'width': 183,
#      'cachedContents': {'largest': '001-0136786',
#       'null': '0',
#       'top': [{'item': '001-0108588', 'count': '1'},
#        {'item': '001-0120682', 'count': '1'},
#        {'item': '001-0130530', 'count': '1'},
#        {'item': '001-0119069', 'count': '1'},
#        {'item': '001-0122886', 'count': '1'},
#        {'item': '001-0125025', 'count': '1'},
#        {'item': '001-0125814', 'count': '1'},
#        {'item': '001-0113008', 'count': '1'},
#        {'item': '001-0112528', 'count': '1'},
#        {'item': '001-0116228', 'count': '1'},
#        {'item': '001-0122270', 'count': '1'},
#        {'item': '001-0126635', 'count': '1'},
#        {'item': '001-0113489', 'count': '1'},
#        {'item': '001-0103821', 'count': '1'},
#        {'item': '001-0134790', 'count': '1'},
#        {'item': '001-0121488', 'count': '1'},
#        {'item': '001-0120887', 'count': '1'},
#        {'item': '001-0102240', 'count': '1'},
#        {'item': '001-0122396', 'count': '1'},
#        {'item': '001-0127207', 'count': '1'}],
#       'not_null': '32642',
#       'smallest': '001-0100004',
#       'cardinality': '32642'},
#      'format': {'align': 'left'}},
#     {'id': 417383744,
#      'name': 'RegisteredTypeMapped',
#      'dataTypeName': 'text',
#      'description': 'The type of registration that we have issued or that is in progress. ',
#      'fieldName': 'permittypemapped',
#      'position': 2,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145306,
#      'width': 224,
#      'cachedContents': {'largest': 'Rental Property',
#       'null': '0',
#       'top': [{'item': 'Rental Property', 'count': '32642'}],
#       'not_null': '32642',
#       'smallest': 'Rental Property',
#       'cardinality': '1'},
#      'format': {'align': 'left'}},
#     {'id': 417383745,
#      'name': 'RegisteredTypeDesc',
#      'dataTypeName': 'text',
#      'description': 'Additional information about the property. ',
#      'fieldName': 'permittypedesc',
#      'position': 3,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145307,
#      'width': 198,
#      'cachedContents': {'largest': 'Registration',
#       'null': '0',
#       'top': [{'item': 'Registration', 'count': '32642'}],
#       'not_null': '32642',
#       'smallest': 'Registration',
#       'cardinality': '1'},
#      'format': {'align': 'left'}},
#     {'id': 417383746,
#      'name': 'RentalHousingUnits',
#      'dataTypeName': 'number',
#      'description': 'The number of rental units that are registered at the property.',
#      'fieldName': 'rentalhousingunits',
#      'position': 4,
#      'renderTypeName': 'number',
#      'tableColumnId': 64145308,
#      'width': 209,
#      'cachedContents': {'largest': '654',
#       'null': '0',
#       'top': [{'item': '1', 'count': '22684'},
#        {'item': '2', 'count': '2967'},
#        {'item': '3', 'count': '1326'},
#        {'item': '4', 'count': '997'},
#        {'item': '6', 'count': '566'},
#        {'item': '5', 'count': '469'},
#        {'item': '8', 'count': '422'},
#        {'item': '7', 'count': '282'},
#        {'item': '9', 'count': '235'},
#        {'item': '10', 'count': '230'},
#        {'item': '12', 'count': '197'},
#        {'item': '11', 'count': '127'},
#        {'item': '15', 'count': '121'},
#        {'item': '16', 'count': '112'},
#        {'item': '14', 'count': '103'},
#        {'item': '13', 'count': '95'},
#        {'item': '18', 'count': '90'},
#        {'item': '20', 'count': '90'},
#        {'item': '24', 'count': '76'},
#        {'item': '21', 'count': '65'}],
#       'not_null': '32642',
#       'smallest': '1',
#       'cardinality': '228'},
#      'format': {'precisionStyle': 'standard', 'align': 'right'}},
#     {'id': 417383747,
#      'name': 'PropertyName',
#      'dataTypeName': 'text',
#      'description': 'The name of the registered property.',
#      'fieldName': 'propertyname',
#      'position': 5,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145309,
#      'width': 244,
#      'cachedContents': {'largest': 'Zwaller house',
#       'null': '23974',
#       'top': [{'item': 'Duplex', 'count': '22'},
#        {'item': 'Belltown Court', 'count': '22'},
#        {'item': 'Insignia', 'count': '21'},
#        {'item': 'Cristalla', 'count': '17'},
#        {'item': 'N/A', 'count': '17'},
#        {'item': 'Ballard Place', 'count': '16'},
#        {'item': 'The Braeburn', 'count': '16'},
#        {'item': 'Blakeley Commons', 'count': '15'},
#        {'item': 'Marselle', 'count': '15'},
#        {'item': 'Enso', 'count': '15'},
#        {'item': 'Meridian', 'count': '14'},
#        {'item': 'Invitation Homes', 'count': '14'},
#        {'item': 'Veridian Cove', 'count': '14'},
#        {'item': 'Cosmopolitan', 'count': '14'},
#        {'item': 'Garden Court', 'count': '13'},
#        {'item': 'Meritage', 'count': '13'},
#        {'item': 'Trace North', 'count': '13'},
#        {'item': 'University Plaza', 'count': '12'},
#        {'item': 'none', 'count': '12'},
#        {'item': 'Escala', 'count': '11'}],
#       'not_null': '8668',
#       'smallest': '\x7f\x7f\x7f',
#       'cardinality': '7172'},
#      'format': {'align': 'left'}},
#     {'id': 417383748,
#      'name': 'RegisteredDate',
#      'dataTypeName': 'text',
#      'description': "The date the property registered it's rental units.",
#      'fieldName': 'registereddate',
#      'position': 6,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145310,
#      'width': 204,
#      'cachedContents': {'largest': '2019-07-25',
#       'null': '0',
#       'top': [{'item': '2014-09-30', 'count': '329'},
#        {'item': '2015-09-30', 'count': '215'},
#        {'item': '2016-03-31', 'count': '214'},
#        {'item': '2015-06-30', 'count': '213'},
#        {'item': '2015-12-31', 'count': '187'},
#        {'item': '2015-12-28', 'count': '186'},
#        {'item': '2015-06-29', 'count': '178'},
#        {'item': '2015-03-31', 'count': '171'},
#        {'item': '2016-03-30', 'count': '157'},
#        {'item': '2016-06-30', 'count': '154'},
#        {'item': '2016-06-29', 'count': '152'},
#        {'item': '2014-09-29', 'count': '148'},
#        {'item': '2015-12-29', 'count': '143'},
#        {'item': '2015-09-29', 'count': '142'},
#        {'item': '2015-07-08', 'count': '138'},
#        {'item': '2016-08-05', 'count': '136'},
#        {'item': '2015-12-30', 'count': '133'},
#        {'item': '2016-06-28', 'count': '129'},
#        {'item': '2016-06-22', 'count': '126'},
#        {'item': '2016-04-07', 'count': '125'}],
#       'not_null': '32642',
#       'smallest': '2014-07-28',
#       'cardinality': '1738'},
#      'format': {'align': 'left'}},
#     {'id': 417383749,
#      'name': 'ExpiresDate',
#      'dataTypeName': 'text',
#      'description': 'The date the rental property registration expires.',
#      'fieldName': 'expiresdate',
#      'position': 7,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145311,
#      'width': 204,
#      'cachedContents': {'largest': '2024-01-07',
#       'null': '0',
#       'top': [{'item': '2019-09-30', 'count': '330'},
#        {'item': '2021-03-31', 'count': '217'},
#        {'item': '2020-09-30', 'count': '215'},
#        {'item': '2020-06-30', 'count': '213'},
#        {'item': '2020-12-28', 'count': '187'},
#        {'item': '2020-12-31', 'count': '187'},
#        {'item': '2020-06-29', 'count': '178'},
#        {'item': '2020-03-31', 'count': '171'},
#        {'item': '2021-03-30', 'count': '161'},
#        {'item': '2021-06-30', 'count': '160'},
#        {'item': '2021-06-29', 'count': '156'},
#        {'item': '2019-09-29', 'count': '148'},
#        {'item': '2020-09-29', 'count': '143'},
#        {'item': '2020-12-29', 'count': '143'},
#        {'item': '2021-06-28', 'count': '140'},
#        {'item': '2020-07-08', 'count': '139'},
#        {'item': '2021-08-05', 'count': '138'},
#        {'item': '2021-06-27', 'count': '137'},
#        {'item': '2020-12-30', 'count': '133'},
#        {'item': '2021-04-07', 'count': '127'}],
#       'not_null': '32642',
#       'smallest': '2019-07-28',
#       'cardinality': '1544'},
#      'format': {'align': 'left'}},
#     {'id': 417383750,
#      'name': 'StatusCurrent',
#      'dataTypeName': 'text',
#      'description': 'The status of the property registration.',
#      'fieldName': 'statuscurrent',
#      'position': 8,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145312,
#      'width': 203,
#      'cachedContents': {'largest': 'Active Registration',
#       'null': '0',
#       'top': [{'item': 'Active Registration', 'count': '32642'}],
#       'not_null': '32642',
#       'smallest': 'Active Registration',
#       'cardinality': '1'},
#      'format': {'align': 'left'}},
#     {'id': 417383751,
#      'name': 'OriginalAddress1',
#      'dataTypeName': 'text',
#      'description': 'The street name and number of the property.',
#      'fieldName': 'originaladdress1',
#      'position': 9,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145313,
#      'width': 292,
#      'cachedContents': {'largest': '99 UNION ST',
#       'null': '0',
#       'top': [{'item': '699 JOHN ST', 'count': '37'},
#        {'item': '819 VIRGINIA ST', 'count': '35'},
#        {'item': '820 BLANCHARD ST', 'count': '33'},
#        {'item': '1420 TERRY AVE', 'count': '32'},
#        {'item': '4540 8TH AVE NE', 'count': '32'},
#        {'item': '201 GALER ST', 'count': '30'},
#        {'item': '1545 NW 57TH ST', 'count': '29'},
#        {'item': '300 N 130TH ST', 'count': '29'},
#        {'item': '2901 NE BLAKELEY ST', 'count': '28'},
#        {'item': '2801 1ST AVE', 'count': '28'},
#        {'item': '2033 2ND AVE', 'count': '25'},
#        {'item': '412 11TH AVE', 'count': '25'},
#        {'item': '1711 E OLIVE WAY', 'count': '25'},
#        {'item': '1400 HUBBELL PL', 'count': '25'},
#        {'item': '2600 2ND AVE', 'count': '24'},
#        {'item': '323 QUEEN ANNE AVE N', 'count': '23'},
#        {'item': '2415 2ND AVE', 'count': '23'},
#        {'item': '1414 12TH AVE', 'count': '23'},
#        {'item': '4547 8TH AVE NE', 'count': '21'},
#        {'item': '1631 16TH AVE', 'count': '21'}],
#       'not_null': '32642',
#       'smallest': '10000 37TH AVE SW',
#       'cardinality': '29221'},
#      'format': {'align': 'left'}},
#     {'id': 417383752,
#      'name': 'OriginalCity',
#      'dataTypeName': 'text',
#      'description': "The city for the property's address.",
#      'fieldName': 'originalcity',
#      'position': 10,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145314,
#      'width': 188,
#      'cachedContents': {'largest': 'SEATTLE',
#       'null': '532',
#       'top': [{'item': 'SEATTLE', 'count': '32030'},
#        {'item': 'Seattle', 'count': '69'},
#        {'item': 'seattle', 'count': '10'},
#        {'item': 'mill creek', 'count': '1'}],
#       'not_null': '32110',
#       'smallest': 'mill creek',
#       'cardinality': '4'},
#      'format': {'align': 'left'}},
#     {'id': 417383753,
#      'name': 'OriginalState',
#      'dataTypeName': 'text',
#      'description': "The state for the property's address.",
#      'fieldName': 'originalstate',
#      'position': 11,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145315,
#      'width': 172,
#      'cachedContents': {'largest': 'WA',
#       'null': '532',
#       'top': [{'item': 'WA', 'count': '32110'}],
#       'not_null': '32110',
#       'smallest': 'WA',
#       'cardinality': '1'},
#      'format': {'align': 'left'}},
#     {'id': 417383754,
#      'name': 'OriginalZip',
#      'dataTypeName': 'text',
#      'description': "The Zip code for the property's address.",
#      'fieldName': 'originalzip',
#      'position': 12,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145316,
#      'width': 232,
#      'cachedContents': {'largest': '98199',
#       'null': '682',
#       'top': [{'item': '98103', 'count': '3381'},
#        {'item': '98115', 'count': '2324'},
#        {'item': '98105', 'count': '2254'},
#        {'item': '98122', 'count': '1856'},
#        {'item': '98107', 'count': '1737'},
#        {'item': '98125', 'count': '1736'},
#        {'item': '98117', 'count': '1594'},
#        {'item': '98118', 'count': '1515'},
#        {'item': '98116', 'count': '1479'},
#        {'item': '98102', 'count': '1450'},
#        {'item': '98144', 'count': '1422'},
#        {'item': '98119', 'count': '1394'},
#        {'item': '98109', 'count': '1287'},
#        {'item': '98133', 'count': '1261'},
#        {'item': '98106', 'count': '1186'},
#        {'item': '98108', 'count': '951'},
#        {'item': '98199', 'count': '920'},
#        {'item': '98112', 'count': '884'},
#        {'item': '98126', 'count': '870'},
#        {'item': '98136', 'count': '707'}],
#       'not_null': '31960',
#       'smallest': '102',
#       'cardinality': '32'},
#      'format': {'align': 'left'}},
#     {'id': 417383755,
#      'name': 'PropertyContactName',
#      'dataTypeName': 'text',
#      'description': 'The contact name for the property management.',
#      'fieldName': 'propertycontactname',
#      'position': 13,
#      'renderTypeName': 'text',
#      'tableColumnId': 64145317,
#      'width': 247,
#      'cachedContents': {'largest': 'Zuocheng Ren',
#       'null': '3942',
#       'top': [{'item': 'Maple Leaf Property Management', 'count': '361'},
#        {'item': 'Avenue One Residential', 'count': '352'},
#        {'item': 'Urban Key', 'count': '168'},
#        {'item': 'Ballard Realty Property Management', 'count': '161'},
#        {'item': 'Dwellings', 'count': '157'},
#        {'item': 'CORNELL & ASSOCIATES, INC', 'count': '140'},
#        {'item': 'Real Property Associates', 'count': '137'},
#        {'item': 'David Drake', 'count': '122'},
#        {'item': 'Lydia Cheng', 'count': '110'},
#        {'item': 'Windermere Property Management', 'count': '108'},
#        {'item': 'Davis Property Management', 'count': '108'},
#        {'item': 'Redside Partners', 'count': '97'},
#        {'item': 'North Pacific Properties', 'count': '93'},
#        {'item': 'xxx xxx', 'count': '93'},
#        {'item': 'Apple Property Management', 'count': '89'},
#        {'item': 'Cornell and Associates', 'count': '86'},
#        {'item': 'Andrea Jacobi', 'count': '83'},
#        {'item': 'Prestige Rental Management', 'count': '79'},
#        {'item': 'Brink Property Management', 'count': '76'},
#        {'item': 'SJA Property Management', 'count': '71'}],
#       'not_null': '28700',
#       'smallest': "0People's Real Estate",
#       'cardinality': '17165'},
#      'format': {'align': 'left'}},
#     {'id': 417383756,
#      'name': 'Link',
#      'dataTypeName': 'url',
#      'description': "A link to view full details and current status information about this permit at SDCI's website.",
#      'fieldName': 'link',
#      'position': 14,
#      'renderTypeName': 'url',
#      'tableColumnId': 83049848,
#      'width': 148,
#      'format': {'align': 'left'},
#      'subColumnTypes': ['url', 'description']},
#     {'id': 417383757,
#      'name': 'Latitude',
#      'dataTypeName': 'number',
#      'description': "The latitude of the rental property's address.",
#      'fieldName': 'latitude',
#      'position': 15,
#      'renderTypeName': 'number',
#      'tableColumnId': 64145346,
#      'width': 112,
#      'cachedContents': {'largest': '47.73396596',
#       'null': '350',
#       'top': [{'item': '47.61610781', 'count': '44'},
#        {'item': '47.61811095', 'count': '42'},
#        {'item': '47.61933082', 'count': '38'},
#        {'item': '47.6628958', 'count': '38'},
#        {'item': '47.61672999', 'count': '35'},
#        {'item': '47.61263209', 'count': '35'},
#        {'item': '47.66983804', 'count': '35'},
#        {'item': '47.72400731', 'count': '32'},
#        {'item': '47.63198146', 'count': '32'},
#        {'item': '47.66582251', 'count': '30'},
#        {'item': '47.61208919', 'count': '30'},
#        {'item': '47.61631757', 'count': '29'},
#        {'item': '47.61221024', 'count': '29'},
#        {'item': '47.61944422', 'count': '29'},
#        {'item': '47.60573674', 'count': '26'},
#        {'item': '47.61481762', 'count': '26'},
#        {'item': '47.61343565', 'count': '25'},
#        {'item': '47.61634038', 'count': '24'},
#        {'item': '47.62181749', 'count': '24'},
#        {'item': '47.66268261', 'count': '23'}],
#       'not_null': '32292',
#       'smallest': '47.4822279',
#       'cardinality': '28392'},
#      'format': {'precisionStyle': 'standard', 'align': 'right'}},
#     {'id': 417383758,
#      'name': 'Longitude',
#      'dataTypeName': 'number',
#      'description': "The longitude of the rental property's address.",
#      'fieldName': 'longitude',
#      'position': 16,
#      'renderTypeName': 'number',
#      'tableColumnId': 64145347,
#      'width': 131,
#      'cachedContents': {'largest': '-122.22129376',
#       'null': '350',
#       'top': [{'item': '-122.3357782', 'count': '44'},
#        {'item': '-122.33909821', 'count': '42'},
#        {'item': '-122.34414473', 'count': '38'},
#        {'item': '-122.31883896', 'count': '38'},
#        {'item': '-122.3782764', 'count': '35'},
#        {'item': '-122.34338244', 'count': '35'},
#        {'item': '-122.32925834', 'count': '35'},
#        {'item': '-122.3549938', 'count': '32'},
#        {'item': '-122.35194662', 'count': '32'},
#        {'item': '-122.2970461', 'count': '30'},
#        {'item': '-122.3428896', 'count': '30'},
#        {'item': '-122.32977292', 'count': '29'},
#        {'item': '-122.35210063', 'count': '29'},
#        {'item': '-122.32319284', 'count': '29'},
#        {'item': '-122.31783239', 'count': '26'},
#        {'item': '-122.34777922', 'count': '26'},
#        {'item': '-122.31642934', 'count': '25'},
#        {'item': '-122.35702584', 'count': '24'},
#        {'item': '-122.3489514', 'count': '24'},
#        {'item': '-122.31986058', 'count': '23'}],
#       'not_null': '32292',
#       'smallest': '-122.42010337',
#       'cardinality': '28391'},
#      'format': {'precisionStyle': 'standard', 'align': 'right'}},
#     {'id': 417383759,
#      'name': 'Location1',
#      'dataTypeName': 'point',
#      'description': 'Mapping coordinates for the property address.',
#      'fieldName': 'location1',
#      'position': 17,
#      'renderTypeName': 'point',
#      'tableColumnId': 64145319,
#      'width': 221,
#      'cachedContents': {'null': '350',
#       'top': [{'item': {'coordinates': [-122.3357782, 47.61610781],
#          'type': 'Point'},
#         'count': '44'},
#        {'item': {'coordinates': [-122.33909821, 47.61811095], 'type': 'Point'},
#         'count': '42'},
#        {'item': {'coordinates': [-122.34414473, 47.61933082], 'type': 'Point'},
#         'count': '38'},
#        {'item': {'coordinates': [-122.31883896, 47.6628958], 'type': 'Point'},
#         'count': '38'},
#        {'item': {'coordinates': [-122.34338244, 47.61672999], 'type': 'Point'},
#         'count': '35'},
#        {'item': {'coordinates': [-122.3782764, 47.66983804], 'type': 'Point'},
#         'count': '35'},
#        {'item': {'coordinates': [-122.32925834, 47.61263209], 'type': 'Point'},
#         'count': '35'},
#        {'item': {'coordinates': [-122.3549938, 47.72400731], 'type': 'Point'},
#         'count': '32'},
#        {'item': {'coordinates': [-122.35194662, 47.63198146], 'type': 'Point'},
#         'count': '32'},
#        {'item': {'coordinates': [-122.2970461, 47.66582251], 'type': 'Point'},
#         'count': '30'},
#        {'item': {'coordinates': [-122.3428896, 47.61208919], 'type': 'Point'},
#         'count': '30'},
#        {'item': {'coordinates': [-122.35210063, 47.61631757], 'type': 'Point'},
#         'count': '29'},
#        {'item': {'coordinates': [-122.32977292, 47.61221024], 'type': 'Point'},
#         'count': '29'},
#        {'item': {'coordinates': [-122.32319284, 47.61944422], 'type': 'Point'},
#         'count': '29'},
#        {'item': {'coordinates': [-122.34777922, 47.61481762], 'type': 'Point'},
#         'count': '26'},
#        {'item': {'coordinates': [-122.31783239, 47.60573674], 'type': 'Point'},
#         'count': '26'},
#        {'item': {'coordinates': [-122.31642934, 47.61343565], 'type': 'Point'},
#         'count': '25'},
#        {'item': {'coordinates': [-122.35702584, 47.62181749], 'type': 'Point'},
#         'count': '24'},
#        {'item': {'coordinates': [-122.3489514, 47.61634038], 'type': 'Point'},
#         'count': '24'},
#        {'item': {'coordinates': [-122.31986058, 47.66268261], 'type': 'Point'},
#         'count': '23'}],
#       'not_null': '32292',
#       'cardinality': '28412'},
#      'format': {'align': 'left'}}],
#    'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#    'license': {'name': 'Public Domain'},
#    'metadata': {'custom_fields': {'Department': {'Department': 'Seattle Department of Constructions and Inspections'},
#      'Refresh Frequency': {'Frequency': 'Daily'}},
#     'availableDisplayTypes': ['table', 'fatrow', 'page'],
#     'renderTypeConfig': {'visible': {'table': True}}},
#    'owner': {'id': '5wys-t5s3',
#     'displayName': 'Seattle SDCI',
#     'screenName': 'Seattle SDCI',
#     'type': 'interactive'},
#    'query': {},
#    'rights': ['read'],
#    'tableAuthor': {'id': '5wys-t5s3',
#     'displayName': 'Seattle SDCI',
#     'screenName': 'Seattle SDCI',
#     'type': 'interactive'},
#    'tags': ['rental housing standards'],
#    'flags': ['default', 'restorable', 'restorePossibleForType']}},
#  'data': [['row-d3wj~gyzj~in8j',
#    '00000000-0000-0000-42B9-E7CFDE00AA06',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0127963',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-11-04',
#    '2021-11-04',
#    'Active Registration',
#    '8840 37TH AVE SW',
#    'SEATTLE',
#    'WA',
#    '98126',
#    'Pug Properties 37 LLC',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0127963',
#     None],
#    '47.52346484',
#    '-122.37911657',
#    'POINT (-122.37911657 47.52346484)'],
#   ['row-z979~4by4-4mea',
#    '00000000-0000-0000-889A-F32025A6AA6E',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0130697',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2017-01-31',
#    '2022-01-31',
#    'Active Registration',
#    '8621 Renton AVE S',
#    'SEATTLE',
#    'WA',
#    '98118',
#    'Charles Lane',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0130697',
#     None],
#    '47.52546474',
#    '-122.27709864',
#    'POINT (-122.27709864 47.52546474)'],
#   ['row-j6mu~x9ub~qnzx',
#    '00000000-0000-0000-2128-6E6275BF794C',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0124603',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-12-08',
#    '2021-12-08',
#    'Active Registration',
#    '7312 26TH AVE NW',
#    'SEATTLE',
#    'WA',
#    '98117',
#    'Michael Thompson',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0124603',
#     None],
#    '47.68175236',
#    '-122.38952921',
#    'POINT (-122.38952921 47.68175236)'],
#   ['row-636u~wgj2-qzif',
#    '00000000-0000-0000-3EA6-96060D7A0842',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0117660',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-03-06',
#    '2021-03-06',
#    'Active Registration',
#    '14020 23RD PL NE',
#    'SEATTLE',
#    'WA',
#    '98125',
#    'Dmitry Feldman',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117660',
#     None],
#    '47.73040916',
#    '-122.30377651',
#    'POINT (-122.30377651 47.73040916)'],
#   ['row-xyxw.7tns-yx62',
#    '00000000-0000-0000-5860-B8346169B2F2',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0132924',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2017-12-04',
#    '2022-12-04',
#    'Active Registration',
#    '10508 C WHITMAN AVE N',
#    'SEATTLE',
#    'WA',
#    '98133',
#    'PROTOCOL PROPERTY MANAGEMENT',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132924',
#     None],
#    '47.70539597',
#    '-122.34552979',
#    'POINT (-122.34552979 47.70539597)'],
#   ['row-rhmx~5b7w_tnqq',
#    '00000000-0000-0000-C45B-3BFB60F8CC22',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0103770',
#    'Rental Property',
#    'Registration',
#    '8',
#    'Bon A Ville Apartments',
#    '2015-02-14',
#    '2020-02-14',
#    'Active Registration',
#    '11249 GREENWOOD AVE N',
#    'SEATTLE',
#    'WA',
#    '98133',
#    'Colin Mansfield',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0103770',
#     None],
#    '47.71202852',
#    '-122.3558762',
#    'POINT (-122.3558762 47.71202852)'],
#   ['row-p5jh~y6n5_es56',
#    '00000000-0000-0000-462A-71CA3B09FE77',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0105904',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-05-19',
#    '2020-05-19',
#    'Active Registration',
#    '5217 25TH AVE SW',
#    'SEATTLE',
#    'WA',
#    '98106',
#    'James Emory Tungsvik',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105904',
#     None],
#    '47.5544197',
#    '-122.36461672',
#    'POINT (-122.36461672 47.5544197)'],
#   ['row-kdxa~tj7k.tzn4',
#    '00000000-0000-0000-B338-04C7C60D3DE0',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0110349',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-09-08',
#    '2020-09-08',
#    'Active Registration',
#    '4140 48TH AVE SW',
#    'SEATTLE',
#    'WA',
#    '98116',
#    'Bih-shiung & /Fu-chih Chen',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0110349',
#     None],
#    '47.56538795',
#    '-122.3931783',
#    'POINT (-122.3931783 47.56538795)'],
#   ['row-4n8z-dais~vjtj',
#    '00000000-0000-0000-34AD-C9386E0D7797',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0131850',
#    'Rental Property',
#    'Registration',
#    '2',
#    None,
#    '2017-06-22',
#    '2022-06-22',
#    'Active Registration',
#    '1115 E FIR ST',
#    'SEATTLE',
#    'WA',
#    '98122',
#    'Phil Boos',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0131850',
#     None],
#    '47.60252227',
#    '-122.31739755',
#    'POINT (-122.31739755 47.60252227)'],
#   ['row-x9a8.nbut-keap',
#    '00000000-0000-0000-E44B-A86BB927FFA9',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0108616',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-07-05',
#    '2020-07-05',
#    'Active Registration',
#    '4510 SW AUSTIN ST',
#    'SEATTLE',
#    'WA',
#    '98136',
#    'Dwellings',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0108616',
#     None],
#    '47.53532018',
#    '-122.39100656',
#    'POINT (-122.39100656 47.53532018)'],
#   ['row-6fci_jpb8-sanq',
#    '00000000-0000-0000-47A4-6B29A34D508E',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0112981',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-11-13',
#    '2020-11-13',
#    'Active Registration',
#    '4126 BAKER AVE NW',
#    'SEATTLE',
#    'WA',
#    '98107',
#    'Norman Crouter',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0112981',
#     None],
#    '47.65723681',
#    '-122.35915687',
#    'POINT (-122.35915687 47.65723681)'],
#   ['row-evdx-ys5n.g4we',
#    '00000000-0000-0000-F7FD-D95AAA7152A0',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0116960',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-02-12',
#    '2021-02-12',
#    'Active Registration',
#    '11527 16TH AVE NE',
#    'SEATTLE',
#    'WA',
#    '98125',
#    'Hancock Properties LLC',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116960',
#     None],
#    '47.71295379',
#    '-122.31149478',
#    'POINT (-122.31149478 47.71295379)'],
#   ['row-82t2~yh6t_7p95',
#    '00000000-0000-0000-FA07-B3201300ABAE',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0118382',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-03-22',
#    '2021-03-22',
#    'Active Registration',
#    '2122 S BRANDON ST',
#    'SEATTLE',
#    'WA',
#    '98108',
#    'Rhen Cai',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0118382',
#     None],
#    '47.55429961',
#    '-122.3052001',
#    'POINT (-122.3052001 47.55429961)'],
#   ['row-r2qe.e4r2_pe6j',
#    '00000000-0000-0000-A5E2-193C75E256C3',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0105712',
#    'Rental Property',
#    'Registration',
#    '6',
#    'Horton St Apartments',
#    '2015-05-11',
#    '2020-05-11',
#    'Active Registration',
#    '1755 S HORTON ST',
#    'SEATTLE',
#    'WA',
#    '98144',
#    'Dan Chhan',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105712',
#     None],
#    '47.57392877',
#    '-122.30850352',
#    'POINT (-122.30850352 47.57392877)'],
#   ['row-hyye_aee6.p4h8',
#    '00000000-0000-0000-A4CB-8E2625B0F5E9',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0112893',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-11-06',
#    '2020-11-06',
#    'Active Registration',
#    '5219 48TH AVE SW',
#    'SEATTLE',
#    'WA',
#    '98136',
#    'Walter Sive',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0112893',
#     None],
#    '47.55509815',
#    '-122.39395599',
#    'POINT (-122.39395599 47.55509815)'],
#   ['row-c7as.rbbs-cgxt',
#    '00000000-0000-0000-898C-0B1ED4E9DDC9',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0109212',
#    'Rental Property',
#    'Registration',
#    '1',
#    'Sunset View',
#    '2015-08-04',
#    '2020-08-04',
#    'Active Registration',
#    '2316 44TH AVE SW',
#    'SEATTLE',
#    'WA',
#    '98116',
#    'Andrew Numa',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0109212',
#     None],
#    '47.58243025',
#    '-122.38744995',
#    'POINT (-122.38744995 47.58243025)'],
#   ['row-67hr~f8d9.y3ke',
#    '00000000-0000-0000-AC8C-5B5F7822B521',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0125458',
#    'Rental Property',
#    'Registration',
#    '1',
#    'Wolf House',
#    '2016-09-04',
#    '2021-09-04',
#    'Active Registration',
#    '5115 S PEARL ST',
#    'SEATTLE',
#    'WA',
#    '98118',
#    'Avenue One Residential',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0125458',
#     None],
#    '47.55609255',
#    '-122.26914558',
#    'POINT (-122.26914558 47.55609255)'],
#   ['row-d56q~amuq-qcq8',
#    '00000000-0000-0000-5745-ECB296DB8A55',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0118323',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-03-18',
#    '2021-03-18',
#    'Active Registration',
#    '13003 30TH AVE NE',
#    'SEATTLE',
#    'WA',
#    '98125',
#    'Raymond Hammer',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0118323',
#     None],
#    '47.72307037',
#    '-122.29670158',
#    'POINT (-122.29670158 47.72307037)'],
#   ['row-3up9-iff5-9w3m',
#    '00000000-0000-0000-B454-2418C79C23F1',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0134281',
#    'Rental Property',
#    'Registration',
#    '1',
#    'Ambassador II',
#    '2018-07-16',
#    '2023-07-16',
#    'Active Registration',
#    '506 E HOWELL ST',
#    'SEATTLE',
#    'WA',
#    '98122',
#    'David Weber',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0134281',
#     None],
#    '47.61803326',
#    '-122.32483046',
#    'POINT (-122.32483046 47.61803326)'],
#   ['row-a86e-3adi_zrqv',
#    '00000000-0000-0000-59D5-14005E1F0FDA',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0111612',
#    'Rental Property',
#    'Registration',
#    '2',
#    None,
#    '2015-09-28',
#    '2020-09-28',
#    'Active Registration',
#    '12036 NORTH PARK AVE N',
#    'SEATTLE',
#    'WA',
#    '98133',
#    'Three Keys Property Management',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0111612',
#     None],
#    '47.71704512',
#    '-122.34924487',
#    'POINT (-122.34924487 47.71704512)'],
#   ['row-tbae.hhef.98zt',
#    '00000000-0000-0000-E357-7BF00DE173C4',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0119990',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-04-21',
#    '2021-04-21',
#    'Active Registration',
#    '2202 NE 83RD ST',
#    'SEATTLE',
#    'WA',
#    '98115',
#    None,
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0119990',
#     None],
#    '47.69005192',
#    '-122.30417858',
#    'POINT (-122.30417858 47.69005192)'],
#   ['row-rhuz-vtxq.hnfj',
#    '00000000-0000-0000-35AB-914457392AB5',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0117892',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-03-09',
#    '2021-03-09',
#    'Active Registration',
#    '12060 LAKESIDE AVE NE',
#    'SEATTLE',
#    'WA',
#    '98125',
#    'Steve Badanes',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117892',
#     None],
#    '47.7170861',
#    '-122.28099997',
#    'POINT (-122.28099997 47.7170861)'],
#   ['row-6ih9_mvag_d6hf',
#    '00000000-0000-0000-FB95-FF79EF9127C1',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0123717',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-10-07',
#    '2021-10-07',
#    'Active Registration',
#    '2127 A WAVERLY PL N',
#    'SEATTLE',
#    'WA',
#    '98109',
#    'Edwin Noble',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0123717',
#     None],
#    '47.63848861',
#    '-122.3432375',
#    'POINT (-122.3432375 47.63848861)'],
#   ['row-t6wx~7fk6.2rwk',
#    '00000000-0000-0000-4111-4C8172C889F2',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0117227',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-02-24',
#    '2021-02-24',
#    'Active Registration',
#    '11519 16TH AVE NE',
#    'SEATTLE',
#    'WA',
#    '98125',
#    'Brian Hancock',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117227',
#     None],
#    '47.71282037',
#    '-122.31150058',
#    'POINT (-122.31150058 47.71282037)'],
#   ['row-jgt6-gptf~9ie3',
#    '00000000-0000-0000-F7A8-52811D53DF7D',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0125508',
#    'Rental Property',
#    'Registration',
#    '1',
#    'Aspen The Condominium',
#    '2016-09-05',
#    '2021-09-05',
#    'Active Registration',
#    '2117 #103 N 107TH ST',
#    'SEATTLE',
#    'WA',
#    '98133',
#    'Ko-Sun Yu',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0125508',
#     None],
#    '47.70665875',
#    '-122.33308346',
#    'POINT (-122.33308346 47.70665875)'],
#   ['row-nhjh-vsg8~mj3i',
#    '00000000-0000-0000-31B8-A91FBDFA60CD',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0105873',
#    'Rental Property',
#    'Registration',
#    '4',
#    '13th',
#    '2015-05-18',
#    '2020-05-18',
#    'Active Registration',
#    '3624 13TH AVE W',
#    'SEATTLE',
#    'WA',
#    '98119',
#    'Walls Property Management',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105873',
#     None],
#    '47.65301513',
#    '-122.37327088',
#    'POINT (-122.37327088 47.65301513)'],
#   ['row-gecr-sz32-8v5z',
#    '00000000-0000-0000-F369-B8F2793F5DDA',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0114377',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-12-13',
#    '2020-12-13',
#    'Active Registration',
#    '3901 1ST AVE NW',
#    'SEATTLE',
#    'WA',
#    '98107',
#    'Kirsten Montoya',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0114377',
#     None],
#    '47.65436158',
#    '-122.357409',
#    'POINT (-122.357409 47.65436158)'],
#   ['row-rwf2.xbsr~nxjm',
#    '00000000-0000-0000-857F-05C7B1EAEAC8',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0116216',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-01-15',
#    '2021-01-15',
#    'Active Registration',
#    '4740 48TH AVE SW',
#    'SEATTLE',
#    'WA',
#    '98116',
#    'Nori Suguro',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116216',
#     None],
#    '47.55989026',
#    '-122.39309149',
#    'POINT (-122.39309149 47.55989026)'],
#   ['row-u4ne.a658~8ymr',
#    '00000000-0000-0000-3401-EF8997E5C649',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0113235',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-11-15',
#    '2020-11-15',
#    'Active Registration',
#    '5258 SW CHARLESTOWN ST',
#    'SEATTLE',
#    'WA',
#    '98116',
#    'Lari Garrison',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0113235',
#     None],
#    '47.57054577',
#    '-122.3999979',
#    'POINT (-122.3999979 47.57054577)'],
#   ['row-rkd4-y86u_d2y9',
#    '00000000-0000-0000-D668-549E63277EE3',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0103563',
#    'Rental Property',
#    'Registration',
#    '26',
#    'Brettler Family Place 1',
#    '2015-01-09',
#    '2020-01-09',
#    'Active Registration',
#    '6870 62ND AVE NE',
#    'SEATTLE',
#    'WA',
#    '98115',
#    'Brian Edwards',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0103563',
#     None],
#    '47.67858019',
#    '-122.26173043',
#    'POINT (-122.26173043 47.67858019)'],
#   ['row-ibze-icbe-npz7',
#    '00000000-0000-0000-0D07-88DB8C4E5D68',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0100113',
#    'Rental Property',
#    'Registration',
#    '45',
#    'Bridgeview',
#    '2014-09-30',
#    '2019-09-30',
#    'Active Registration',
#    '708 N 35TH ST',
#    'SEATTLE',
#    'WA',
#    '98103',
#    'CORNELL & ASSOCIATES, INC',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0100113',
#     None],
#    '47.65061424',
#    '-122.34946964',
#    'POINT (-122.34946964 47.65061424)'],
#   ['row-rhym-uab9~xpha',
#    '00000000-0000-0000-3065-CF9D93287444',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0129847',
#    'Rental Property',
#    'Registration',
#    '3',
#    None,
#    '2017-01-02',
#    '2022-01-02',
#    'Active Registration',
#    '1032 NE 68TH ST',
#    'SEATTLE',
#    'WA',
#    '98115',
#    None,
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129847',
#     None],
#    '47.67820276',
#    '-122.31597077',
#    'POINT (-122.31597077 47.67820276)'],
#   ['row-4t9i~xyq2_8vix',
#    '00000000-0000-0000-9E70-61A4008EFAF6',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0132270',
#    'Rental Property',
#    'Registration',
#    '1',
#    'Ballard Place',
#    '2017-08-23',
#    '2022-08-23',
#    'Active Registration',
#    '1545 NW 57TH ST',
#    'SEATTLE',
#    'WA',
#    '98107',
#    'Brooke Loughrin',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132270',
#     None],
#    '47.66983804',
#    '-122.3782764',
#    'POINT (-122.3782764 47.66983804)'],
#   ['row-bdrh_jc2d.x32n',
#    '00000000-0000-0000-9216-D3150D3615FA',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0132681',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2017-10-26',
#    '2022-10-26',
#    'Active Registration',
#    '3805 M L KING JR WAY S',
#    'SEATTLE',
#    'WA',
#    '98144',
#    'Jacob Chen',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132681',
#     None],
#    '47.56993804',
#    '-122.29724876',
#    'POINT (-122.29724876 47.56993804)'],
#   ['row-vz6r.brnn-5j5t',
#    '00000000-0000-0000-282C-AA1D37653F3E',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0129331',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-12-23',
#    '2021-12-23',
#    'Active Registration',
#    '519 NE 83RD ST',
#    'SEATTLE',
#    'WA',
#    '98115',
#    'Acer NW, Inc',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129331',
#     None],
#    '47.68876673',
#    '-122.32213945',
#    'POINT (-122.32213945 47.68876673)'],
#   ['row-4wcr~wbu5_v3fd',
#    '00000000-0000-0000-A443-F38B60C5C014',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0108195',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-07-15',
#    '2020-07-15',
#    'Active Registration',
#    '8837 29TH AVE NW',
#    'SEATTLE',
#    'WA',
#    '98117',
#    'GREG PAYNE',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0108195',
#     None],
#    '47.69401891',
#    '-122.39416579',
#    'POINT (-122.39416579 47.69401891)'],
#   ['row-bz2t-7amh~i7tc',
#    '00000000-0000-0000-B942-AB7435482D05',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0121047',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-05-26',
#    '2021-05-26',
#    'Active Registration',
#    '736 N 72ND ST',
#    'SEATTLE',
#    'WA',
#    '98103',
#    "MacPherson's Property Management",
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0121047',
#     None],
#    '47.68125936',
#    '-122.34828591',
#    'POINT (-122.34828591 47.68125936)'],
#   ['row-izir.qi5d~pqus',
#    '00000000-0000-0000-FF8D-491A2DC35C33',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0117085',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-02-17',
#    '2021-02-17',
#    'Active Registration',
#    '11501 B 26TH AVE NE',
#    'SEATTLE',
#    'WA',
#    '98125',
#    'oanh hoang',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117085',
#     None],
#    '47.71222698',
#    '-122.3005834',
#    'POINT (-122.3005834 47.71222698)'],
#   ['row-54dz-ieaw-mdzz',
#    '00000000-0000-0000-6698-7BBE522F768F',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0133804',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2018-04-30',
#    '2023-04-30',
#    'Active Registration',
#    '616 14TH AVE E',
#    'SEATTLE',
#    'WA',
#    '98112',
#    'David Drake',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0133804',
#     None],
#    '47.62482576',
#    '-122.31436897',
#    'POINT (-122.31436897 47.62482576)'],
#   ['row-u3ez_cu98_sz9x',
#    '00000000-0000-0000-53C7-6FEF584D8736',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0101971',
#    'Rental Property',
#    'Registration',
#    '38',
#    'Carribean House Apartments',
#    '2014-09-29',
#    '2019-09-29',
#    'Active Registration',
#    '10800 ROOSEVELT WAY NE',
#    'SEATTLE',
#    'WA',
#    '98125',
#    'Bob Dinehart',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0101971',
#     None],
#    '47.70801984',
#    '-122.31751673',
#    'POINT (-122.31751673 47.70801984)'],
#   ['row-6g5i.n2c5_x85a',
#    '00000000-0000-0000-9C98-973417753BA8',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0132540',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2017-10-06',
#    '2022-10-06',
#    'Active Registration',
#    '1153 82nd',
#    'SEATTLE',
#    'WA',
#    '98103',
#    None,
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132540',
#     None],
#    '47.68823033',
#    '-122.34215974',
#    'POINT (-122.34215974 47.68823033)'],
#   ['row-nec4_e9iw_9i2m',
#    '00000000-0000-0000-60C4-957730D87C6E',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0136272',
#    'Rental Property',
#    'Registration',
#    '1',
#    'Charles St',
#    '2019-05-30',
#    '2021-05-30',
#    'Active Registration',
#    '2011 S CHARLES ST',
#    'SEATTLE',
#    'WA',
#    '98144',
#    "Ryan O'Connor",
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0136272',
#     None],
#    '47.59424611',
#    '-122.3056695',
#    'POINT (-122.3056695 47.59424611)'],
#   ['row-9xrb.cup5_vfqp',
#    '00000000-0000-0000-80A5-2B75777D646B',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0108919',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-07-13',
#    '2020-07-13',
#    'Active Registration',
#    '8456 20TH AVE SW',
#    'SEATTLE',
#    'WA',
#    '98106',
#    'Michele Rozinek',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0108919',
#     None],
#    '47.52664629',
#    '-122.35885813',
#    'POINT (-122.35885813 47.52664629)'],
#   ['row-kkv6~2y9a-ymyc',
#    '00000000-0000-0000-4AEE-0A9EC5DE74F4',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0116534',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-02-03',
#    '2021-02-03',
#    'Active Registration',
#    '1026 NE 117TH ST',
#    'SEATTLE',
#    'WA',
#    '98125',
#    'Ruth Patterson',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116534',
#     None],
#    '47.71424797',
#    '-122.3171297',
#    'POINT (-122.3171297 47.71424797)'],
#   ['row-fiya-yfhm~anbc',
#    '00000000-0000-0000-D078-4C3A2F3A75E5',
#    0,
#    1561394371,
#    None,
#    1561394394,
#    None,
#    '{ }',
#    '001-0116332',
#    'Rental Property',
#    'Registration',
#    '13',
#    None,
#    '2016-01-27',
#    '2021-01-27',
#    'Active Registration',
#    '323 BELMONT AVE E',
#    'SEATTLE',
#    'WA',
#    '98102',
#    'Phalon Perry',
# ...
#     None],
#    '47.67355064',
#    '-122.38502478',
#    'POINT (-122.38502478 47.67355064)'],
#   ['row-zj49~v7sx~vbaq',
#    '00000000-0000-0000-EC98-959A4FD8F7B0',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0114184',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-12-09',
#    '2020-12-09',
#    'Active Registration',
#    '236 NW 56TH ST',
#    'SEATTLE',
#    'WA',
#    '98107',
#    'Alex Saunders',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0114184',
#     None],
#    '47.66978107',
#    '-122.36056555',
#    'POINT (-122.36056555 47.66978107)'],
#   ['row-5yvs_5wyy.ndxz',
#    '00000000-0000-0000-87C5-5874DCDDC3B5',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0115464',
#    'Rental Property',
#    'Registration',
#    '1',
#    '1907',
#    '2015-12-30',
#    '2020-12-30',
#    'Active Registration',
#    '1907 20TH AVE S',
#    'SEATTLE',
#    'WA',
#    '98144',
#    'Yu He',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0115464',
#     None],
#    '47.58607457',
#    '-122.30720188',
#    'POINT (-122.30720188 47.58607457)'],
#   ['row-nzci.4mjc.wd4k',
#    '00000000-0000-0000-020C-44CB1DCF7D4D',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0120585',
#    'Rental Property',
#    'Registration',
#    '3',
#    None,
#    '2016-05-12',
#    '2021-05-12',
#    'Active Registration',
#    '419 14TH AVE E',
#    'SEATTLE',
#    'WA',
#    '98112',
#    'North Pacific Properties',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0120585',
#     None],
#    '47.62262545',
#    '-122.31491079',
#    'POINT (-122.31491079 47.62262545)'],
#   ['row-nb8b-c3n5~xqcj',
#    '00000000-0000-0000-36EC-0EA12963D470',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0122268',
#    'Rental Property',
#    'Registration',
#    '1',
#    'Ballard Landing #401',
#    '2016-06-29',
#    '2021-06-29',
#    'Active Registration',
#    '1422 NW 63RD ST',
#    'SEATTLE',
#    'WA',
#    '98107',
#    'Renee Stewart',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0122268',
#     None],
#    '47.6747468',
#    '-122.37481146',
#    'POINT (-122.37481146 47.6747468)'],
#   ['row-jt3w.vyx5~cf8t',
#    '00000000-0000-0000-1647-D03ABC3EA9CB',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0123681',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-08-09',
#    '2021-08-09',
#    'Active Registration',
#    '749 N 91ST ST',
#    'SEATTLE',
#    'WA',
#    '98103',
#    'Ann Peach',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0123681',
#     None],
#    '47.69473509',
#    '-122.34786742',
#    'POINT (-122.34786742 47.69473509)'],
#   ['row-rnxt-9nad-ea3g',
#    '00000000-0000-0000-7182-1D7EFD6E2B80',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0128737',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-12-06',
#    '2021-12-06',
#    'Active Registration',
#    '121 VINE ST',
#    'SEATTLE',
#    'WA',
#    '98121',
#    'Colleen Gasca',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0128737',
#     None],
#    '47.61553253',
#    '-122.34883741',
#    'POINT (-122.34883741 47.61553253)'],
#   ['row-7qy7.ysy5-p28c',
#    '00000000-0000-0000-D830-ABDAD8E59D9A',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0104572',
#    'Rental Property',
#    'Registration',
#    '6',
#    None,
#    '2015-04-01',
#    '2020-04-01',
#    'Active Registration',
#    '5607 15TH AVE NE',
#    'SEATTLE',
#    'WA',
#    '98105',
#    'Greg Huber',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0104572',
#     None],
#    '47.66970274',
#    '-122.31224745',
#    'POINT (-122.31224745 47.66970274)'],
#   ['row-bwin-ykc2_wmpm',
#    '00000000-0000-0000-6E5E-A5AA88CA8832',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0135937',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2019-04-08',
#    '2021-04-08',
#    'Active Registration',
#    '1007 N 48TH ST',
#    'SEATTLE',
#    'WA',
#    '98103',
#    'Becca Fraiman',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0135937',
#     None],
#    '47.66340275',
#    '-122.34573186',
#    'POINT (-122.34573186 47.66340275)'],
#   ['row-8d7f~nxwx~q3qn',
#    '00000000-0000-0000-3963-5D7F1376B3B5',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0105282',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-04-07',
#    '2020-04-07',
#    'Active Registration',
#    '300 W MCGRAW PL',
#    'SEATTLE',
#    'WA',
#    '98119',
#    'Laurie Finn',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105282',
#     None],
#    '47.63988137',
#    '-122.36120343',
#    'POINT (-122.36120343 47.63988137)'],
#   ['row-w6wd.xxsh~k7h8',
#    '00000000-0000-0000-7D8A-EF56B99EE3E8',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0132476',
#    'Rental Property',
#    'Registration',
#    '1',
#    'WESTLAKE 201',
#    '2017-09-30',
#    '2022-09-30',
#    'Active Registration',
#    '2125 WESTLAKE AVE N',
#    'SEATTLE',
#    'WA',
#    '98109',
#    'Stephen Sy',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132476',
#     None],
#    '47.63893517',
#    '-122.34168235',
#    'POINT (-122.34168235 47.63893517)'],
#   ['row-3qa5_qpch-nx59',
#    '00000000-0000-0000-8B29-7BB048789376',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0135371',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2019-01-18',
#    '2021-01-18',
#    'Active Registration',
#    '950 N 96TH ST',
#    'SEATTLE',
#    'WA',
#    '98103',
#    'WJL HomeServices LLC.',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0135371',
#     None],
#    '47.69889715',
#    '-122.34562406',
#    'POINT (-122.34562406 47.69889715)'],
#   ['row-7cjx.pr5w~uuhe',
#    '00000000-0000-0000-71E5-62FAA9079A21',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0104591',
#    'Rental Property',
#    'Registration',
#    '6',
#    None,
#    '2015-03-24',
#    '2020-03-24',
#    'Active Registration',
#    '711 21ST AVE',
#    'SEATTLE',
#    'WA',
#    '98122',
#    'Michael Kaz',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0104591',
#     None],
#    '47.60843472',
#    '-122.30540282',
#    'POINT (-122.30540282 47.60843472)'],
#   ['row-wkdh_ww6y-uxmp',
#    '00000000-0000-0000-B6DC-108E1DF4219A',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0115444',
#    'Rental Property',
#    'Registration',
#    '2',
#    None,
#    '2015-12-29',
#    '2020-12-29',
#    'Active Registration',
#    '1817 25TH AVE S',
#    'SEATTLE',
#    'WA',
#    '98144',
#    'Yong Chang',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0115444',
#     None],
#    '47.58644468',
#    '-122.30066615',
#    'POINT (-122.30066615 47.58644468)'],
#   ['row-cwqh_drrk_mhdi',
#    '00000000-0000-0000-E41B-75065D93E0D2',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0110980',
#    'Rental Property',
#    'Registration',
#    '1',
#    '3844-49th',
#    '2015-09-18',
#    '2020-09-18',
#    'Active Registration',
#    '3844 49TH AVE SW',
#    'SEATTLE',
#    'WA',
#    '98116',
#    'Urban Key',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0110980',
#     None],
#    '47.56888884',
#    '-122.39453107',
#    'POINT (-122.39453107 47.56888884)'],
#   ['row-pgv7.zp3i_czdi',
#    '00000000-0000-0000-C339-10AFDAB9C040',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0107609',
#    'Rental Property',
#    'Registration',
#    '2',
#    '1302 N 48th',
#    '2015-06-25',
#    '2020-06-25',
#    'Active Registration',
#    '1302 N 48TH ST',
#    'SEATTLE',
#    'WA',
#    '98103',
#    'Zachary Downing',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0107609',
#     None],
#    '47.66376289',
#    '-122.34185323',
#    'POINT (-122.34185323 47.66376289)'],
#   ['row-4uev~y2sk-uupr',
#    '00000000-0000-0000-7C82-2B76284F9098',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0111026',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2015-09-18',
#    '2020-09-18',
#    'Active Registration',
#    '1018 E SHELBY ST',
#    'SEATTLE',
#    'WA',
#    '98102',
#    'Christine Yokan',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0111026',
#     None],
#    '47.64673106',
#    '-122.31877026',
#    'POINT (-122.31877026 47.64673106)'],
#   ['row-ir5z.6nx5~3u6y',
#    '00000000-0000-0000-681B-AF6A11CA0331',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0112832',
#    'Rental Property',
#    'Registration',
#    '3',
#    None,
#    '2015-11-06',
#    '2020-11-06',
#    'Active Registration',
#    '6240 6TH AVE NW',
#    'SEATTLE',
#    'WA',
#    '98107',
#    'Kathleen Falkenberg',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0112832',
#     None],
#    '47.67543043',
#    '-122.36371196',
#    'POINT (-122.36371196 47.67543043)'],
#   ['row-g7vn.4rzj-arey',
#    '00000000-0000-0000-6FFC-7950A6AA6AE9',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0131711',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2017-06-02',
#    '2022-06-02',
#    'Active Registration',
#    '1906 E LYNN ST',
#    'SEATTLE',
#    'WA',
#    '98112',
#    'Edmond Ambauen',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0131711',
#     None],
#    '47.63977206',
#    '-122.30689623',
#    'POINT (-122.30689623 47.63977206)'],
#   ['row-kaii_9ykg~gdj4',
#    '00000000-0000-0000-6421-3981B87B0B0C',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0134779',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2018-10-01',
#    '2023-10-01',
#    'Active Registration',
#    '128 C 24TH AVE E',
#    'SEATTLE',
#    'WA',
#    '98112',
#    None,
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0134779',
#     None],
#    '47.61983097',
#    '-122.3006841',
#    'POINT (-122.3006841 47.61983097)'],
#   ['row-mess_ni5n_d2av',
#    '00000000-0000-0000-8B81-57A9660A712C',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0128469',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-11-29',
#    '2021-11-29',
#    'Active Registration',
#    '9025 25TH AVE NE',
#    'SEATTLE',
#    'WA',
#    '98115',
#    'Louis Bajuk-Yorgan',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0128469',
#     None],
#    '47.69468412',
#    '-122.30185551',
#    'POINT (-122.30185551 47.69468412)'],
#   ['row-ukx6~8dmn~ztis',
#    '00000000-0000-0000-6BB1-581E97522F9B',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0106827',
#    'Rental Property',
#    'Registration',
#    '2',
#    None,
#    '2015-06-14',
#    '2020-06-14',
#    'Active Registration',
#    '914 W EMERSON ST',
#    'SEATTLE',
#    'WA',
#    '98119',
#    'LGC UW Portfolio II LLC',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0106827',
#     None],
#    '47.65258481',
#    '-122.36935131',
#    'POINT (-122.36935131 47.65258481)'],
#   ['row-22az_wk69-2k8u',
#    '00000000-0000-0000-CCBA-F99C2A1FD5FA',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0117782',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-03-08',
#    '2021-03-08',
#    'Active Registration',
#    '11320 LAKESIDE AVE NE',
#    'SEATTLE',
#    'WA',
#    '98125',
#    'HARPAL DHALIWAL',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117782',
#     None],
#    '47.71185585',
#    '-122.27738046',
#    'POINT (-122.27738046 47.71185585)'],
#   ['row-7qmq.74nf~xts2',
#    '00000000-0000-0000-F43D-D58E81F0564B',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0112213',
#    'Rental Property',
#    'Registration',
#    '4',
#    None,
#    '2015-10-13',
#    '2020-10-13',
#    'Active Registration',
#    '8849 NESBIT AVE N',
#    'SEATTLE',
#    'WA',
#    '98103',
#    'John Maloney',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0112213',
#     None],
#    '47.69380931',
#    '-122.34370086',
#    'POINT (-122.34370086 47.69380931)'],
#   ['row-x7qu-7r73~xf8d',
#    '00000000-0000-0000-E352-8329F3B22443',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0130538',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2017-01-20',
#    '2022-01-20',
#    'Active Registration',
#    '7741 2ND AVE NE',
#    'SEATTLE',
#    'WA',
#    '98115',
#    'Saint Andrews Episcopal Church',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0130538',
#     None],
#    '47.68627783',
#    '-122.32727713',
#    'POINT (-122.32727713 47.68627783)'],
#   ['row-eezh~tieu.x4z2',
#    '00000000-0000-0000-2769-D926BF1CADDE',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0109093',
#    'Rental Property',
#    'Registration',
#    '3',
#    None,
#    '2015-08-02',
#    '2020-08-02',
#    'Active Registration',
#    '2106 6TH AVE W',
#    'SEATTLE',
#    'WA',
#    '98119',
#    'Mariana Panaiotov',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0109093',
#     None],
#    '47.63806334',
#    '-122.36471518',
#    'POINT (-122.36471518 47.63806334)'],
#   ['row-6yaq_wf9z-jq7h',
#    '00000000-0000-0000-07B2-DA3AAAB0F6AE',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0105665',
#    'Rental Property',
#    'Registration',
#    '1',
#    'Harwood Condos',
#    '2015-05-06',
#    '2020-05-06',
#    'Active Registration',
#    '1311 12TH AVE S',
#    'SEATTLE',
#    'WA',
#    '98144',
#    'Brian Martin',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105665',
#     None],
#    '47.59094844',
#    '-122.31801682',
#    'POINT (-122.31801682 47.59094844)'],
#   ['row-mk39-4jfu~9my3',
#    '00000000-0000-0000-41CD-768BF0EB9DD8',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0117890',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-03-09',
#    '2021-03-09',
#    'Active Registration',
#    '171 15TH AVE',
#    'SEATTLE',
#    'WA',
#    '98122',
#    'Alex Karchevsky',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117890',
#     None],
#    '47.60336516',
#    '-122.31315485',
#    'POINT (-122.31315485 47.60336516)'],
#   ['row-7va8.42qd.4q66',
#    '00000000-0000-0000-F043-3559FFD19CDB',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0120003',
#    'Rental Property',
#    'Registration',
#    '2',
#    'Union Street',
#    '2016-04-23',
#    '2021-04-23',
#    'Active Registration',
#    '2512 E UNION ST',
#    'SEATTLE',
#    'WA',
#    '98122',
#    None,
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0120003',
#     None],
#    '47.6131743',
#    '-122.29948923',
#    'POINT (-122.29948923 47.6131743)'],
#   ['row-civr-9wpb~u6vy',
#    '00000000-0000-0000-B72B-F1441ADA62B7',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0129171',
#    'Rental Property',
#    'Registration',
#    '1',
#    None,
#    '2016-12-22',
#    '2021-12-22',
#    'Active Registration',
#    '5121 S WILLOW ST',
#    'SEATTLE',
#    'WA',
#    '98118',
#    'Michael Leavy',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129171',
#     None],
#    '47.5402983',
#    '-122.26883781',
#    'POINT (-122.26883781 47.5402983)'],
#   ['row-dvkz~fbtu_uq2b',
#    '00000000-0000-0000-24B0-D639CE488E13',
#    0,
#    1561394371,
#    None,
#    1561394395,
#    None,
#    '{ }',
#    '001-0101597',
#    'Rental Property',
#    'Registration',
#    '16',
#    'Delphian Apartments',
#    '2014-09-25',
#    '2019-09-25',
#    'Active Registration',
#    '400 W ROY ST',
#    'SEATTLE',
#    'WA',
#    '98119',
#    'John Cain',
#    ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0101597',
#     None],
#    '47.62618783',
#    '-122.36218374',
#    'POINT (-122.36218374 47.62618783)'],
#   ...]}

# %%
#datatype of seattle props json file
type(seattleprops)
# Out:
# dict

# %%
#seattleprops dictionary keys
seattleprops.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
#the metadata
#seattleprops['meta']
# Out:
# {'view': {'id': 'j2xh-c7vt',
#   'name': 'Rental Property Registration',
#   'attribution': 'City of Seattle',
#   'attributionLink': 'http://www.seattle.gov/sdci',
#   'averageRating': 0,
#   'category': 'Permitting',
#   'createdAt': 1524754568,
#   'description': 'A list of properties that have registered their rental units with the City of Seattle under the Rental Registration and Inspection Ordinance.',
#   'displayType': 'table',
#   'downloadCount': 313,
#   'hideFromCatalog': False,
#   'hideFromDataJson': False,
#   'indexUpdatedAt': 1562867880,
#   'licenseId': 'PUBLIC_DOMAIN',
#   'locale': 'en_US',
#   'newBackend': True,
#   'numberOfComments': 0,
#   'oid': 31914420,
#   'provenance': 'official',
#   'publicationAppendEnabled': False,
#   'publicationDate': 1562867928,
#   'publicationGroup': 15065876,
#   'publicationStage': 'published',
#   'rowsUpdatedAt': 1564242562,
#   'rowsUpdatedBy': '5wys-t5s3',
#   'tableId': 16352451,
#   'totalTimesRated': 0,
#   'viewCount': 2309,
#   'viewLastModified': 1562867928,
#   'viewType': 'tabular',
#   'approvals': [{'reviewedAt': 1529517213,
#     'reviewedAutomatically': True,
#     'state': 'approved',
#     'submissionId': 886413,
#     'submissionObject': 'public_audience_request',
#     'submissionOutcome': 'change_audience',
#     'submittedAt': 1529517213,
#     'workflowId': 623,
#     'submissionDetails': {'permissionType': 'READ'},
#     'submissionOutcomeApplication': {'failureCount': 0, 'status': 'success'},
#     'submitter': {'id': '5wys-t5s3', 'displayName': 'Seattle SDCI'}}],
#   'columns': [{'id': -1,
#     'name': 'sid',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':sid',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'id',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':id',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'position',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':position',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'created_at',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':created_at',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'created_meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':created_meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'updated_at',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':updated_at',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'updated_meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':updated_meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': -1,
#     'name': 'meta',
#     'dataTypeName': 'meta_data',
#     'fieldName': ':meta',
#     'position': 0,
#     'renderTypeName': 'meta_data',
#     'format': {},
#     'flags': ['hidden']},
#    {'id': 417383743,
#     'name': 'RegistrationNum',
#     'dataTypeName': 'text',
#     'description': "The tracking number used to refer to this registration in SDCI's tracking system.",
#     'fieldName': 'permitnum',
#     'position': 1,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145304,
#     'width': 183,
#     'cachedContents': {'largest': '001-0136786',
#      'null': '0',
#      'top': [{'item': '001-0108588', 'count': '1'},
#       {'item': '001-0120682', 'count': '1'},
#       {'item': '001-0130530', 'count': '1'},
#       {'item': '001-0119069', 'count': '1'},
#       {'item': '001-0122886', 'count': '1'},
#       {'item': '001-0125025', 'count': '1'},
#       {'item': '001-0125814', 'count': '1'},
#       {'item': '001-0113008', 'count': '1'},
#       {'item': '001-0112528', 'count': '1'},
#       {'item': '001-0116228', 'count': '1'},
#       {'item': '001-0122270', 'count': '1'},
#       {'item': '001-0126635', 'count': '1'},
#       {'item': '001-0113489', 'count': '1'},
#       {'item': '001-0103821', 'count': '1'},
#       {'item': '001-0134790', 'count': '1'},
#       {'item': '001-0121488', 'count': '1'},
#       {'item': '001-0120887', 'count': '1'},
#       {'item': '001-0102240', 'count': '1'},
#       {'item': '001-0122396', 'count': '1'},
#       {'item': '001-0127207', 'count': '1'}],
#      'not_null': '32642',
#      'smallest': '001-0100004',
#      'cardinality': '32642'},
#     'format': {'align': 'left'}},
#    {'id': 417383744,
#     'name': 'RegisteredTypeMapped',
#     'dataTypeName': 'text',
#     'description': 'The type of registration that we have issued or that is in progress. ',
#     'fieldName': 'permittypemapped',
#     'position': 2,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145306,
#     'width': 224,
#     'cachedContents': {'largest': 'Rental Property',
#      'null': '0',
#      'top': [{'item': 'Rental Property', 'count': '32642'}],
#      'not_null': '32642',
#      'smallest': 'Rental Property',
#      'cardinality': '1'},
#     'format': {'align': 'left'}},
#    {'id': 417383745,
#     'name': 'RegisteredTypeDesc',
#     'dataTypeName': 'text',
#     'description': 'Additional information about the property. ',
#     'fieldName': 'permittypedesc',
#     'position': 3,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145307,
#     'width': 198,
#     'cachedContents': {'largest': 'Registration',
#      'null': '0',
#      'top': [{'item': 'Registration', 'count': '32642'}],
#      'not_null': '32642',
#      'smallest': 'Registration',
#      'cardinality': '1'},
#     'format': {'align': 'left'}},
#    {'id': 417383746,
#     'name': 'RentalHousingUnits',
#     'dataTypeName': 'number',
#     'description': 'The number of rental units that are registered at the property.',
#     'fieldName': 'rentalhousingunits',
#     'position': 4,
#     'renderTypeName': 'number',
#     'tableColumnId': 64145308,
#     'width': 209,
#     'cachedContents': {'largest': '654',
#      'null': '0',
#      'top': [{'item': '1', 'count': '22684'},
#       {'item': '2', 'count': '2967'},
#       {'item': '3', 'count': '1326'},
#       {'item': '4', 'count': '997'},
#       {'item': '6', 'count': '566'},
#       {'item': '5', 'count': '469'},
#       {'item': '8', 'count': '422'},
#       {'item': '7', 'count': '282'},
#       {'item': '9', 'count': '235'},
#       {'item': '10', 'count': '230'},
#       {'item': '12', 'count': '197'},
#       {'item': '11', 'count': '127'},
#       {'item': '15', 'count': '121'},
#       {'item': '16', 'count': '112'},
#       {'item': '14', 'count': '103'},
#       {'item': '13', 'count': '95'},
#       {'item': '18', 'count': '90'},
#       {'item': '20', 'count': '90'},
#       {'item': '24', 'count': '76'},
#       {'item': '21', 'count': '65'}],
#      'not_null': '32642',
#      'smallest': '1',
#      'cardinality': '228'},
#     'format': {'precisionStyle': 'standard', 'align': 'right'}},
#    {'id': 417383747,
#     'name': 'PropertyName',
#     'dataTypeName': 'text',
#     'description': 'The name of the registered property.',
#     'fieldName': 'propertyname',
#     'position': 5,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145309,
#     'width': 244,
#     'cachedContents': {'largest': 'Zwaller house',
#      'null': '23974',
#      'top': [{'item': 'Duplex', 'count': '22'},
#       {'item': 'Belltown Court', 'count': '22'},
#       {'item': 'Insignia', 'count': '21'},
#       {'item': 'Cristalla', 'count': '17'},
#       {'item': 'N/A', 'count': '17'},
#       {'item': 'Ballard Place', 'count': '16'},
#       {'item': 'The Braeburn', 'count': '16'},
#       {'item': 'Blakeley Commons', 'count': '15'},
#       {'item': 'Marselle', 'count': '15'},
#       {'item': 'Enso', 'count': '15'},
#       {'item': 'Meridian', 'count': '14'},
#       {'item': 'Invitation Homes', 'count': '14'},
#       {'item': 'Veridian Cove', 'count': '14'},
#       {'item': 'Cosmopolitan', 'count': '14'},
#       {'item': 'Garden Court', 'count': '13'},
#       {'item': 'Meritage', 'count': '13'},
#       {'item': 'Trace North', 'count': '13'},
#       {'item': 'University Plaza', 'count': '12'},
#       {'item': 'none', 'count': '12'},
#       {'item': 'Escala', 'count': '11'}],
#      'not_null': '8668',
#      'smallest': '\x7f\x7f\x7f',
#      'cardinality': '7172'},
#     'format': {'align': 'left'}},
#    {'id': 417383748,
#     'name': 'RegisteredDate',
#     'dataTypeName': 'text',
#     'description': "The date the property registered it's rental units.",
#     'fieldName': 'registereddate',
#     'position': 6,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145310,
#     'width': 204,
#     'cachedContents': {'largest': '2019-07-25',
#      'null': '0',
#      'top': [{'item': '2014-09-30', 'count': '329'},
#       {'item': '2015-09-30', 'count': '215'},
#       {'item': '2016-03-31', 'count': '214'},
#       {'item': '2015-06-30', 'count': '213'},
#       {'item': '2015-12-31', 'count': '187'},
#       {'item': '2015-12-28', 'count': '186'},
#       {'item': '2015-06-29', 'count': '178'},
#       {'item': '2015-03-31', 'count': '171'},
#       {'item': '2016-03-30', 'count': '157'},
#       {'item': '2016-06-30', 'count': '154'},
#       {'item': '2016-06-29', 'count': '152'},
#       {'item': '2014-09-29', 'count': '148'},
#       {'item': '2015-12-29', 'count': '143'},
#       {'item': '2015-09-29', 'count': '142'},
#       {'item': '2015-07-08', 'count': '138'},
#       {'item': '2016-08-05', 'count': '136'},
#       {'item': '2015-12-30', 'count': '133'},
#       {'item': '2016-06-28', 'count': '129'},
#       {'item': '2016-06-22', 'count': '126'},
#       {'item': '2016-04-07', 'count': '125'}],
#      'not_null': '32642',
#      'smallest': '2014-07-28',
#      'cardinality': '1738'},
#     'format': {'align': 'left'}},
#    {'id': 417383749,
#     'name': 'ExpiresDate',
#     'dataTypeName': 'text',
#     'description': 'The date the rental property registration expires.',
#     'fieldName': 'expiresdate',
#     'position': 7,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145311,
#     'width': 204,
#     'cachedContents': {'largest': '2024-01-07',
#      'null': '0',
#      'top': [{'item': '2019-09-30', 'count': '330'},
#       {'item': '2021-03-31', 'count': '217'},
#       {'item': '2020-09-30', 'count': '215'},
#       {'item': '2020-06-30', 'count': '213'},
#       {'item': '2020-12-28', 'count': '187'},
#       {'item': '2020-12-31', 'count': '187'},
#       {'item': '2020-06-29', 'count': '178'},
#       {'item': '2020-03-31', 'count': '171'},
#       {'item': '2021-03-30', 'count': '161'},
#       {'item': '2021-06-30', 'count': '160'},
#       {'item': '2021-06-29', 'count': '156'},
#       {'item': '2019-09-29', 'count': '148'},
#       {'item': '2020-09-29', 'count': '143'},
#       {'item': '2020-12-29', 'count': '143'},
#       {'item': '2021-06-28', 'count': '140'},
#       {'item': '2020-07-08', 'count': '139'},
#       {'item': '2021-08-05', 'count': '138'},
#       {'item': '2021-06-27', 'count': '137'},
#       {'item': '2020-12-30', 'count': '133'},
#       {'item': '2021-04-07', 'count': '127'}],
#      'not_null': '32642',
#      'smallest': '2019-07-28',
#      'cardinality': '1544'},
#     'format': {'align': 'left'}},
#    {'id': 417383750,
#     'name': 'StatusCurrent',
#     'dataTypeName': 'text',
#     'description': 'The status of the property registration.',
#     'fieldName': 'statuscurrent',
#     'position': 8,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145312,
#     'width': 203,
#     'cachedContents': {'largest': 'Active Registration',
#      'null': '0',
#      'top': [{'item': 'Active Registration', 'count': '32642'}],
#      'not_null': '32642',
#      'smallest': 'Active Registration',
#      'cardinality': '1'},
#     'format': {'align': 'left'}},
#    {'id': 417383751,
#     'name': 'OriginalAddress1',
#     'dataTypeName': 'text',
#     'description': 'The street name and number of the property.',
#     'fieldName': 'originaladdress1',
#     'position': 9,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145313,
#     'width': 292,
#     'cachedContents': {'largest': '99 UNION ST',
#      'null': '0',
#      'top': [{'item': '699 JOHN ST', 'count': '37'},
#       {'item': '819 VIRGINIA ST', 'count': '35'},
#       {'item': '820 BLANCHARD ST', 'count': '33'},
#       {'item': '1420 TERRY AVE', 'count': '32'},
#       {'item': '4540 8TH AVE NE', 'count': '32'},
#       {'item': '201 GALER ST', 'count': '30'},
#       {'item': '1545 NW 57TH ST', 'count': '29'},
#       {'item': '300 N 130TH ST', 'count': '29'},
#       {'item': '2901 NE BLAKELEY ST', 'count': '28'},
#       {'item': '2801 1ST AVE', 'count': '28'},
#       {'item': '2033 2ND AVE', 'count': '25'},
#       {'item': '412 11TH AVE', 'count': '25'},
#       {'item': '1711 E OLIVE WAY', 'count': '25'},
#       {'item': '1400 HUBBELL PL', 'count': '25'},
#       {'item': '2600 2ND AVE', 'count': '24'},
#       {'item': '323 QUEEN ANNE AVE N', 'count': '23'},
#       {'item': '2415 2ND AVE', 'count': '23'},
#       {'item': '1414 12TH AVE', 'count': '23'},
#       {'item': '4547 8TH AVE NE', 'count': '21'},
#       {'item': '1631 16TH AVE', 'count': '21'}],
#      'not_null': '32642',
#      'smallest': '10000 37TH AVE SW',
#      'cardinality': '29221'},
#     'format': {'align': 'left'}},
#    {'id': 417383752,
#     'name': 'OriginalCity',
#     'dataTypeName': 'text',
#     'description': "The city for the property's address.",
#     'fieldName': 'originalcity',
#     'position': 10,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145314,
#     'width': 188,
#     'cachedContents': {'largest': 'SEATTLE',
#      'null': '532',
#      'top': [{'item': 'SEATTLE', 'count': '32030'},
#       {'item': 'Seattle', 'count': '69'},
#       {'item': 'seattle', 'count': '10'},
#       {'item': 'mill creek', 'count': '1'}],
#      'not_null': '32110',
#      'smallest': 'mill creek',
#      'cardinality': '4'},
#     'format': {'align': 'left'}},
#    {'id': 417383753,
#     'name': 'OriginalState',
#     'dataTypeName': 'text',
#     'description': "The state for the property's address.",
#     'fieldName': 'originalstate',
#     'position': 11,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145315,
#     'width': 172,
#     'cachedContents': {'largest': 'WA',
#      'null': '532',
#      'top': [{'item': 'WA', 'count': '32110'}],
#      'not_null': '32110',
#      'smallest': 'WA',
#      'cardinality': '1'},
#     'format': {'align': 'left'}},
#    {'id': 417383754,
#     'name': 'OriginalZip',
#     'dataTypeName': 'text',
#     'description': "The Zip code for the property's address.",
#     'fieldName': 'originalzip',
#     'position': 12,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145316,
#     'width': 232,
#     'cachedContents': {'largest': '98199',
#      'null': '682',
#      'top': [{'item': '98103', 'count': '3381'},
#       {'item': '98115', 'count': '2324'},
#       {'item': '98105', 'count': '2254'},
#       {'item': '98122', 'count': '1856'},
#       {'item': '98107', 'count': '1737'},
#       {'item': '98125', 'count': '1736'},
#       {'item': '98117', 'count': '1594'},
#       {'item': '98118', 'count': '1515'},
#       {'item': '98116', 'count': '1479'},
#       {'item': '98102', 'count': '1450'},
#       {'item': '98144', 'count': '1422'},
#       {'item': '98119', 'count': '1394'},
#       {'item': '98109', 'count': '1287'},
#       {'item': '98133', 'count': '1261'},
#       {'item': '98106', 'count': '1186'},
#       {'item': '98108', 'count': '951'},
#       {'item': '98199', 'count': '920'},
#       {'item': '98112', 'count': '884'},
#       {'item': '98126', 'count': '870'},
#       {'item': '98136', 'count': '707'}],
#      'not_null': '31960',
#      'smallest': '102',
#      'cardinality': '32'},
#     'format': {'align': 'left'}},
#    {'id': 417383755,
#     'name': 'PropertyContactName',
#     'dataTypeName': 'text',
#     'description': 'The contact name for the property management.',
#     'fieldName': 'propertycontactname',
#     'position': 13,
#     'renderTypeName': 'text',
#     'tableColumnId': 64145317,
#     'width': 247,
#     'cachedContents': {'largest': 'Zuocheng Ren',
#      'null': '3942',
#      'top': [{'item': 'Maple Leaf Property Management', 'count': '361'},
#       {'item': 'Avenue One Residential', 'count': '352'},
#       {'item': 'Urban Key', 'count': '168'},
#       {'item': 'Ballard Realty Property Management', 'count': '161'},
#       {'item': 'Dwellings', 'count': '157'},
#       {'item': 'CORNELL & ASSOCIATES, INC', 'count': '140'},
#       {'item': 'Real Property Associates', 'count': '137'},
#       {'item': 'David Drake', 'count': '122'},
#       {'item': 'Lydia Cheng', 'count': '110'},
#       {'item': 'Windermere Property Management', 'count': '108'},
#       {'item': 'Davis Property Management', 'count': '108'},
#       {'item': 'Redside Partners', 'count': '97'},
#       {'item': 'North Pacific Properties', 'count': '93'},
#       {'item': 'xxx xxx', 'count': '93'},
#       {'item': 'Apple Property Management', 'count': '89'},
#       {'item': 'Cornell and Associates', 'count': '86'},
#       {'item': 'Andrea Jacobi', 'count': '83'},
#       {'item': 'Prestige Rental Management', 'count': '79'},
#       {'item': 'Brink Property Management', 'count': '76'},
#       {'item': 'SJA Property Management', 'count': '71'}],
#      'not_null': '28700',
#      'smallest': "0People's Real Estate",
#      'cardinality': '17165'},
#     'format': {'align': 'left'}},
#    {'id': 417383756,
#     'name': 'Link',
#     'dataTypeName': 'url',
#     'description': "A link to view full details and current status information about this permit at SDCI's website.",
#     'fieldName': 'link',
#     'position': 14,
#     'renderTypeName': 'url',
#     'tableColumnId': 83049848,
#     'width': 148,
#     'format': {'align': 'left'},
#     'subColumnTypes': ['url', 'description']},
#    {'id': 417383757,
#     'name': 'Latitude',
#     'dataTypeName': 'number',
#     'description': "The latitude of the rental property's address.",
#     'fieldName': 'latitude',
#     'position': 15,
#     'renderTypeName': 'number',
#     'tableColumnId': 64145346,
#     'width': 112,
#     'cachedContents': {'largest': '47.73396596',
#      'null': '350',
#      'top': [{'item': '47.61610781', 'count': '44'},
#       {'item': '47.61811095', 'count': '42'},
#       {'item': '47.61933082', 'count': '38'},
#       {'item': '47.6628958', 'count': '38'},
#       {'item': '47.61672999', 'count': '35'},
#       {'item': '47.61263209', 'count': '35'},
#       {'item': '47.66983804', 'count': '35'},
#       {'item': '47.72400731', 'count': '32'},
#       {'item': '47.63198146', 'count': '32'},
#       {'item': '47.66582251', 'count': '30'},
#       {'item': '47.61208919', 'count': '30'},
#       {'item': '47.61631757', 'count': '29'},
#       {'item': '47.61221024', 'count': '29'},
#       {'item': '47.61944422', 'count': '29'},
#       {'item': '47.60573674', 'count': '26'},
#       {'item': '47.61481762', 'count': '26'},
#       {'item': '47.61343565', 'count': '25'},
#       {'item': '47.61634038', 'count': '24'},
#       {'item': '47.62181749', 'count': '24'},
#       {'item': '47.66268261', 'count': '23'}],
#      'not_null': '32292',
#      'smallest': '47.4822279',
#      'cardinality': '28392'},
#     'format': {'precisionStyle': 'standard', 'align': 'right'}},
#    {'id': 417383758,
#     'name': 'Longitude',
#     'dataTypeName': 'number',
#     'description': "The longitude of the rental property's address.",
#     'fieldName': 'longitude',
#     'position': 16,
#     'renderTypeName': 'number',
#     'tableColumnId': 64145347,
#     'width': 131,
#     'cachedContents': {'largest': '-122.22129376',
#      'null': '350',
#      'top': [{'item': '-122.3357782', 'count': '44'},
#       {'item': '-122.33909821', 'count': '42'},
#       {'item': '-122.34414473', 'count': '38'},
#       {'item': '-122.31883896', 'count': '38'},
#       {'item': '-122.3782764', 'count': '35'},
#       {'item': '-122.34338244', 'count': '35'},
#       {'item': '-122.32925834', 'count': '35'},
#       {'item': '-122.3549938', 'count': '32'},
#       {'item': '-122.35194662', 'count': '32'},
#       {'item': '-122.2970461', 'count': '30'},
#       {'item': '-122.3428896', 'count': '30'},
#       {'item': '-122.32977292', 'count': '29'},
#       {'item': '-122.35210063', 'count': '29'},
#       {'item': '-122.32319284', 'count': '29'},
#       {'item': '-122.31783239', 'count': '26'},
#       {'item': '-122.34777922', 'count': '26'},
#       {'item': '-122.31642934', 'count': '25'},
#       {'item': '-122.35702584', 'count': '24'},
#       {'item': '-122.3489514', 'count': '24'},
#       {'item': '-122.31986058', 'count': '23'}],
#      'not_null': '32292',
#      'smallest': '-122.42010337',
#      'cardinality': '28391'},
#     'format': {'precisionStyle': 'standard', 'align': 'right'}},
#    {'id': 417383759,
#     'name': 'Location1',
#     'dataTypeName': 'point',
#     'description': 'Mapping coordinates for the property address.',
#     'fieldName': 'location1',
#     'position': 17,
#     'renderTypeName': 'point',
#     'tableColumnId': 64145319,
#     'width': 221,
#     'cachedContents': {'null': '350',
#      'top': [{'item': {'coordinates': [-122.3357782, 47.61610781],
#         'type': 'Point'},
#        'count': '44'},
#       {'item': {'coordinates': [-122.33909821, 47.61811095], 'type': 'Point'},
#        'count': '42'},
#       {'item': {'coordinates': [-122.34414473, 47.61933082], 'type': 'Point'},
#        'count': '38'},
#       {'item': {'coordinates': [-122.31883896, 47.6628958], 'type': 'Point'},
#        'count': '38'},
#       {'item': {'coordinates': [-122.34338244, 47.61672999], 'type': 'Point'},
#        'count': '35'},
#       {'item': {'coordinates': [-122.3782764, 47.66983804], 'type': 'Point'},
#        'count': '35'},
#       {'item': {'coordinates': [-122.32925834, 47.61263209], 'type': 'Point'},
#        'count': '35'},
#       {'item': {'coordinates': [-122.3549938, 47.72400731], 'type': 'Point'},
#        'count': '32'},
#       {'item': {'coordinates': [-122.35194662, 47.63198146], 'type': 'Point'},
#        'count': '32'},
#       {'item': {'coordinates': [-122.2970461, 47.66582251], 'type': 'Point'},
#        'count': '30'},
#       {'item': {'coordinates': [-122.3428896, 47.61208919], 'type': 'Point'},
#        'count': '30'},
#       {'item': {'coordinates': [-122.35210063, 47.61631757], 'type': 'Point'},
#        'count': '29'},
#       {'item': {'coordinates': [-122.32977292, 47.61221024], 'type': 'Point'},
#        'count': '29'},
#       {'item': {'coordinates': [-122.32319284, 47.61944422], 'type': 'Point'},
#        'count': '29'},
#       {'item': {'coordinates': [-122.34777922, 47.61481762], 'type': 'Point'},
#        'count': '26'},
#       {'item': {'coordinates': [-122.31783239, 47.60573674], 'type': 'Point'},
#        'count': '26'},
#       {'item': {'coordinates': [-122.31642934, 47.61343565], 'type': 'Point'},
#        'count': '25'},
#       {'item': {'coordinates': [-122.35702584, 47.62181749], 'type': 'Point'},
#        'count': '24'},
#       {'item': {'coordinates': [-122.3489514, 47.61634038], 'type': 'Point'},
#        'count': '24'},
#       {'item': {'coordinates': [-122.31986058, 47.66268261], 'type': 'Point'},
#        'count': '23'}],
#      'not_null': '32292',
#      'cardinality': '28412'},
#     'format': {'align': 'left'}}],
#   'grants': [{'inherited': False, 'type': 'viewer', 'flags': ['public']}],
#   'license': {'name': 'Public Domain'},
#   'metadata': {'custom_fields': {'Department': {'Department': 'Seattle Department of Constructions and Inspections'},
#     'Refresh Frequency': {'Frequency': 'Daily'}},
#    'availableDisplayTypes': ['table', 'fatrow', 'page'],
#    'renderTypeConfig': {'visible': {'table': True}}},
#   'owner': {'id': '5wys-t5s3',
#    'displayName': 'Seattle SDCI',
#    'screenName': 'Seattle SDCI',
#    'type': 'interactive'},
#   'query': {},
#   'rights': ['read'],
#   'tableAuthor': {'id': '5wys-t5s3',
#    'displayName': 'Seattle SDCI',
#    'screenName': 'Seattle SDCI',
#    'type': 'interactive'},
#   'tags': ['rental housing standards'],
#   'flags': ['default', 'restorable', 'restorePossibleForType']}}

# %%
#a look into the data key
#seattleprops['data']
# Out:
# [['row-d3wj~gyzj~in8j',
#   '00000000-0000-0000-42B9-E7CFDE00AA06',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0127963',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-11-04',
#   '2021-11-04',
#   'Active Registration',
#   '8840 37TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98126',
#   'Pug Properties 37 LLC',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0127963',
#    None],
#   '47.52346484',
#   '-122.37911657',
#   'POINT (-122.37911657 47.52346484)'],
#  ['row-z979~4by4-4mea',
#   '00000000-0000-0000-889A-F32025A6AA6E',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0130697',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-01-31',
#   '2022-01-31',
#   'Active Registration',
#   '8621 Renton AVE S',
#   'SEATTLE',
#   'WA',
#   '98118',
#   'Charles Lane',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0130697',
#    None],
#   '47.52546474',
#   '-122.27709864',
#   'POINT (-122.27709864 47.52546474)'],
#  ['row-j6mu~x9ub~qnzx',
#   '00000000-0000-0000-2128-6E6275BF794C',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0124603',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-12-08',
#   '2021-12-08',
#   'Active Registration',
#   '7312 26TH AVE NW',
#   'SEATTLE',
#   'WA',
#   '98117',
#   'Michael Thompson',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0124603',
#    None],
#   '47.68175236',
#   '-122.38952921',
#   'POINT (-122.38952921 47.68175236)'],
#  ['row-636u~wgj2-qzif',
#   '00000000-0000-0000-3EA6-96060D7A0842',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0117660',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-03-06',
#   '2021-03-06',
#   'Active Registration',
#   '14020 23RD PL NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'Dmitry Feldman',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117660',
#    None],
#   '47.73040916',
#   '-122.30377651',
#   'POINT (-122.30377651 47.73040916)'],
#  ['row-xyxw.7tns-yx62',
#   '00000000-0000-0000-5860-B8346169B2F2',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0132924',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-12-04',
#   '2022-12-04',
#   'Active Registration',
#   '10508 C WHITMAN AVE N',
#   'SEATTLE',
#   'WA',
#   '98133',
#   'PROTOCOL PROPERTY MANAGEMENT',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132924',
#    None],
#   '47.70539597',
#   '-122.34552979',
#   'POINT (-122.34552979 47.70539597)'],
#  ['row-rhmx~5b7w_tnqq',
#   '00000000-0000-0000-C45B-3BFB60F8CC22',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0103770',
#   'Rental Property',
#   'Registration',
#   '8',
#   'Bon A Ville Apartments',
#   '2015-02-14',
#   '2020-02-14',
#   'Active Registration',
#   '11249 GREENWOOD AVE N',
#   'SEATTLE',
#   'WA',
#   '98133',
#   'Colin Mansfield',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0103770',
#    None],
#   '47.71202852',
#   '-122.3558762',
#   'POINT (-122.3558762 47.71202852)'],
#  ['row-p5jh~y6n5_es56',
#   '00000000-0000-0000-462A-71CA3B09FE77',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0105904',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-05-19',
#   '2020-05-19',
#   'Active Registration',
#   '5217 25TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98106',
#   'James Emory Tungsvik',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105904',
#    None],
#   '47.5544197',
#   '-122.36461672',
#   'POINT (-122.36461672 47.5544197)'],
#  ['row-kdxa~tj7k.tzn4',
#   '00000000-0000-0000-B338-04C7C60D3DE0',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0110349',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-09-08',
#   '2020-09-08',
#   'Active Registration',
#   '4140 48TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98116',
#   'Bih-shiung & /Fu-chih Chen',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0110349',
#    None],
#   '47.56538795',
#   '-122.3931783',
#   'POINT (-122.3931783 47.56538795)'],
#  ['row-4n8z-dais~vjtj',
#   '00000000-0000-0000-34AD-C9386E0D7797',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0131850',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2017-06-22',
#   '2022-06-22',
#   'Active Registration',
#   '1115 E FIR ST',
#   'SEATTLE',
#   'WA',
#   '98122',
#   'Phil Boos',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0131850',
#    None],
#   '47.60252227',
#   '-122.31739755',
#   'POINT (-122.31739755 47.60252227)'],
#  ['row-x9a8.nbut-keap',
#   '00000000-0000-0000-E44B-A86BB927FFA9',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0108616',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-07-05',
#   '2020-07-05',
#   'Active Registration',
#   '4510 SW AUSTIN ST',
#   'SEATTLE',
#   'WA',
#   '98136',
#   'Dwellings',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0108616',
#    None],
#   '47.53532018',
#   '-122.39100656',
#   'POINT (-122.39100656 47.53532018)'],
#  ['row-6fci_jpb8-sanq',
#   '00000000-0000-0000-47A4-6B29A34D508E',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0112981',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-11-13',
#   '2020-11-13',
#   'Active Registration',
#   '4126 BAKER AVE NW',
#   'SEATTLE',
#   'WA',
#   '98107',
#   'Norman Crouter',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0112981',
#    None],
#   '47.65723681',
#   '-122.35915687',
#   'POINT (-122.35915687 47.65723681)'],
#  ['row-evdx-ys5n.g4we',
#   '00000000-0000-0000-F7FD-D95AAA7152A0',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0116960',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-02-12',
#   '2021-02-12',
#   'Active Registration',
#   '11527 16TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'Hancock Properties LLC',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116960',
#    None],
#   '47.71295379',
#   '-122.31149478',
#   'POINT (-122.31149478 47.71295379)'],
#  ['row-82t2~yh6t_7p95',
#   '00000000-0000-0000-FA07-B3201300ABAE',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0118382',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-03-22',
#   '2021-03-22',
#   'Active Registration',
#   '2122 S BRANDON ST',
#   'SEATTLE',
#   'WA',
#   '98108',
#   'Rhen Cai',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0118382',
#    None],
#   '47.55429961',
#   '-122.3052001',
#   'POINT (-122.3052001 47.55429961)'],
#  ['row-r2qe.e4r2_pe6j',
#   '00000000-0000-0000-A5E2-193C75E256C3',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0105712',
#   'Rental Property',
#   'Registration',
#   '6',
#   'Horton St Apartments',
#   '2015-05-11',
#   '2020-05-11',
#   'Active Registration',
#   '1755 S HORTON ST',
#   'SEATTLE',
#   'WA',
#   '98144',
#   'Dan Chhan',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105712',
#    None],
#   '47.57392877',
#   '-122.30850352',
#   'POINT (-122.30850352 47.57392877)'],
#  ['row-hyye_aee6.p4h8',
#   '00000000-0000-0000-A4CB-8E2625B0F5E9',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0112893',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-11-06',
#   '2020-11-06',
#   'Active Registration',
#   '5219 48TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98136',
#   'Walter Sive',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0112893',
#    None],
#   '47.55509815',
#   '-122.39395599',
#   'POINT (-122.39395599 47.55509815)'],
#  ['row-c7as.rbbs-cgxt',
#   '00000000-0000-0000-898C-0B1ED4E9DDC9',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0109212',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Sunset View',
#   '2015-08-04',
#   '2020-08-04',
#   'Active Registration',
#   '2316 44TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98116',
#   'Andrew Numa',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0109212',
#    None],
#   '47.58243025',
#   '-122.38744995',
#   'POINT (-122.38744995 47.58243025)'],
#  ['row-67hr~f8d9.y3ke',
#   '00000000-0000-0000-AC8C-5B5F7822B521',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0125458',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Wolf House',
#   '2016-09-04',
#   '2021-09-04',
#   'Active Registration',
#   '5115 S PEARL ST',
#   'SEATTLE',
#   'WA',
#   '98118',
#   'Avenue One Residential',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0125458',
#    None],
#   '47.55609255',
#   '-122.26914558',
#   'POINT (-122.26914558 47.55609255)'],
#  ['row-d56q~amuq-qcq8',
#   '00000000-0000-0000-5745-ECB296DB8A55',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0118323',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-03-18',
#   '2021-03-18',
#   'Active Registration',
#   '13003 30TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'Raymond Hammer',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0118323',
#    None],
#   '47.72307037',
#   '-122.29670158',
#   'POINT (-122.29670158 47.72307037)'],
#  ['row-3up9-iff5-9w3m',
#   '00000000-0000-0000-B454-2418C79C23F1',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0134281',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Ambassador II',
#   '2018-07-16',
#   '2023-07-16',
#   'Active Registration',
#   '506 E HOWELL ST',
#   'SEATTLE',
#   'WA',
#   '98122',
#   'David Weber',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0134281',
#    None],
#   '47.61803326',
#   '-122.32483046',
#   'POINT (-122.32483046 47.61803326)'],
#  ['row-a86e-3adi_zrqv',
#   '00000000-0000-0000-59D5-14005E1F0FDA',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0111612',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2015-09-28',
#   '2020-09-28',
#   'Active Registration',
#   '12036 NORTH PARK AVE N',
#   'SEATTLE',
#   'WA',
#   '98133',
#   'Three Keys Property Management',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0111612',
#    None],
#   '47.71704512',
#   '-122.34924487',
#   'POINT (-122.34924487 47.71704512)'],
#  ['row-tbae.hhef.98zt',
#   '00000000-0000-0000-E357-7BF00DE173C4',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0119990',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-04-21',
#   '2021-04-21',
#   'Active Registration',
#   '2202 NE 83RD ST',
#   'SEATTLE',
#   'WA',
#   '98115',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0119990',
#    None],
#   '47.69005192',
#   '-122.30417858',
#   'POINT (-122.30417858 47.69005192)'],
#  ['row-rhuz-vtxq.hnfj',
#   '00000000-0000-0000-35AB-914457392AB5',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0117892',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-03-09',
#   '2021-03-09',
#   'Active Registration',
#   '12060 LAKESIDE AVE NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'Steve Badanes',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117892',
#    None],
#   '47.7170861',
#   '-122.28099997',
#   'POINT (-122.28099997 47.7170861)'],
#  ['row-6ih9_mvag_d6hf',
#   '00000000-0000-0000-FB95-FF79EF9127C1',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0123717',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-10-07',
#   '2021-10-07',
#   'Active Registration',
#   '2127 A WAVERLY PL N',
#   'SEATTLE',
#   'WA',
#   '98109',
#   'Edwin Noble',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0123717',
#    None],
#   '47.63848861',
#   '-122.3432375',
#   'POINT (-122.3432375 47.63848861)'],
#  ['row-t6wx~7fk6.2rwk',
#   '00000000-0000-0000-4111-4C8172C889F2',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0117227',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-02-24',
#   '2021-02-24',
#   'Active Registration',
#   '11519 16TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'Brian Hancock',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117227',
#    None],
#   '47.71282037',
#   '-122.31150058',
#   'POINT (-122.31150058 47.71282037)'],
#  ['row-jgt6-gptf~9ie3',
#   '00000000-0000-0000-F7A8-52811D53DF7D',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0125508',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Aspen The Condominium',
#   '2016-09-05',
#   '2021-09-05',
#   'Active Registration',
#   '2117 #103 N 107TH ST',
#   'SEATTLE',
#   'WA',
#   '98133',
#   'Ko-Sun Yu',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0125508',
#    None],
#   '47.70665875',
#   '-122.33308346',
#   'POINT (-122.33308346 47.70665875)'],
#  ['row-nhjh-vsg8~mj3i',
#   '00000000-0000-0000-31B8-A91FBDFA60CD',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0105873',
#   'Rental Property',
#   'Registration',
#   '4',
#   '13th',
#   '2015-05-18',
#   '2020-05-18',
#   'Active Registration',
#   '3624 13TH AVE W',
#   'SEATTLE',
#   'WA',
#   '98119',
#   'Walls Property Management',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105873',
#    None],
#   '47.65301513',
#   '-122.37327088',
#   'POINT (-122.37327088 47.65301513)'],
#  ['row-gecr-sz32-8v5z',
#   '00000000-0000-0000-F369-B8F2793F5DDA',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0114377',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-12-13',
#   '2020-12-13',
#   'Active Registration',
#   '3901 1ST AVE NW',
#   'SEATTLE',
#   'WA',
#   '98107',
#   'Kirsten Montoya',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0114377',
#    None],
#   '47.65436158',
#   '-122.357409',
#   'POINT (-122.357409 47.65436158)'],
#  ['row-rwf2.xbsr~nxjm',
#   '00000000-0000-0000-857F-05C7B1EAEAC8',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0116216',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-01-15',
#   '2021-01-15',
#   'Active Registration',
#   '4740 48TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98116',
#   'Nori Suguro',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116216',
#    None],
#   '47.55989026',
#   '-122.39309149',
#   'POINT (-122.39309149 47.55989026)'],
#  ['row-u4ne.a658~8ymr',
#   '00000000-0000-0000-3401-EF8997E5C649',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0113235',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-11-15',
#   '2020-11-15',
#   'Active Registration',
#   '5258 SW CHARLESTOWN ST',
#   'SEATTLE',
#   'WA',
#   '98116',
#   'Lari Garrison',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0113235',
#    None],
#   '47.57054577',
#   '-122.3999979',
#   'POINT (-122.3999979 47.57054577)'],
#  ['row-rkd4-y86u_d2y9',
#   '00000000-0000-0000-D668-549E63277EE3',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0103563',
#   'Rental Property',
#   'Registration',
#   '26',
#   'Brettler Family Place 1',
#   '2015-01-09',
#   '2020-01-09',
#   'Active Registration',
#   '6870 62ND AVE NE',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'Brian Edwards',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0103563',
#    None],
#   '47.67858019',
#   '-122.26173043',
#   'POINT (-122.26173043 47.67858019)'],
#  ['row-ibze-icbe-npz7',
#   '00000000-0000-0000-0D07-88DB8C4E5D68',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0100113',
#   'Rental Property',
#   'Registration',
#   '45',
#   'Bridgeview',
#   '2014-09-30',
#   '2019-09-30',
#   'Active Registration',
#   '708 N 35TH ST',
#   'SEATTLE',
#   'WA',
#   '98103',
#   'CORNELL & ASSOCIATES, INC',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0100113',
#    None],
#   '47.65061424',
#   '-122.34946964',
#   'POINT (-122.34946964 47.65061424)'],
#  ['row-rhym-uab9~xpha',
#   '00000000-0000-0000-3065-CF9D93287444',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0129847',
#   'Rental Property',
#   'Registration',
#   '3',
#   None,
#   '2017-01-02',
#   '2022-01-02',
#   'Active Registration',
#   '1032 NE 68TH ST',
#   'SEATTLE',
#   'WA',
#   '98115',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129847',
#    None],
#   '47.67820276',
#   '-122.31597077',
#   'POINT (-122.31597077 47.67820276)'],
#  ['row-4t9i~xyq2_8vix',
#   '00000000-0000-0000-9E70-61A4008EFAF6',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0132270',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Ballard Place',
#   '2017-08-23',
#   '2022-08-23',
#   'Active Registration',
#   '1545 NW 57TH ST',
#   'SEATTLE',
#   'WA',
#   '98107',
#   'Brooke Loughrin',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132270',
#    None],
#   '47.66983804',
#   '-122.3782764',
#   'POINT (-122.3782764 47.66983804)'],
#  ['row-bdrh_jc2d.x32n',
#   '00000000-0000-0000-9216-D3150D3615FA',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0132681',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-10-26',
#   '2022-10-26',
#   'Active Registration',
#   '3805 M L KING JR WAY S',
#   'SEATTLE',
#   'WA',
#   '98144',
#   'Jacob Chen',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132681',
#    None],
#   '47.56993804',
#   '-122.29724876',
#   'POINT (-122.29724876 47.56993804)'],
#  ['row-vz6r.brnn-5j5t',
#   '00000000-0000-0000-282C-AA1D37653F3E',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0129331',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-12-23',
#   '2021-12-23',
#   'Active Registration',
#   '519 NE 83RD ST',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'Acer NW, Inc',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129331',
#    None],
#   '47.68876673',
#   '-122.32213945',
#   'POINT (-122.32213945 47.68876673)'],
#  ['row-4wcr~wbu5_v3fd',
#   '00000000-0000-0000-A443-F38B60C5C014',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0108195',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-07-15',
#   '2020-07-15',
#   'Active Registration',
#   '8837 29TH AVE NW',
#   'SEATTLE',
#   'WA',
#   '98117',
#   'GREG PAYNE',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0108195',
#    None],
#   '47.69401891',
#   '-122.39416579',
#   'POINT (-122.39416579 47.69401891)'],
#  ['row-bz2t-7amh~i7tc',
#   '00000000-0000-0000-B942-AB7435482D05',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0121047',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-05-26',
#   '2021-05-26',
#   'Active Registration',
#   '736 N 72ND ST',
#   'SEATTLE',
#   'WA',
#   '98103',
#   "MacPherson's Property Management",
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0121047',
#    None],
#   '47.68125936',
#   '-122.34828591',
#   'POINT (-122.34828591 47.68125936)'],
#  ['row-izir.qi5d~pqus',
#   '00000000-0000-0000-FF8D-491A2DC35C33',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0117085',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-02-17',
#   '2021-02-17',
#   'Active Registration',
#   '11501 B 26TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'oanh hoang',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117085',
#    None],
#   '47.71222698',
#   '-122.3005834',
#   'POINT (-122.3005834 47.71222698)'],
#  ['row-54dz-ieaw-mdzz',
#   '00000000-0000-0000-6698-7BBE522F768F',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0133804',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2018-04-30',
#   '2023-04-30',
#   'Active Registration',
#   '616 14TH AVE E',
#   'SEATTLE',
#   'WA',
#   '98112',
#   'David Drake',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0133804',
#    None],
#   '47.62482576',
#   '-122.31436897',
#   'POINT (-122.31436897 47.62482576)'],
#  ['row-u3ez_cu98_sz9x',
#   '00000000-0000-0000-53C7-6FEF584D8736',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0101971',
#   'Rental Property',
#   'Registration',
#   '38',
#   'Carribean House Apartments',
#   '2014-09-29',
#   '2019-09-29',
#   'Active Registration',
#   '10800 ROOSEVELT WAY NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'Bob Dinehart',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0101971',
#    None],
#   '47.70801984',
#   '-122.31751673',
#   'POINT (-122.31751673 47.70801984)'],
#  ['row-6g5i.n2c5_x85a',
#   '00000000-0000-0000-9C98-973417753BA8',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0132540',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-10-06',
#   '2022-10-06',
#   'Active Registration',
#   '1153 82nd',
#   'SEATTLE',
#   'WA',
#   '98103',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132540',
#    None],
#   '47.68823033',
#   '-122.34215974',
#   'POINT (-122.34215974 47.68823033)'],
#  ['row-nec4_e9iw_9i2m',
#   '00000000-0000-0000-60C4-957730D87C6E',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0136272',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Charles St',
#   '2019-05-30',
#   '2021-05-30',
#   'Active Registration',
#   '2011 S CHARLES ST',
#   'SEATTLE',
#   'WA',
#   '98144',
#   "Ryan O'Connor",
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0136272',
#    None],
#   '47.59424611',
#   '-122.3056695',
#   'POINT (-122.3056695 47.59424611)'],
#  ['row-9xrb.cup5_vfqp',
#   '00000000-0000-0000-80A5-2B75777D646B',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0108919',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-07-13',
#   '2020-07-13',
#   'Active Registration',
#   '8456 20TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98106',
#   'Michele Rozinek',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0108919',
#    None],
#   '47.52664629',
#   '-122.35885813',
#   'POINT (-122.35885813 47.52664629)'],
#  ['row-kkv6~2y9a-ymyc',
#   '00000000-0000-0000-4AEE-0A9EC5DE74F4',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0116534',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-02-03',
#   '2021-02-03',
#   'Active Registration',
#   '1026 NE 117TH ST',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'Ruth Patterson',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116534',
#    None],
#   '47.71424797',
#   '-122.3171297',
#   'POINT (-122.3171297 47.71424797)'],
#  ['row-fiya-yfhm~anbc',
#   '00000000-0000-0000-D078-4C3A2F3A75E5',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0116332',
#   'Rental Property',
#   'Registration',
#   '13',
#   None,
#   '2016-01-27',
#   '2021-01-27',
#   'Active Registration',
#   '323 BELMONT AVE E',
#   'SEATTLE',
#   'WA',
#   '98102',
#   'Phalon Perry',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116332',
#    None],
#   '47.62149727',
#   '-122.32427049',
#   'POINT (-122.32427049 47.62149727)'],
#  ['row-tdnq-utjn_nep4',
#   '00000000-0000-0000-B5D3-D4365210E9F8',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0111820',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-09-29',
#   '2020-09-29',
#   'Active Registration',
#   '8029 26TH AVE NW',
#   'SEATTLE',
#   'WA',
#   '98117',
#   'Warren Rice',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0111820',
#    None],
#   '47.68770385',
#   '-122.39011491',
#   'POINT (-122.39011491 47.68770385)'],
#  ['row-9dpy_9bda_2cnu',
#   '00000000-0000-0000-ECB7-8409809A20AE',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0129812',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-12-31',
#   '2021-12-31',
#   'Active Registration',
#   '3250 NW ESPLANADE',
#   'SEATTLE',
#   'WA',
#   '98117',
#   'Angela Norby',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129812',
#    None],
#   '47.69823761',
#   '-122.39990558',
#   'POINT (-122.39990558 47.69823761)'],
#  ['row-jdnr.tir9-xk5m',
#   '00000000-0000-0000-DAD8-3D639AAEACCA',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0124529',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-08-10',
#   '2021-08-10',
#   'Active Registration',
#   '8700 B MARY AVE NW',
#   'SEATTLE',
#   'WA',
#   '98117',
#   'MELEAH GIBSON',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0124529',
#    None],
#   '47.69253241',
#   '-122.37504251',
#   'POINT (-122.37504251 47.69253241)'],
#  ['row-qmf2-saz6~r9mr',
#   '00000000-0000-0000-D371-12B9DCE5B3A8',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0135156',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2018-12-06',
#   '2023-12-06',
#   'Active Registration',
#   '2561 S MYRTLE ST',
#   'SEATTLE',
#   'WA',
#   '98108',
#   'Timur Ernoff',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0135156',
#    None],
#   '47.53882208',
#   '-122.29889249',
#   'POINT (-122.29889249 47.53882208)'],
#  ['row-e7za.zpsb-etxx',
#   '00000000-0000-0000-3423-9AFAEF33DFB8',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0116434',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-01-27',
#   '2021-01-27',
#   'Active Registration',
#   '1763 NW 57TH ST',
#   'SEATTLE',
#   'WA',
#   '98107',
#   'Geir Jonsson',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116434',
#    None],
#   '47.67000392',
#   '-122.3816191',
#   'POINT (-122.3816191 47.67000392)'],
#  ['row-6wiq~zr4k-8t5r',
#   '00000000-0000-0000-0520-CE8562A015F9',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0120200',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-05-05',
#   '2021-05-05',
#   'Active Registration',
#   '322 23RD AVE E',
#   'SEATTLE',
#   'WA',
#   '98112',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0120200',
#    None],
#   '47.62208444',
#   '-122.30225063',
#   'POINT (-122.30225063 47.62208444)'],
#  ['row-ev6x_pzhi.v36y',
#   '00000000-0000-0000-6A0A-809F145E8E24',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0131669',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-09-25',
#   '2022-09-25',
#   'Active Registration',
#   '583 BATTERY ST',
#   'SEATTLE',
#   'WA',
#   '98121',
#   'Joe Horgan',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0131669',
#    None],
#   '47.61672999',
#   '-122.34338244',
#   'POINT (-122.34338244 47.61672999)'],
#  ['row-8age_294u_vbcd',
#   '00000000-0000-0000-746A-A2C8102C7CD5',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0133760',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Kim 22nd Street',
#   '2018-04-21',
#   '2023-04-21',
#   'Active Registration',
#   '3429 B 22ND AVE W',
#   'SEATTLE',
#   'WA',
#   '98199',
#   'xxx xxx',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0133760',
#    None],
#   '47.65119612',
#   '-122.38527096',
#   'POINT (-122.38527096 47.65119612)'],
#  ['row-eb9g~nzbe-4uzm',
#   '00000000-0000-0000-D1F5-1E5ECCABC233',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0125804',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-09-10',
#   '2021-09-10',
#   'Active Registration',
#   '9031 32ND AVE SW',
#   'SEATTLE',
#   'WA',
#   '98126',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0125804',
#    None],
#   '47.52188844',
#   '-122.37432938',
#   'POINT (-122.37432938 47.52188844)'],
#  ['row-98qt.t4hs-e22d',
#   '00000000-0000-0000-82FF-907ABD0D40C1',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0108381',
#   'Rental Property',
#   'Registration',
#   '7',
#   None,
#   '2015-06-30',
#   '2020-06-30',
#   'Active Registration',
#   '4211 12TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98105',
#   'Craig Mueller',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0108381',
#    None],
#   '47.65870768',
#   '-122.31582207',
#   'POINT (-122.31582207 47.65870768)'],
#  ['row-b8qm-cjjp.97jy',
#   '00000000-0000-0000-2158-55833BC70892',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0100801',
#   'Rental Property',
#   'Registration',
#   '72',
#   'Carolina Court Apartments',
#   '2014-09-09',
#   '2019-09-09',
#   'Active Registration',
#   '527 EASTLAKE AVE E',
#   'SEATTLE',
#   'WA',
#   '98109',
#   'Epic Asset Management',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0100801',
#    None],
#   '47.62402666',
#   '-122.32973849',
#   'POINT (-122.32973849 47.62402666)'],
#  ['row-ucib.8qd3-mk3r',
#   '00000000-0000-0000-131B-454A7DA31984',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0101844',
#   'Rental Property',
#   'Registration',
#   '18',
#   'Wallingford Ave',
#   '2014-10-07',
#   '2019-10-07',
#   'Active Registration',
#   '3426 WALLINGFORD AVE N',
#   'SEATTLE',
#   'WA',
#   '98103',
#   'CORNELL & ASSOCIATES, INC',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0101844',
#    None],
#   '47.64884913',
#   '-122.33601144',
#   'POINT (-122.33601144 47.64884913)'],
#  ['row-j9z9~kupg-ekh4',
#   '00000000-0000-0000-6D8E-34E91266EECA',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0114605',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-01-14',
#   '2021-01-14',
#   'Active Registration',
#   '1407 TAYLOR AVE N',
#   'SEATTLE',
#   'WA',
#   '98109',
#   'John Yeung',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0114605',
#    None],
#   '47.63165592',
#   '-122.34662004',
#   'POINT (-122.34662004 47.63165592)'],
#  ['row-qsu6-c6eh~3iby',
#   '00000000-0000-0000-385E-66ED4B1248C0',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0127151',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2016-10-06',
#   '2021-10-06',
#   'Active Registration',
#   '8322 LOYAL WAY NW',
#   'SEATTLE',
#   'WA',
#   '98117',
#   'Nick Stefonick',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0127151',
#    None],
#   '47.6890971',
#   '-122.39651045',
#   'POINT (-122.39651045 47.6890971)'],
#  ['row-pamd-zwq2-rcyt',
#   '00000000-0000-0000-4703-55F170AD28B3',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0114021',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-12-09',
#   '2020-12-09',
#   'Active Registration',
#   '306 HALLADAY ST',
#   'SEATTLE',
#   'WA',
#   '98109',
#   'Ruth Hohlbein',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0114021',
#    None],
#   '47.64225253',
#   '-122.35143454',
#   'POINT (-122.35143454 47.64225253)'],
#  ['row-u4zj~qaf7~2urx',
#   '00000000-0000-0000-AB18-6E7D7A379592',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0114903',
#   'Rental Property',
#   'Registration',
#   '4',
#   None,
#   '2015-12-21',
#   '2020-12-21',
#   'Active Registration',
#   '3601 COURTLAND PL S',
#   'SEATTLE',
#   'WA',
#   '98144',
#   'Huy Dang',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0114903',
#    None],
#   '47.57146764',
#   '-122.28736166',
#   'POINT (-122.28736166 47.57146764)'],
#  ['row-8zjf.idc6.g5b5',
#   '00000000-0000-0000-B894-173FFE47FE9A',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0131362',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-04-11',
#   '2022-04-11',
#   'Active Registration',
#   '2745 NE 96TH ST',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'Stephen Newman',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0131362',
#    None],
#   '47.69822328',
#   '-122.29678679',
#   'POINT (-122.29678679 47.69822328)'],
#  ['row-zqsw~v5qc-8d67',
#   '00000000-0000-0000-9D7E-F168C7E866ED',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0133982',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Bagley Lofts',
#   '2018-05-27',
#   '2023-05-27',
#   'Active Registration',
#   '4422 BAGLEY AVE N',
#   'SEATTLE',
#   'WA',
#   '98103',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0133982',
#    None],
#   '47.66112355',
#   '-122.3320854',
#   'POINT (-122.3320854 47.66112355)'],
#  ['row-8zdk~jn5p.i2a5',
#   '00000000-0000-0000-594E-4628093C2A73',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0106859',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-06-23',
#   '2020-06-23',
#   'Active Registration',
#   '4218 B 7TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98105',
#   'Windermere Property Management',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0106859',
#    None],
#   '47.65807315',
#   '-122.32060026',
#   'POINT (-122.32060026 47.65807315)'],
#  ['row-6m4t-hn7w.k26g',
#   '00000000-0000-0000-2784-B0D0DE2C8103',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0104714',
#   'Rental Property',
#   'Registration',
#   '12',
#   'Casa Anita',
#   '2015-03-25',
#   '2020-03-25',
#   'Active Registration',
#   '2220 EASTLAKE AVE E',
#   'SEATTLE',
#   'WA',
#   '98102',
#   'North Pacific Properties',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0104714',
#    None],
#   '47.63880499',
#   '-122.32559218',
#   'POINT (-122.32559218 47.63880499)'],
#  ['row-p5k4~zjuj~gbeh',
#   '00000000-0000-0000-2942-AE03F739944D',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0128169',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-11-16',
#   '2021-11-16',
#   'Active Registration',
#   '7316 15TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'Gordon Schryer',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0128169',
#    None],
#   '47.68173934',
#   '-122.31140861',
#   'POINT (-122.31140861 47.68173934)'],
#  ['row-wd6s-z2gw-e3v5',
#   '00000000-0000-0000-6522-21012E9D6E0F',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0123676',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-07-05',
#   '2021-07-05',
#   'Active Registration',
#   '8407 36TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98126',
#   'Susan Davidson',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0123676',
#    None],
#   '47.52803555',
#   '-122.3786311',
#   'POINT (-122.3786311 47.52803555)'],
#  ['row-9c6j-fbi6_7kqa',
#   '00000000-0000-0000-CA99-4081D3E1D8F3',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0125313',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2016-08-30',
#   '2021-08-30',
#   'Active Registration',
#   '8602 10TH AVE S',
#   'SEATTLE',
#   'WA',
#   '98108',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0125313',
#    None],
#   '47.52622605',
#   '-122.32001968',
#   'POINT (-122.32001968 47.52622605)'],
#  ['row-tcdi_ntfb-rnbu',
#   '00000000-0000-0000-0D66-69C406F40EAE',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0126501',
#   'Rental Property',
#   'Registration',
#   '3',
#   None,
#   '2016-09-29',
#   '2021-09-29',
#   'Active Registration',
#   '1207 NW 85TH ST',
#   'SEATTLE',
#   'WA',
#   '98117',
#   'Doreen Duggan',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0126501',
#    None],
#   '47.69043421',
#   '-122.37183294',
#   'POINT (-122.37183294 47.69043421)'],
#  ['row-hceh_76n3_94r7',
#   '00000000-0000-0000-0B3A-ED54EF8943DB',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0129975',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-01-04',
#   '2022-01-04',
#   'Active Registration',
#   '6808 26TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'Gerald Finafrock',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129975',
#    None],
#   '47.67790589',
#   '-122.29927843',
#   'POINT (-122.29927843 47.67790589)'],
#  ['row-52mv.ud68.g3ys',
#   '00000000-0000-0000-7880-C09D5A44E580',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0109905',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-08-25',
#   '2020-08-25',
#   'Active Registration',
#   '10001 13TH AVE NW',
#   'SEATTLE',
#   'WA',
#   '98177',
#   'John E & Janet S Welch Trust',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0109905',
#    None],
#   '47.70169911',
#   '-122.3730896',
#   'POINT (-122.3730896 47.70169911)'],
#  ['row-3yni.nfuu_rz69',
#   '00000000-0000-0000-DF76-D7003A445F5A',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0116063',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2016-01-22',
#   '2021-01-22',
#   'Active Registration',
#   '2207 NW 61ST ST',
#   'SEATTLE',
#   'WA',
#   '98107',
#   'Nick Stefonick',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116063',
#    None],
#   '47.6729209',
#   '-122.38519302',
#   'POINT (-122.38519302 47.6729209)'],
#  ['row-wmz3~ezfr~f7yr',
#   '00000000-0000-0000-E11C-4D04DD874B8F',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0102350',
#   'Rental Property',
#   'Registration',
#   '351',
#   'The Station At Othello Park',
#   '2014-09-30',
#   '2019-09-30',
#   'Active Registration',
#   '4219 S OTHELLO ST',
#   'SEATTLE',
#   'WA',
#   '98118',
#   'Station At Othello, LLC',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0102350',
#    None],
#   '47.53692011',
#   '-122.27985292',
#   'POINT (-122.27985292 47.53692011)'],
#  ['row-zeua.57i2.pyf3',
#   '00000000-0000-0000-EECC-0C3DE962912B',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0120238',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-05-05',
#   '2021-05-05',
#   'Active Registration',
#   '1011 D N 50TH ST',
#   'SEATTLE',
#   'WA',
#   '98103',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0120238',
#    None],
#   '47.66472841',
#   '-122.34540582',
#   'POINT (-122.34540582 47.66472841)'],
#  ['row-2tzz.t9qy.siba',
#   '00000000-0000-0000-64CF-3542D434EE80',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0133421',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2018-02-27',
#   '2023-02-27',
#   'Active Registration',
#   '9628 8TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'Maple Leaf Property Management',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0133421',
#    None],
#   '47.69935712',
#   '-122.32010391',
#   'POINT (-122.32010391 47.69935712)'],
#  ['row-5icf~ap46~6jx2',
#   '00000000-0000-0000-871E-4442E4988CA6',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0125747',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-10-24',
#   '2021-10-24',
#   'Active Registration',
#   '3211 S GRAHAM ST',
#   'SEATTLE',
#   'WA',
#   '98118',
#   'Jian Xiong Xue',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0125747',
#    None],
#   '47.54594088',
#   '-122.29107573',
#   'POINT (-122.29107573 47.54594088)'],
#  ['row-cbfk~st6d.wmzz',
#   '00000000-0000-0000-8080-F6F8DAFF6225',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0127184',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-11-14',
#   '2021-11-14',
#   'Active Registration',
#   '5217 57TH AVE S',
#   'SEATTLE',
#   'WA',
#   '98118',
#   'Eleanor Ryan',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0127184',
#    None],
#   '47.55430737',
#   '-122.26278222',
#   'POINT (-122.26278222 47.55430737)'],
#  ['row-996t_gvfc.mw6t',
#   '00000000-0000-0000-9B68-CF34F4A1DE42',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0106615',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Canal Place',
#   '2015-06-10',
#   '2020-06-10',
#   'Active Registration',
#   '965 W NICKERSON ST',
#   'SEATTLE',
#   'WA',
#   '98119',
#   'Sherry Taylor',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0106615',
#    None],
#   '47.65346757',
#   '-122.36988302',
#   'POINT (-122.36988302 47.65346757)'],
#  ['row-z9pb.pmm2-smya',
#   '00000000-0000-0000-7DD8-4CDE4F9D68F1',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0111468',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-09-25',
#   '2020-09-25',
#   'Active Registration',
#   '616 11TH AVE E',
#   'SEATTLE',
#   'WA',
#   '98102',
#   'Huey-Yi Sung',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0111468',
#    None],
#   '47.62478856',
#   '-122.31747949',
#   'POINT (-122.31747949 47.62478856)'],
#  ['row-74n8_4e3i.vxxg',
#   '00000000-0000-0000-29D3-7F7AA4B553D3',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0106967',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-07-10',
#   '2020-07-10',
#   'Active Registration',
#   '5010 8TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98105',
#   'Kathy Harmon',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0106967',
#    None],
#   '47.66534569',
#   '-122.31926902',
#   'POINT (-122.31926902 47.66534569)'],
#  ['row-stpx-ars8~2378',
#   '00000000-0000-0000-365D-BA7D1C16BE6C',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0100366',
#   'Rental Property',
#   'Registration',
#   '23',
#   None,
#   '2014-08-11',
#   '2019-08-11',
#   'Active Registration',
#   '11020 GREENWOOD AVE N',
#   'SEATTLE',
#   'WA',
#   '98133',
#   'Community House Mental Health Agency',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0100366',
#    None],
#   '47.70937781',
#   '-122.35498679',
#   'POINT (-122.35498679 47.70937781)'],
#  ['row-n2d8_ve6g_ifkz',
#   '00000000-0000-0000-383E-1F0DBDB30C68',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0118142',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-03-18',
#   '2021-03-18',
#   'Active Registration',
#   '10026 48TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'Jenna Weinstein',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0118142',
#    None],
#   '47.70195768',
#   '-122.27616872',
#   'POINT (-122.27616872 47.70195768)'],
#  ['row-xdtc_gkyv_7gsg',
#   '00000000-0000-0000-A988-AC02B4E4FBC0',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0111067',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2015-09-19',
#   '2020-09-19',
#   'Active Registration',
#   '14336 EVANSTON AVE N',
#   'SEATTLE',
#   'WA',
#   '98133',
#   'Xiaoxia Tan',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0111067',
#    None],
#   '47.73349226',
#   '-122.35126527',
#   'POINT (-122.35126527 47.73349226)'],
#  ['row-9c34-2tw7~f9vc',
#   '00000000-0000-0000-7262-122B28831FF8',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0129002',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Dicky Ong',
#   '2016-12-13',
#   '2021-12-13',
#   'Active Registration',
#   '6800 OSWEGO PL NE',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'Lydia Cheng',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129002',
#    None],
#   '47.67803382',
#   '-122.32236361',
#   'POINT (-122.32236361 47.67803382)'],
#  ['row-ryaz_vkn2.ey5q',
#   '00000000-0000-0000-C626-895089FC63C1',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0135948',
#   'Rental Property',
#   'Registration',
#   '1',
#   '9508 Rainier Ave S',
#   '2019-04-10',
#   '2021-04-10',
#   'Active Registration',
#   '9508 RAINIER AVE S',
#   'SEATTLE',
#   'WA',
#   '98118',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0135948',
#    None],
#   '47.52061055',
#   '-122.26095926',
#   'POINT (-122.26095926 47.52061055)'],
#  ['row-8j8e~hvuw-ckft',
#   '00000000-0000-0000-ABE1-749586695EEA',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0124847',
#   'Rental Property',
#   'Registration',
#   '1',
#   'B28',
#   '2016-08-17',
#   '2021-08-17',
#   'Active Registration',
#   '5002 49TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98136',
#   'Landlord Management Inc',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0124847',
#    None],
#   '47.55739972',
#   '-122.39470674',
#   'POINT (-122.39470674 47.55739972)'],
#  ['row-suqh.uhmy.mz72',
#   '00000000-0000-0000-43D5-8C07319B3FFC',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0107328',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-06-22',
#   '2020-06-22',
#   'Active Registration',
#   '5827 57TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98105',
#   'Steve Ulene',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0107328',
#    None],
#   '47.67112461',
#   '-122.26704893',
#   'POINT (-122.26704893 47.67112461)'],
#  ['row-vvre_6tmj_99yx',
#   '00000000-0000-0000-4AF1-A88A9C1DCD46',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0122418',
#   'Rental Property',
#   'Registration',
#   '3',
#   None,
#   '2016-06-22',
#   '2021-06-22',
#   'Active Registration',
#   '118 17TH AVE E',
#   'SEATTLE',
#   'WA',
#   '98112',
#   'Gerald Littlefield',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0122418',
#    None],
#   '47.61910494',
#   '-122.30985541',
#   'POINT (-122.30985541 47.61910494)'],
#  ['row-k752_aayu~xarr',
#   '00000000-0000-0000-4094-44C7D63EFE27',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0118391',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2016-04-07',
#   '2021-04-07',
#   'Active Registration',
#   '12310 33RD AVE NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'Ballard Realty Property Management',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0118391',
#    None],
#   '47.71779151',
#   '-122.29250921',
#   'POINT (-122.29250921 47.71779151)'],
#  ['row-stht-butr.jaqt',
#   '00000000-0000-0000-0547-8EF37D950E03',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0108726',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-07-08',
#   '2020-07-08',
#   'Active Registration',
#   '9438 23RD AVE SW',
#   'SEATTLE',
#   'WA',
#   '98106',
#   'Fred Olsen',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0108726',
#    None],
#   '47.51799371',
#   '-122.36233904',
#   'POINT (-122.36233904 47.51799371)'],
#  ['row-zsbj.7zuc_5bw6',
#   '00000000-0000-0000-54F2-FB5AEB839982',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0120692',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-05-14',
#   '2021-05-14',
#   'Active Registration',
#   '714 N 46TH ST',
#   'SEATTLE',
#   'WA',
#   '98103',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0120692',
#    None],
#   '47.66235005',
#   '-122.34939488',
#   'POINT (-122.34939488 47.66235005)'],
#  ['row-x7zi~n29c-g87d',
#   '00000000-0000-0000-6FB5-C0192E3304C0',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0118873',
#   'Rental Property',
#   'Registration',
#   '3',
#   None,
#   '2016-03-25',
#   '2021-03-25',
#   'Active Registration',
#   '1211 E OLIVE ST',
#   'SEATTLE',
#   'WA',
#   '98122',
#   'Kevin Harasimowicz',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0118873',
#    None],
#   '47.61628478',
#   '-122.31630585',
#   'POINT (-122.31630585 47.61628478)'],
#  ['row-y2h2_cvxs.wgie',
#   '00000000-0000-0000-0471-3DF41C1B032B',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0129890',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2017-01-03',
#   '2022-01-03',
#   'Active Registration',
#   '6524 1ST AVE NE',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'alan sato',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129890',
#    None],
#   '47.67667155',
#   '-122.32814303',
#   'POINT (-122.32814303 47.67667155)'],
#  ['row-5b5h-qbcx~fayd',
#   '00000000-0000-0000-C717-C44146F95F44',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0131349',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-04-09',
#   '2022-04-09',
#   'Active Registration',
#   '2828 B SW ADAMS ST',
#   'SEATTLE',
#   'WA',
#   '98126',
#   'Timothy Corrigan',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0131349',
#    None],
#   '47.56646027',
#   '-122.36948365',
#   'POINT (-122.36948365 47.56646027)'],
#  ['row-3vf4.5qck-bpuh',
#   '00000000-0000-0000-15D0-7C482E0B4359',
#   0,
#   1561394371,
#   None,
#   1561394394,
#   None,
#   '{ }',
#   '001-0116993',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Pike Lofts',
#   '2016-02-16',
#   '2021-02-16',
#   'Active Registration',
#   '303 E PIKE ST',
#   'SEATTLE',
#   'WA',
#   '98122',
#   'Kent Whitehead',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0116993',
#    None],
#   '47.61390837',
#   '-122.3272126',
#   'POINT (-122.3272126 47.61390837)'],
#  ['row-7au9~hvss_qe5v',
#   '00000000-0000-0000-B738-BD7A5C161714',
#   0,
# ...
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0111288',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-10-13',
#   '2020-10-13',
#   'Active Registration',
#   '11044 1ST AVE NW',
#   'SEATTLE',
#   'WA',
#   '98177',
#   'Michael Gemza',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0111288',
#    None],
#   '47.71005254',
#   '-122.35779841',
#   'POINT (-122.35779841 47.71005254)'],
#  ['row-bybu~45da~nkfg',
#   '00000000-0000-0000-316E-E05491609E39',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0102762',
#   'Rental Property',
#   'Registration',
#   '10',
#   None,
#   '2014-10-16',
#   '2019-10-16',
#   'Active Registration',
#   '2201 NW 62ND ST',
#   'SEATTLE',
#   'WA',
#   '98107',
#   'Kurt & Susan Nelson',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0102762',
#    None],
#   '47.67355064',
#   '-122.38502478',
#   'POINT (-122.38502478 47.67355064)'],
#  ['row-zj49~v7sx~vbaq',
#   '00000000-0000-0000-EC98-959A4FD8F7B0',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0114184',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-12-09',
#   '2020-12-09',
#   'Active Registration',
#   '236 NW 56TH ST',
#   'SEATTLE',
#   'WA',
#   '98107',
#   'Alex Saunders',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0114184',
#    None],
#   '47.66978107',
#   '-122.36056555',
#   'POINT (-122.36056555 47.66978107)'],
#  ['row-5yvs_5wyy.ndxz',
#   '00000000-0000-0000-87C5-5874DCDDC3B5',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0115464',
#   'Rental Property',
#   'Registration',
#   '1',
#   '1907',
#   '2015-12-30',
#   '2020-12-30',
#   'Active Registration',
#   '1907 20TH AVE S',
#   'SEATTLE',
#   'WA',
#   '98144',
#   'Yu He',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0115464',
#    None],
#   '47.58607457',
#   '-122.30720188',
#   'POINT (-122.30720188 47.58607457)'],
#  ['row-nzci.4mjc.wd4k',
#   '00000000-0000-0000-020C-44CB1DCF7D4D',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0120585',
#   'Rental Property',
#   'Registration',
#   '3',
#   None,
#   '2016-05-12',
#   '2021-05-12',
#   'Active Registration',
#   '419 14TH AVE E',
#   'SEATTLE',
#   'WA',
#   '98112',
#   'North Pacific Properties',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0120585',
#    None],
#   '47.62262545',
#   '-122.31491079',
#   'POINT (-122.31491079 47.62262545)'],
#  ['row-nb8b-c3n5~xqcj',
#   '00000000-0000-0000-36EC-0EA12963D470',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0122268',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Ballard Landing #401',
#   '2016-06-29',
#   '2021-06-29',
#   'Active Registration',
#   '1422 NW 63RD ST',
#   'SEATTLE',
#   'WA',
#   '98107',
#   'Renee Stewart',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0122268',
#    None],
#   '47.6747468',
#   '-122.37481146',
#   'POINT (-122.37481146 47.6747468)'],
#  ['row-jt3w.vyx5~cf8t',
#   '00000000-0000-0000-1647-D03ABC3EA9CB',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0123681',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-08-09',
#   '2021-08-09',
#   'Active Registration',
#   '749 N 91ST ST',
#   'SEATTLE',
#   'WA',
#   '98103',
#   'Ann Peach',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0123681',
#    None],
#   '47.69473509',
#   '-122.34786742',
#   'POINT (-122.34786742 47.69473509)'],
#  ['row-rnxt-9nad-ea3g',
#   '00000000-0000-0000-7182-1D7EFD6E2B80',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0128737',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-12-06',
#   '2021-12-06',
#   'Active Registration',
#   '121 VINE ST',
#   'SEATTLE',
#   'WA',
#   '98121',
#   'Colleen Gasca',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0128737',
#    None],
#   '47.61553253',
#   '-122.34883741',
#   'POINT (-122.34883741 47.61553253)'],
#  ['row-7qy7.ysy5-p28c',
#   '00000000-0000-0000-D830-ABDAD8E59D9A',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0104572',
#   'Rental Property',
#   'Registration',
#   '6',
#   None,
#   '2015-04-01',
#   '2020-04-01',
#   'Active Registration',
#   '5607 15TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98105',
#   'Greg Huber',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0104572',
#    None],
#   '47.66970274',
#   '-122.31224745',
#   'POINT (-122.31224745 47.66970274)'],
#  ['row-bwin-ykc2_wmpm',
#   '00000000-0000-0000-6E5E-A5AA88CA8832',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0135937',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2019-04-08',
#   '2021-04-08',
#   'Active Registration',
#   '1007 N 48TH ST',
#   'SEATTLE',
#   'WA',
#   '98103',
#   'Becca Fraiman',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0135937',
#    None],
#   '47.66340275',
#   '-122.34573186',
#   'POINT (-122.34573186 47.66340275)'],
#  ['row-8d7f~nxwx~q3qn',
#   '00000000-0000-0000-3963-5D7F1376B3B5',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0105282',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-04-07',
#   '2020-04-07',
#   'Active Registration',
#   '300 W MCGRAW PL',
#   'SEATTLE',
#   'WA',
#   '98119',
#   'Laurie Finn',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105282',
#    None],
#   '47.63988137',
#   '-122.36120343',
#   'POINT (-122.36120343 47.63988137)'],
#  ['row-w6wd.xxsh~k7h8',
#   '00000000-0000-0000-7D8A-EF56B99EE3E8',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0132476',
#   'Rental Property',
#   'Registration',
#   '1',
#   'WESTLAKE 201',
#   '2017-09-30',
#   '2022-09-30',
#   'Active Registration',
#   '2125 WESTLAKE AVE N',
#   'SEATTLE',
#   'WA',
#   '98109',
#   'Stephen Sy',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0132476',
#    None],
#   '47.63893517',
#   '-122.34168235',
#   'POINT (-122.34168235 47.63893517)'],
#  ['row-3qa5_qpch-nx59',
#   '00000000-0000-0000-8B29-7BB048789376',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0135371',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2019-01-18',
#   '2021-01-18',
#   'Active Registration',
#   '950 N 96TH ST',
#   'SEATTLE',
#   'WA',
#   '98103',
#   'WJL HomeServices LLC.',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0135371',
#    None],
#   '47.69889715',
#   '-122.34562406',
#   'POINT (-122.34562406 47.69889715)'],
#  ['row-7cjx.pr5w~uuhe',
#   '00000000-0000-0000-71E5-62FAA9079A21',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0104591',
#   'Rental Property',
#   'Registration',
#   '6',
#   None,
#   '2015-03-24',
#   '2020-03-24',
#   'Active Registration',
#   '711 21ST AVE',
#   'SEATTLE',
#   'WA',
#   '98122',
#   'Michael Kaz',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0104591',
#    None],
#   '47.60843472',
#   '-122.30540282',
#   'POINT (-122.30540282 47.60843472)'],
#  ['row-wkdh_ww6y-uxmp',
#   '00000000-0000-0000-B6DC-108E1DF4219A',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0115444',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2015-12-29',
#   '2020-12-29',
#   'Active Registration',
#   '1817 25TH AVE S',
#   'SEATTLE',
#   'WA',
#   '98144',
#   'Yong Chang',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0115444',
#    None],
#   '47.58644468',
#   '-122.30066615',
#   'POINT (-122.30066615 47.58644468)'],
#  ['row-cwqh_drrk_mhdi',
#   '00000000-0000-0000-E41B-75065D93E0D2',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0110980',
#   'Rental Property',
#   'Registration',
#   '1',
#   '3844-49th',
#   '2015-09-18',
#   '2020-09-18',
#   'Active Registration',
#   '3844 49TH AVE SW',
#   'SEATTLE',
#   'WA',
#   '98116',
#   'Urban Key',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0110980',
#    None],
#   '47.56888884',
#   '-122.39453107',
#   'POINT (-122.39453107 47.56888884)'],
#  ['row-pgv7.zp3i_czdi',
#   '00000000-0000-0000-C339-10AFDAB9C040',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0107609',
#   'Rental Property',
#   'Registration',
#   '2',
#   '1302 N 48th',
#   '2015-06-25',
#   '2020-06-25',
#   'Active Registration',
#   '1302 N 48TH ST',
#   'SEATTLE',
#   'WA',
#   '98103',
#   'Zachary Downing',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0107609',
#    None],
#   '47.66376289',
#   '-122.34185323',
#   'POINT (-122.34185323 47.66376289)'],
#  ['row-4uev~y2sk-uupr',
#   '00000000-0000-0000-7C82-2B76284F9098',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0111026',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2015-09-18',
#   '2020-09-18',
#   'Active Registration',
#   '1018 E SHELBY ST',
#   'SEATTLE',
#   'WA',
#   '98102',
#   'Christine Yokan',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0111026',
#    None],
#   '47.64673106',
#   '-122.31877026',
#   'POINT (-122.31877026 47.64673106)'],
#  ['row-ir5z.6nx5~3u6y',
#   '00000000-0000-0000-681B-AF6A11CA0331',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0112832',
#   'Rental Property',
#   'Registration',
#   '3',
#   None,
#   '2015-11-06',
#   '2020-11-06',
#   'Active Registration',
#   '6240 6TH AVE NW',
#   'SEATTLE',
#   'WA',
#   '98107',
#   'Kathleen Falkenberg',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0112832',
#    None],
#   '47.67543043',
#   '-122.36371196',
#   'POINT (-122.36371196 47.67543043)'],
#  ['row-g7vn.4rzj-arey',
#   '00000000-0000-0000-6FFC-7950A6AA6AE9',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0131711',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-06-02',
#   '2022-06-02',
#   'Active Registration',
#   '1906 E LYNN ST',
#   'SEATTLE',
#   'WA',
#   '98112',
#   'Edmond Ambauen',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0131711',
#    None],
#   '47.63977206',
#   '-122.30689623',
#   'POINT (-122.30689623 47.63977206)'],
#  ['row-kaii_9ykg~gdj4',
#   '00000000-0000-0000-6421-3981B87B0B0C',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0134779',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2018-10-01',
#   '2023-10-01',
#   'Active Registration',
#   '128 C 24TH AVE E',
#   'SEATTLE',
#   'WA',
#   '98112',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0134779',
#    None],
#   '47.61983097',
#   '-122.3006841',
#   'POINT (-122.3006841 47.61983097)'],
#  ['row-mess_ni5n_d2av',
#   '00000000-0000-0000-8B81-57A9660A712C',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0128469',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-11-29',
#   '2021-11-29',
#   'Active Registration',
#   '9025 25TH AVE NE',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'Louis Bajuk-Yorgan',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0128469',
#    None],
#   '47.69468412',
#   '-122.30185551',
#   'POINT (-122.30185551 47.69468412)'],
#  ['row-ukx6~8dmn~ztis',
#   '00000000-0000-0000-6BB1-581E97522F9B',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0106827',
#   'Rental Property',
#   'Registration',
#   '2',
#   None,
#   '2015-06-14',
#   '2020-06-14',
#   'Active Registration',
#   '914 W EMERSON ST',
#   'SEATTLE',
#   'WA',
#   '98119',
#   'LGC UW Portfolio II LLC',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0106827',
#    None],
#   '47.65258481',
#   '-122.36935131',
#   'POINT (-122.36935131 47.65258481)'],
#  ['row-22az_wk69-2k8u',
#   '00000000-0000-0000-CCBA-F99C2A1FD5FA',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0117782',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-03-08',
#   '2021-03-08',
#   'Active Registration',
#   '11320 LAKESIDE AVE NE',
#   'SEATTLE',
#   'WA',
#   '98125',
#   'HARPAL DHALIWAL',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117782',
#    None],
#   '47.71185585',
#   '-122.27738046',
#   'POINT (-122.27738046 47.71185585)'],
#  ['row-7qmq.74nf~xts2',
#   '00000000-0000-0000-F43D-D58E81F0564B',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0112213',
#   'Rental Property',
#   'Registration',
#   '4',
#   None,
#   '2015-10-13',
#   '2020-10-13',
#   'Active Registration',
#   '8849 NESBIT AVE N',
#   'SEATTLE',
#   'WA',
#   '98103',
#   'John Maloney',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0112213',
#    None],
#   '47.69380931',
#   '-122.34370086',
#   'POINT (-122.34370086 47.69380931)'],
#  ['row-x7qu-7r73~xf8d',
#   '00000000-0000-0000-E352-8329F3B22443',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0130538',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2017-01-20',
#   '2022-01-20',
#   'Active Registration',
#   '7741 2ND AVE NE',
#   'SEATTLE',
#   'WA',
#   '98115',
#   'Saint Andrews Episcopal Church',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0130538',
#    None],
#   '47.68627783',
#   '-122.32727713',
#   'POINT (-122.32727713 47.68627783)'],
#  ['row-eezh~tieu.x4z2',
#   '00000000-0000-0000-2769-D926BF1CADDE',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0109093',
#   'Rental Property',
#   'Registration',
#   '3',
#   None,
#   '2015-08-02',
#   '2020-08-02',
#   'Active Registration',
#   '2106 6TH AVE W',
#   'SEATTLE',
#   'WA',
#   '98119',
#   'Mariana Panaiotov',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0109093',
#    None],
#   '47.63806334',
#   '-122.36471518',
#   'POINT (-122.36471518 47.63806334)'],
#  ['row-6yaq_wf9z-jq7h',
#   '00000000-0000-0000-07B2-DA3AAAB0F6AE',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0105665',
#   'Rental Property',
#   'Registration',
#   '1',
#   'Harwood Condos',
#   '2015-05-06',
#   '2020-05-06',
#   'Active Registration',
#   '1311 12TH AVE S',
#   'SEATTLE',
#   'WA',
#   '98144',
#   'Brian Martin',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0105665',
#    None],
#   '47.59094844',
#   '-122.31801682',
#   'POINT (-122.31801682 47.59094844)'],
#  ['row-mk39-4jfu~9my3',
#   '00000000-0000-0000-41CD-768BF0EB9DD8',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0117890',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-03-09',
#   '2021-03-09',
#   'Active Registration',
#   '171 15TH AVE',
#   'SEATTLE',
#   'WA',
#   '98122',
#   'Alex Karchevsky',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0117890',
#    None],
#   '47.60336516',
#   '-122.31315485',
#   'POINT (-122.31315485 47.60336516)'],
#  ['row-7va8.42qd.4q66',
#   '00000000-0000-0000-F043-3559FFD19CDB',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0120003',
#   'Rental Property',
#   'Registration',
#   '2',
#   'Union Street',
#   '2016-04-23',
#   '2021-04-23',
#   'Active Registration',
#   '2512 E UNION ST',
#   'SEATTLE',
#   'WA',
#   '98122',
#   None,
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0120003',
#    None],
#   '47.6131743',
#   '-122.29948923',
#   'POINT (-122.29948923 47.6131743)'],
#  ['row-civr-9wpb~u6vy',
#   '00000000-0000-0000-B72B-F1441ADA62B7',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0129171',
#   'Rental Property',
#   'Registration',
#   '1',
#   None,
#   '2016-12-22',
#   '2021-12-22',
#   'Active Registration',
#   '5121 S WILLOW ST',
#   'SEATTLE',
#   'WA',
#   '98118',
#   'Michael Leavy',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0129171',
#    None],
#   '47.5402983',
#   '-122.26883781',
#   'POINT (-122.26883781 47.5402983)'],
#  ['row-dvkz~fbtu_uq2b',
#   '00000000-0000-0000-24B0-D639CE488E13',
#   0,
#   1561394371,
#   None,
#   1561394395,
#   None,
#   '{ }',
#   '001-0101597',
#   'Rental Property',
#   'Registration',
#   '16',
#   'Delphian Apartments',
#   '2014-09-25',
#   '2019-09-25',
#   'Active Registration',
#   '400 W ROY ST',
#   'SEATTLE',
#   'WA',
#   '98119',
#   'John Cain',
#   ['https://cosaccela.seattle.gov/portal/customize/LinkToRecord.aspx?altId=001-0101597',
#    None],
#   '47.62618783',
#   '-122.36218374',
#   'POINT (-122.36218374 47.62618783)'],
#  ...]

# %%
#datatype of first level
type(seattleprops['data'][0])
# Out:
# list

# %%
type(seattleprops['data'][0][0])
# Out:
# str

# %%
seattleprops['data'][0][0]
# Out:
# 'row-d3wj~gyzj~in8j'

# %%
#the total number of rental properties in dataset
#there are 32,642 rental properties 
len(seattleprops['data'])
# Out:
# 32642

# %% [markdown]
# ### Data Exploring - CSV
# Using City of Seattle's provided CSV

# %%
location = "seattle_Rental_Property_Registration.csv"

srentprops_df = pd.read_csv(location)
srentprops_df.head()
# Out:
#   RegistrationNum RegisteredTypeMapped RegisteredTypeDesc  RentalHousingUnits  \
# 0     001-0130088      Rental Property       Registration                   1
# 1     001-0129613      Rental Property       Registration                   1
# 2     001-0129034      Rental Property       Registration                   1
# 3     001-0122782      Rental Property       Registration                   1
# 4     001-0136116      Rental Property       Registration                   1
#
#   PropertyName RegisteredDate ExpiresDate        StatusCurrent  \
# 0          NaN     2017-01-06  2022-01-06  Active Registration
# 1          NaN     2016-12-29  2021-12-29  Active Registration
# 2          NaN     2016-12-13  2021-12-13  Active Registration
# 3          NaN     2016-06-26  2021-06-26  Active Registration
# 4          NaN     2019-05-08  2021-05-08  Active Registration
#
#   OriginalAddress1 OriginalCity OriginalState  OriginalZip  \
# 0   146 NW 74TH ST      SEATTLE            WA      98117.0
# 1     2100 3RD AVE      SEATTLE            WA      98121.0
# 2  5720 37TH AVE S      SEATTLE            WA      98118.0
# 3    147 N 76TH ST      SEATTLE            WA      98103.0
# 4  2311 43RD AVE E      SEATTLE            WA      98112.0
#
#   PropertyContactName                                               Link  \
# 0                 NaN  https://cosaccela.seattle.gov/portal/customize...
# 1                 NaN  https://cosaccela.seattle.gov/portal/customize...
# 2                 NaN  https://cosaccela.seattle.gov/portal/customize...
# 3                 NaN  https://cosaccela.seattle.gov/portal/customize...
# 4           Marc Boyd  https://cosaccela.seattle.gov/portal/customize...
#
#     Latitude   Longitude                          Location1
# 0  47.682748 -122.359981  POINT (-122.35998077 47.68274781)
# 1  47.613531 -122.342333   POINT (-122.3423326 47.61353093)
# 2  47.550597 -122.286020  POINT (-122.28602015 47.55059675)
# 3  47.683823 -122.355983   POINT (-122.35598277 47.6838228)
# 4  47.639513 -122.277395  POINT (-122.27739453 47.63951303)

# %%
#see column header names
srentprops_df.columns
# Out:
# Index(['RegistrationNum', 'RegisteredTypeMapped', 'RegisteredTypeDesc',
#        'RentalHousingUnits', 'PropertyName', 'RegisteredDate', 'ExpiresDate',
#        'StatusCurrent', 'OriginalAddress1', 'OriginalCity', 'OriginalState',
#        'OriginalZip', 'PropertyContactName', 'Link', 'Latitude', 'Longitude',
#        'Location1'],
#       dtype='object')

# %%
#missing values
srentprops_df.isnull().sum()
# Out:
# RegistrationNum             0
# RegisteredTypeMapped        0
# RegisteredTypeDesc          0
# RentalHousingUnits          0
# PropertyName            24002
# RegisteredDate              0
# ExpiresDate                 0
# StatusCurrent               0
# OriginalAddress1            0
# OriginalCity              532
# OriginalState             532
# OriginalZip               682
# PropertyContactName      3943
# Link                        0
# Latitude                  350
# Longitude                 350
# Location1                 350
# dtype: int64

# %%
#rows where OriginalZip is null
missing_zipcode = srentprops_df[srentprops_df['OriginalZip'].isnull()]
missing_zipcode.head(10)
# Out:
#    RegistrationNum RegisteredTypeMapped RegisteredTypeDesc  \
# 6      001-0135141      Rental Property       Registration
# 7      001-0135816      Rental Property       Registration
# 10     001-0134846      Rental Property       Registration
# 11     001-0134074      Rental Property       Registration
# 12     001-0134099      Rental Property       Registration
# 16     001-0134961      Rental Property       Registration
# 19     001-0135251      Rental Property       Registration
# 20     001-0134421      Rental Property       Registration
# 22     001-0134925      Rental Property       Registration
# 23     001-0126582      Rental Property       Registration
#
#     RentalHousingUnits            PropertyName RegisteredDate ExpiresDate  \
# 6                    1                     NaN     2019-04-18  2021-04-18
# 7                    1                     NaN     2019-03-16  2021-03-16
# 10                   2       4220 Bagley Ave N     2018-10-14  2023-10-14
# 11                   1                     NaN     2018-06-11  2023-06-11
# 12                   2     Concord Condominium     2018-06-13  2023-06-13
# 16                   1  San Villa Condominiums     2018-10-31  2023-10-31
# 19                   2                     NaN     2018-12-31  2023-12-31
# 20                   1                  Portal     2018-08-03  2023-08-03
# 22                   1         Harbour Heights     2018-10-23  2023-10-23
# 23                   1                     NaN     2016-12-08  2021-12-08
#
#           StatusCurrent    OriginalAddress1 OriginalCity OriginalState  \
# 6   Active Registration    1214 E Hamlin ST          NaN           NaN
# 7   Active Registration       516 N 62nd ST          NaN           NaN
# 10  Active Registration   4220 Bagley AVE N          NaN           NaN
# 11  Active Registration        2911 2nd AVE          NaN           NaN
# 12  Active Registration        2929 1st AVE          NaN           NaN
# 16  Active Registration     9520 1st AVE NE          NaN           NaN
# 19  Active Registration  10610 Bagley AVE N          NaN           NaN
# 20  Active Registration     655 Crockett ST          NaN           NaN
# 22  Active Registration        2621 2nd AVE          NaN           NaN
# 23  Active Registration       5102 27th AVE      SEATTLE            WA
#
#     OriginalZip             PropertyContactName  \
# 6           NaN                   Andrea Jacobi
# 7           NaN                 Laurie Milligan
# 10          NaN                             NaN
# 11          NaN  Maple Leaf Property Management
# 12          NaN                             NaN
# 16          NaN                      Jon RINKER
# 19          NaN                             NaN
# 20          NaN                   Amanjot Singh
# 22          NaN                             NaN
# 23          NaN                  Kok Lan Cheung
#
#                                                  Link   Latitude   Longitude  \
# 6   https://cosaccela.seattle.gov/portal/customize...  47.645789 -122.315878
# 7   https://cosaccela.seattle.gov/portal/customize...  47.674134 -122.352152
# 10  https://cosaccela.seattle.gov/portal/customize...  47.658610 -122.332352
# 11  https://cosaccela.seattle.gov/portal/customize...  47.617548 -122.352260
# 12  https://cosaccela.seattle.gov/portal/customize...  47.617331 -122.353778
# 16  https://cosaccela.seattle.gov/portal/customize...  47.698343 -122.327890
# 19  https://cosaccela.seattle.gov/portal/customize...  47.706301 -122.332320
# 20  https://cosaccela.seattle.gov/portal/customize...  47.637099 -122.343811
# 22  https://cosaccela.seattle.gov/portal/customize...  47.616126 -122.349747
# 23  https://cosaccela.seattle.gov/portal/customize...        NaN         NaN
#
#                             Location1
# 6     POINT (-122.315878 47.64578913)
# 7   POINT (-122.35215202 47.67413375)
# 10  POINT (-122.33235174 47.65860961)
# 11  POINT (-122.35226048 47.61754767)
# 12  POINT (-122.35377814 47.61733149)
# 16  POINT (-122.32788992 47.69834301)
# 19  POINT (-122.33232029 47.70630089)
# 20  POINT (-122.34381127 47.63709868)
# 22  POINT (-122.34974746 47.61612629)
# 23                                NaN

# %%
#rows where original city, state, and zip is null
missing_csz = srentprops_df[(srentprops_df['OriginalCity'].isnull())&(srentprops_df['OriginalState'].isnull())&(srentprops_df['OriginalZip'].isnull())]
missing_csz.head(10)
# Out:
#    RegistrationNum RegisteredTypeMapped RegisteredTypeDesc  \
# 6      001-0135141      Rental Property       Registration
# 7      001-0135816      Rental Property       Registration
# 10     001-0134846      Rental Property       Registration
# 11     001-0134074      Rental Property       Registration
# 12     001-0134099      Rental Property       Registration
# 16     001-0134961      Rental Property       Registration
# 19     001-0135251      Rental Property       Registration
# 20     001-0134421      Rental Property       Registration
# 22     001-0134925      Rental Property       Registration
# 24     001-0135417      Rental Property       Registration
#
#     RentalHousingUnits            PropertyName RegisteredDate ExpiresDate  \
# 6                    1                     NaN     2019-04-18  2021-04-18
# 7                    1                     NaN     2019-03-16  2021-03-16
# 10                   2       4220 Bagley Ave N     2018-10-14  2023-10-14
# 11                   1                     NaN     2018-06-11  2023-06-11
# 12                   2     Concord Condominium     2018-06-13  2023-06-13
# 16                   1  San Villa Condominiums     2018-10-31  2023-10-31
# 19                   2                     NaN     2018-12-31  2023-12-31
# 20                   1                  Portal     2018-08-03  2023-08-03
# 22                   1         Harbour Heights     2018-10-23  2023-10-23
# 24                   1                     NaN     2019-01-23  2021-01-23
#
#           StatusCurrent    OriginalAddress1 OriginalCity OriginalState  \
# 6   Active Registration    1214 E Hamlin ST          NaN           NaN
# 7   Active Registration       516 N 62nd ST          NaN           NaN
# 10  Active Registration   4220 Bagley AVE N          NaN           NaN
# 11  Active Registration        2911 2nd AVE          NaN           NaN
# 12  Active Registration        2929 1st AVE          NaN           NaN
# 16  Active Registration     9520 1st AVE NE          NaN           NaN
# 19  Active Registration  10610 Bagley AVE N          NaN           NaN
# 20  Active Registration     655 Crockett ST          NaN           NaN
# 22  Active Registration        2621 2nd AVE          NaN           NaN
# 24  Active Registration  4643 Eastern AVE N          NaN           NaN
#
#     OriginalZip             PropertyContactName  \
# 6           NaN                   Andrea Jacobi
# 7           NaN                 Laurie Milligan
# 10          NaN                             NaN
# 11          NaN  Maple Leaf Property Management
# 12          NaN                             NaN
# 16          NaN                      Jon RINKER
# 19          NaN                             NaN
# 20          NaN                   Amanjot Singh
# 22          NaN                             NaN
# 24          NaN                             NaN
#
#                                                  Link   Latitude   Longitude  \
# 6   https://cosaccela.seattle.gov/portal/customize...  47.645789 -122.315878
# 7   https://cosaccela.seattle.gov/portal/customize...  47.674134 -122.352152
# 10  https://cosaccela.seattle.gov/portal/customize...  47.658610 -122.332352
# 11  https://cosaccela.seattle.gov/portal/customize...  47.617548 -122.352260
# 12  https://cosaccela.seattle.gov/portal/customize...  47.617331 -122.353778
# 16  https://cosaccela.seattle.gov/portal/customize...  47.698343 -122.327890
# 19  https://cosaccela.seattle.gov/portal/customize...  47.706301 -122.332320
# 20  https://cosaccela.seattle.gov/portal/customize...  47.637099 -122.343811
# 22  https://cosaccela.seattle.gov/portal/customize...  47.616126 -122.349747
# 24  https://cosaccela.seattle.gov/portal/customize...  47.663877 -122.329386
#
#                             Location1
# 6     POINT (-122.315878 47.64578913)
# 7   POINT (-122.35215202 47.67413375)
# 10  POINT (-122.33235174 47.65860961)
# 11  POINT (-122.35226048 47.61754767)
# 12  POINT (-122.35377814 47.61733149)
# 16  POINT (-122.32788992 47.69834301)
# 19  POINT (-122.33232029 47.70630089)
# 20  POINT (-122.34381127 47.63709868)
# 22  POINT (-122.34974746 47.61612629)
# 24   POINT (-122.32938582 47.6638771)

# %%
#number of rows with city, state, and zip were missing
len(missing_csz)
# Out:
# 532

# %%
#other missing values in the missing_csz rows
#about half of them are missing latitude, longitude
#we can use the rows with available latitude and longitude values to find the missing city/state/zipcode values
missing_csz.isnull().sum()
# Out:
# RegistrationNum           0
# RegisteredTypeMapped      0
# RegisteredTypeDesc        0
# RentalHousingUnits        0
# PropertyName            295
# RegisteredDate            0
# ExpiresDate               0
# StatusCurrent             0
# OriginalAddress1          0
# OriginalCity            532
# OriginalState           532
# OriginalZip             532
# PropertyContactName      83
# Link                      0
# Latitude                248
# Longitude               248
# Location1               248
# dtype: int64

# %%
#rows in missing_csz variable, but has longtitude and latitude values
missing_csz_ll = srentprops_df[(srentprops_df['OriginalCity'].isnull())&(srentprops_df['OriginalState'].isnull())
                            &(srentprops_df['OriginalZip'].isnull())&(srentprops_df['Latitude'].notnull())
                            &(srentprops_df['Longitude'].notnull())]
missing_csz_ll.head()
# Out:
#    RegistrationNum RegisteredTypeMapped RegisteredTypeDesc  \
# 6      001-0135141      Rental Property       Registration
# 7      001-0135816      Rental Property       Registration
# 10     001-0134846      Rental Property       Registration
# 11     001-0134074      Rental Property       Registration
# 12     001-0134099      Rental Property       Registration
#
#     RentalHousingUnits         PropertyName RegisteredDate ExpiresDate  \
# 6                    1                  NaN     2019-04-18  2021-04-18
# 7                    1                  NaN     2019-03-16  2021-03-16
# 10                   2    4220 Bagley Ave N     2018-10-14  2023-10-14
# 11                   1                  NaN     2018-06-11  2023-06-11
# 12                   2  Concord Condominium     2018-06-13  2023-06-13
#
#           StatusCurrent   OriginalAddress1 OriginalCity OriginalState  \
# 6   Active Registration   1214 E Hamlin ST          NaN           NaN
# 7   Active Registration      516 N 62nd ST          NaN           NaN
# 10  Active Registration  4220 Bagley AVE N          NaN           NaN
# 11  Active Registration       2911 2nd AVE          NaN           NaN
# 12  Active Registration       2929 1st AVE          NaN           NaN
#
#     OriginalZip             PropertyContactName  \
# 6           NaN                   Andrea Jacobi
# 7           NaN                 Laurie Milligan
# 10          NaN                             NaN
# 11          NaN  Maple Leaf Property Management
# 12          NaN                             NaN
#
#                                                  Link   Latitude   Longitude  \
# 6   https://cosaccela.seattle.gov/portal/customize...  47.645789 -122.315878
# 7   https://cosaccela.seattle.gov/portal/customize...  47.674134 -122.352152
# 10  https://cosaccela.seattle.gov/portal/customize...  47.658610 -122.332352
# 11  https://cosaccela.seattle.gov/portal/customize...  47.617548 -122.352260
# 12  https://cosaccela.seattle.gov/portal/customize...  47.617331 -122.353778
#
#                             Location1
# 6     POINT (-122.315878 47.64578913)
# 7   POINT (-122.35215202 47.67413375)
# 10  POINT (-122.33235174 47.65860961)
# 11  POINT (-122.35226048 47.61754767)
# 12  POINT (-122.35377814 47.61733149)

# %%
#number of rows the missing_csz variable, but has longtitude and latitude
len(missing_csz_ll)
# Out:
# 284

# %%
#rows where there are missing values for zip code but there are values for city and state
missingzip_notcs = srentprops_df[(srentprops_df['OriginalCity'].notnull())&(srentprops_df['OriginalState'].notnull())&(srentprops_df['OriginalZip'].isnull())]
missingzip_notcs
# Out:
#       RegistrationNum RegisteredTypeMapped RegisteredTypeDesc  \
# 23        001-0126582      Rental Property       Registration
# 445       001-0134169      Rental Property       Registration
# 627       001-0119417      Rental Property       Registration
# 795       001-0133331      Rental Property       Registration
# 840       001-0134339      Rental Property       Registration
# 954       001-0135187      Rental Property       Registration
# 1121      001-0134457      Rental Property       Registration
# 1235      001-0134286      Rental Property       Registration
# 1242      001-0132564      Rental Property       Registration
# 1580      001-0134073      Rental Property       Registration
# 1632      001-0134983      Rental Property       Registration
# 2000      001-0133817      Rental Property       Registration
# 2068      001-0133816      Rental Property       Registration
# 2390      001-0134287      Rental Property       Registration
# 2500      001-0133847      Rental Property       Registration
# 3279      001-0134631      Rental Property       Registration
# 5493      001-0134095      Rental Property       Registration
# 5967      001-0134668      Rental Property       Registration
# 6133      001-0134707      Rental Property       Registration
# 6597      001-0134762      Rental Property       Registration
# 7067      001-0134198      Rental Property       Registration
# 8052      001-0133898      Rental Property       Registration
# 8098      001-0134487      Rental Property       Registration
# 8140      001-0134057      Rental Property       Registration
# 8373      001-0133945      Rental Property       Registration
# 8458      001-0134001      Rental Property       Registration
# 8659      001-0133974      Rental Property       Registration
# 10204     001-0134192      Rental Property       Registration
# 10717     001-0134455      Rental Property       Registration
# 11500     001-0134656      Rental Property       Registration
# ...               ...                  ...                ...
# 31960     001-0133332      Rental Property       Registration
# 31969     001-0117358      Rental Property       Registration
# 31972     001-0134890      Rental Property       Registration
# 31974     001-0135188      Rental Property       Registration
# 31975     001-0116199      Rental Property       Registration
# 31987     001-0131720      Rental Property       Registration
# 31991     001-0127438      Rental Property       Registration
# 32015     001-0104174      Rental Property       Registration
# 32027     001-0110877      Rental Property       Registration
# 32044     001-0132959      Rental Property       Registration
# 32046     001-0112183      Rental Property       Registration
# 32059     001-0134763      Rental Property       Registration
# 32060     001-0128672      Rental Property       Registration
# 32078     001-0134303      Rental Property       Registration
# 32081     001-0111373      Rental Property       Registration
# 32094     001-0132384      Rental Property       Registration
# 32106     001-0132889      Rental Property       Registration
# 32118     001-0134988      Rental Property       Registration
# 32121     001-0135124      Rental Property       Registration
# 32140     001-0130696      Rental Property       Registration
# 32183     001-0111140      Rental Property       Registration
# 32187     001-0132961      Rental Property       Registration
# 32193     001-0133948      Rental Property       Registration
# 32209     001-0134036      Rental Property       Registration
# 32229     001-0134892      Rental Property       Registration
# 32234     001-0110019      Rental Property       Registration
# 32256     001-0127919      Rental Property       Registration
# 32266     001-0133700      Rental Property       Registration
# 32279     001-0134986      Rental Property       Registration
# 32282     001-0134895      Rental Property       Registration
#
#        RentalHousingUnits PropertyName RegisteredDate ExpiresDate  \
# 23                      1          NaN     2016-12-08  2021-12-08
# 445                     1          NaN     2018-09-21  2023-09-21
# 627                     1          NaN     2016-04-06  2021-04-06
# 795                     1          NaN     2018-02-16  2023-02-16
# 840                     1          NaN     2018-08-24  2023-08-24
# 954                     1          NaN     2019-01-16  2021-01-16
# 1121                    1          NaN     2018-08-23  2023-08-23
# 1235                    1          NaN     2018-08-02  2023-08-02
# 1242                    1          NaN     2018-05-24  2023-05-24
# 1580                    1          NaN     2018-08-02  2023-08-02
# 1632                    1          NaN     2018-11-14  2023-11-14
# 2000                    1           27     2018-05-03  2023-05-03
# 2068                    1           #A     2018-05-04  2023-05-04
# 2390                    2          NaN     2018-08-02  2023-08-02
# 2500                    1          NaN     2018-05-14  2023-05-14
# 3279                    1          NaN     2018-09-21  2023-09-21
# 5493                    1          NaN     2018-08-02  2023-08-02
# 5967                    1          NaN     2018-09-11  2023-09-11
# 6133                    1          NaN     2018-09-20  2023-09-20
# 6597                    1          NaN     2018-10-26  2023-10-26
# 7067                    1          NaN     2018-09-21  2023-09-21
# 8052                    1          NaN     2018-05-15  2023-05-15
# 8098                    1          NaN     2018-08-14  2023-08-14
# 8140                    1          NaN     2018-06-21  2023-06-21
# 8373                    1          NaN     2018-05-22  2023-05-22
# 8458                    1          NaN     2018-05-31  2023-05-31
# 8659                    1          NaN     2018-05-25  2023-05-25
# 10204                   1          NaN     2018-09-21  2023-09-21
# 10717                   1          NaN     2018-08-23  2023-08-23
# 11500                   1          NaN     2018-09-20  2023-09-20
# ...                   ...          ...            ...         ...
# 31960                   2          NaN     2018-02-16  2023-02-16
# 31969                   4          NaN     2016-02-29  2021-02-28
# 31972                   1          NaN     2018-10-26  2023-10-26
# 31974                   1          NaN     2019-01-16  2021-01-16
# 31975                   1          NaN     2016-01-15  2021-01-15
# 31987                   1          NaN     2017-09-25  2022-09-25
# 31991                   1          NaN     2016-10-17  2021-10-17
# 32015                   8          NaN     2015-03-17  2020-03-17
# 32027                   2          NaN     2015-09-25  2020-09-25
# 32044                   2          NaN     2017-12-19  2022-12-19
# 32046                   1          NaN     2015-10-01  2020-10-01
# 32059                   1          NaN     2018-10-26  2023-10-26
# 32060                   1          NaN     2017-02-09  2022-02-09
# 32078                  91          NaN     2018-10-17  2023-10-17
# 32081                   1          NaN     2015-09-28  2020-09-28
# 32094                   4          NaN     2017-09-19  2022-09-19
# 32106                   1          NaN     2017-11-29  2022-11-29
# 32118                   1          NaN     2018-11-13  2023-11-13
# 32121                   1          NaN     2018-12-17  2023-12-17
# 32140                   1          NaN     2017-02-14  2022-02-14
# 32183                   2          NaN     2015-10-06  2020-10-06
# 32187                   1          NaN     2017-12-19  2022-12-19
# 32193                   1          NaN     2018-05-22  2023-05-22
# 32209                   1          NaN     2018-06-21  2023-06-21
# 32229                   1          NaN     2018-10-26  2023-10-26
# 32234                   1          NaN     2015-09-05  2020-09-05
# 32256                   1          NaN     2016-11-16  2021-11-16
# 32266                   1          NaN     2018-04-11  2023-04-11
# 32279                   1          NaN     2018-11-14  2023-11-14
# 32282                   1          NaN     2018-10-18  2023-10-18
#
#              StatusCurrent         OriginalAddress1 OriginalCity  \
# 23     Active Registration            5102 27th AVE      SEATTLE
# 445    Active Registration              588 Bell ST      SEATTLE
# 627    Active Registration     1103 M L KING JR WAY      SEATTLE
# 795    Active Registration              9239 A 35th      SEATTLE
# 840    Active Registration            701 1st AVE N      SEATTLE
# 954    Active Registration         7333 22ND AVE NW      SEATTLE
# 1121   Active Registration         1936 NE 127th ST      SEATTLE
# 1235   Active Registration           1701 N 36th ST      SEATTLE
# 1242   Active Registration          2201 3RD AVENUE      SEATTLE
# 1580   Active Registration         438 malden AVE E      SEATTLE
# 1632   Active Registration         2810 NE 115TH ST      SEATTLE
# 2000   Active Registration         3151 alki AVE SW      SEATTLE
# 2068   Active Registration       8836 MIDVALE AVE N      SEATTLE
# 2390   Active Registration           1715 N 36th ST      SEATTLE
# 2500   Active Registration      6533 seaview AVE NW      SEATTLE
# 3279   Active Registration           5515 S Avon ST      SEATTLE
# 5493   Active Registration          2808 NW 65th ST      SEATTLE
# 5967   Active Registration          2801 18th AVE S      SEATTLE
# 6133   Active Registration   3817 California AVE SW      SEATTLE
# 6597   Active Registration          1545 19th AVE S      SEATTLE
# 7067   Active Registration          2046 NW 63rd ST      SEATTLE
# 8052   Active Registration       124 BELLEVUE AVE E      SEATTLE
# 8098   Active Registration      2233 Boylston AVE E      SEATTLE
# 8140   Active Registration           303 NW 90th ST      SEATTLE
# 8373   Active Registration          920 NW 106th ST      SEATTLE
# 8458   Active Registration             2125 1st AVE      SEATTLE
# 8659   Active Registration           718 26th AVE S      SEATTLE
# 10204  Active Registration         7064 35th AVE NE      SEATTLE
# 10717  Active Registration          2801 23rd AVE S      SEATTLE
# 11500  Active Registration   3834 California AVE SW      SEATTLE
# ...                    ...                      ...          ...
# 31960  Active Registration                 528 11 E      SEATTLE
# 31969  Active Registration            1404 30th AVE      SEATTLE
# 31972  Active Registration               103 N 79TH      SEATTLE
# 31974  Active Registration         7322 RAINIER AVE      SEATTLE
# 31975  Active Registration        2655 B NW 63rd ST      SEATTLE
# 31987  Active Registration              6539 5th NE      SEATTLE
# 31991  Active Registration       2205 A NE 117th ST      SEATTLE
# 32015  Active Registration    3015 C Fairview AVE E      SEATTLE
# 32027  Active Registration         4512 41st AVE SW      SEATTLE
# 32044  Active Registration              311 N 137TH      SEATTLE
# 32046  Active Registration      4524 E Laurel DR NE      SEATTLE
# 32059  Active Registration       12812 N park AVE N      SEATTLE
# 32060  Active Registration             852 NW 90 ST      SEATTLE
# 32078  Active Registration            3501 Ra AVE S      SEATTLE
# 32081  Active Registration          408 N 125th TRL      SEATTLE
# 32094  Active Registration             2629 NW 63RD      SEATTLE
# 32106  Active Registration             215 23rd AVE      SEATTLE
# 32118  Active Registration    5621 C FAUNTLEROY WAY      SEATTLE
# 32121  Active Registration            2033 E NEWTON      SEATTLE
# 32140  Active Registration           9303 S 52nd ST      SEATTLE
# 32183  Active Registration            3201 61st AVE      SEATTLE
# 32187  Active Registration              2101 N 40TH      SEATTLE
# 32193  Active Registration             1809 N 107TH      SEATTLE
# 32209  Active Registration              1001 W Howe      SEATTLE
# 32229  Active Registration             6751 48TH SW      SEATTLE
# 32234  Active Registration     12266 Densmore AVE E      SEATTLE
# 32256  Active Registration      9728 Woodlawn AVE N      SEATTLE
# 32266  Active Registration            723 N 95th ST      SEATTLE
# 32279  Active Registration    5621 B FAUNTLEROY WAY      SEATTLE
# 32282  Active Registration  10623 Sand Point WAY NE      SEATTLE
#
#       OriginalState  OriginalZip                         PropertyContactName  \
# 23               WA          NaN                              Kok Lan Cheung
# 445              WA          NaN                                  Joe Horgan
# 627              WA          NaN                              Michelle Huang
# 795              WA          NaN                                Susan Giroux
# 840              WA          NaN  Fletcher-McGookin Community Property Trust
# 954              WA          NaN                                  john yeung
# 1121             WA          NaN                               James McGuire
# 1235             WA          NaN                              SHIRLEY BARGER
# 1242             WA          NaN                     SJA Property Management
# 1580             WA          NaN                          Wanwirote Varophas
# 1632             WA          NaN                                  Judy Sandy
# 2000             WA          NaN                                Sharon Perry
# 2068             WA          NaN                                   Calvin Lu
# 2390             WA          NaN                              Shirley Barger
# 2500             WA          NaN                              Curtis Johnson
# 3279             WA          NaN                                Sarita Kumar
# 5493             WA          NaN                             Scott Dallmeyer
# 5967             WA          NaN                                  Jay LaBrie
# 6133             WA          NaN                                     Ping Li
# 6597             WA          NaN                                  LYDIA CHOW
# 7067             WA          NaN                             Michael Carlson
# 8052             WA          NaN                              Charlie Bauman
# 8098             WA          NaN                                     Ping Li
# 8140             WA          NaN                               Mohit Agarwal
# 8373             WA          NaN                                Joyce Newton
# 8458             WA          NaN                               Clifton James
# 8659             WA          NaN                                   Pauh Wang
# 10204            WA          NaN                                 Suzann Zorn
# 10717            WA          NaN                    Transpacific Corporation
# 11500            WA          NaN                                SUSAN TORREY
# ...             ...          ...                                         ...
# 31960            WA          NaN                                     BEI LIU
# 31969            WA          NaN                          William Langworthy
# 31972            WA          NaN                                  Joanne Lee
# 31974            WA          NaN                                SAM STUELAND
# 31975            WA          NaN                   Steve & Rachelle Jacobson
# 31987            WA          NaN                                  Steve Boyd
# 31991            WA          NaN                                Robert Grove
# 32015            WA          NaN                                Linda Nelson
# 32027            WA          NaN                                Carmen Orton
# 32044            WA          NaN                                  Marc Stern
# 32046            WA          NaN                              Sharifah Sabah
# 32059            WA          NaN                                  LYDIA CHOW
# 32060            WA          NaN                               Tamela Thomas
# 32078            WA          NaN          DESC ESTELLE SUPPORTIVE HOUSING LP
# 32081            WA          NaN                               Eugene Tetteh
# 32094            WA          NaN                                A.D. Vickery
# 32106            WA          NaN                               Jason Tillman
# 32118            WA          NaN                                  Judy Sandy
# 32121            WA          NaN                              JJR Management
# 32140            WA          NaN                                 Bill Rogers
# 32183            WA          NaN                    Frank & Marilyn Rutledge
# 32187            WA          NaN                               WYN POTTINGER
# 32193            WA          NaN                                   Lorri Day
# 32209            WA          NaN                                Scott Ulrich
# 32229            WA          NaN                              SEAN MCKINSTRY
# 32234            WA          NaN                    Leanne Van & Larry Chrin
# 32256            WA          NaN                                 Tameka West
# 32266            WA          NaN                                  Jay Labrie
# 32279            WA          NaN                                  Judy Sandy
# 32282            WA          NaN                          Prolink Realty LLC
#
#                                                     Link   Latitude  \
# 23     https://cosaccela.seattle.gov/portal/customize...        NaN
# 445    https://cosaccela.seattle.gov/portal/customize...  47.616730
# 627    https://cosaccela.seattle.gov/portal/customize...        NaN
# 795    https://cosaccela.seattle.gov/portal/customize...        NaN
# 840    https://cosaccela.seattle.gov/portal/customize...  47.625634
# 954    https://cosaccela.seattle.gov/portal/customize...  47.682296
# 1121   https://cosaccela.seattle.gov/portal/customize...  47.721431
# 1235   https://cosaccela.seattle.gov/portal/customize...  47.650341
# 1242   https://cosaccela.seattle.gov/portal/customize...        NaN
# 1580   https://cosaccela.seattle.gov/portal/customize...  47.622841
# 1632   https://cosaccela.seattle.gov/portal/customize...  47.712208
# 2000   https://cosaccela.seattle.gov/portal/customize...  47.576320
# 2068   https://cosaccela.seattle.gov/portal/customize...  47.693492
# 2390   https://cosaccela.seattle.gov/portal/customize...  47.650363
# 2500   https://cosaccela.seattle.gov/portal/customize...  47.676245
# 3279   https://cosaccela.seattle.gov/portal/customize...  47.501162
# 5493   https://cosaccela.seattle.gov/portal/customize...  47.676108
# 5967   https://cosaccela.seattle.gov/portal/customize...  47.578575
# 6133   https://cosaccela.seattle.gov/portal/customize...  47.569664
# 6597   https://cosaccela.seattle.gov/portal/customize...  47.588715
# 7067   https://cosaccela.seattle.gov/portal/customize...  47.674737
# 8052   https://cosaccela.seattle.gov/portal/customize...  47.619437
# 8098   https://cosaccela.seattle.gov/portal/customize...  47.639232
# 8140   https://cosaccela.seattle.gov/portal/customize...  47.694056
# 8373   https://cosaccela.seattle.gov/portal/customize...  47.706143
# 8458   https://cosaccela.seattle.gov/portal/customize...  47.612280
# 8659   https://cosaccela.seattle.gov/portal/customize...  47.596146
# 10204  https://cosaccela.seattle.gov/portal/customize...  47.681469
# 10717  https://cosaccela.seattle.gov/portal/customize...  47.578175
# 11500  https://cosaccela.seattle.gov/portal/customize...  47.569736
# ...                                                  ...        ...
# 31960  https://cosaccela.seattle.gov/portal/customize...        NaN
# 31969  https://cosaccela.seattle.gov/portal/customize...        NaN
# 31972  https://cosaccela.seattle.gov/portal/customize...        NaN
# 31974  https://cosaccela.seattle.gov/portal/customize...        NaN
# 31975  https://cosaccela.seattle.gov/portal/customize...        NaN
# 31987  https://cosaccela.seattle.gov/portal/customize...        NaN
# 31991  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32015  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32027  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32044  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32046  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32059  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32060  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32078  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32081  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32094  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32106  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32118  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32121  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32140  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32183  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32187  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32193  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32209  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32229  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32234  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32256  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32266  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32279  https://cosaccela.seattle.gov/portal/customize...        NaN
# 32282  https://cosaccela.seattle.gov/portal/customize...        NaN
#
#         Longitude                          Location1
# 23            NaN                                NaN
# 445   -122.343382  POINT (-122.34338244 47.61672999)
# 627           NaN                                NaN
# 795           NaN                                NaN
# 840   -122.355979  POINT (-122.35597876 47.62563431)
# 954   -122.384583  POINT (-122.38458282 47.68229568)
# 1121  -122.307583  POINT (-122.30758286 47.72143076)
# 1235  -122.337212  POINT (-122.33721191 47.65034085)
# 1242          NaN                                NaN
# 1580  -122.313474  POINT (-122.31347424 47.62284107)
# 1632  -122.296990  POINT (-122.29699033 47.71220776)
# 2000  -122.419631  POINT (-122.41963127 47.57632044)
# 2068  -122.342036  POINT (-122.34203576 47.69349229)
# 2390  -122.336852   POINT (-122.3368517 47.65036287)
# 2500  -122.409754  POINT (-122.40975361 47.67624488)
# 3279  -122.264392    POINT (-122.264392 47.50116165)
# 5493  -122.393516  POINT (-122.39351599 47.67610779)
# 5967  -122.309618  POINT (-122.30961772 47.57857461)
# 6133  -122.387022  POINT (-122.38702249 47.56966412)
# 6597  -122.308706  POINT (-122.30870569 47.58871453)
# 7067  -122.384254    POINT (-122.38425412 47.674737)
# 8052  -122.326274  POINT (-122.32627428 47.61943673)
# 8098  -122.323951  POINT (-122.32395073 47.63923243)
# 8140  -122.361017   POINT (-122.3610172 47.69405634)
# 8373  -122.369061  POINT (-122.36906096 47.70614294)
# 8458  -122.345130  POINT (-122.34513023 47.61227955)
# 8659  -122.298761  POINT (-122.29876078 47.59614551)
# 10204 -122.289813  POINT (-122.28981317 47.68146875)
# 10717 -122.303623  POINT (-122.30362333 47.57817548)
# 11500 -122.386768  POINT (-122.38676769 47.56973594)
# ...           ...                                ...
# 31960         NaN                                NaN
# 31969         NaN                                NaN
# 31972         NaN                                NaN
# 31974         NaN                                NaN
# 31975         NaN                                NaN
# 31987         NaN                                NaN
# 31991         NaN                                NaN
# 32015         NaN                                NaN
# 32027         NaN                                NaN
# 32044         NaN                                NaN
# 32046         NaN                                NaN
# 32059         NaN                                NaN
# 32060         NaN                                NaN
# 32078         NaN                                NaN
# 32081         NaN                                NaN
# 32094         NaN                                NaN
# 32106         NaN                                NaN
# 32118         NaN                                NaN
# 32121         NaN                                NaN
# 32140         NaN                                NaN
# 32183         NaN                                NaN
# 32187         NaN                                NaN
# 32193         NaN                                NaN
# 32209         NaN                                NaN
# 32229         NaN                                NaN
# 32234         NaN                                NaN
# 32256         NaN                                NaN
# 32266         NaN                                NaN
# 32279         NaN                                NaN
# 32282         NaN                                NaN
#
# [150 rows x 17 columns]

# %%
#there are 150 rows that have a missing zip code but have values for city and state
len(missingzip_notcs)
# Out:
# 150

# %%
#the other missing values under missingzip_notcs
missingzip_notcs.isnull().sum()
# Out:
# RegistrationNum           0
# RegisteredTypeMapped      0
# RegisteredTypeDesc        0
# RentalHousingUnits        0
# PropertyName            143
# RegisteredDate            0
# ExpiresDate               0
# StatusCurrent             0
# OriginalAddress1          0
# OriginalCity              0
# OriginalState             0
# OriginalZip             150
# PropertyContactName       0
# Link                      0
# Latitude                 55
# Longitude                55
# Location1                55
# dtype: int64

# %%
#all rows with missing values in the dataframe
srentprops_df.isnull().sum()
# Out:
# RegistrationNum             0
# RegisteredTypeMapped        0
# RegisteredTypeDesc          0
# RentalHousingUnits          0
# PropertyName            24002
# RegisteredDate              0
# ExpiresDate                 0
# StatusCurrent               0
# OriginalAddress1            0
# OriginalCity              532
# OriginalState             532
# OriginalZip               682
# PropertyContactName      3943
# Link                        0
# Latitude                  350
# Longitude                 350
# Location1                 350
# dtype: int64

# %% [markdown]
# Missing Data Recap:
# - There are 682 rows where zip code is missing
# - Of those 682 rows, 532 of them also have missing city and state values (missing_csz)
# - Of these 532, 284 rows have longitude and latitude values (missing_csz_ll)
# - Of those 682 rows, 150 of them of them have values for city and state columns (missingzip_notcs)

# %% [markdown]
# Above, we see that there are no missing values for original address. Could we use this to find the missing values for city, zip code, and latitude/longitude?

# %% [markdown]
# ### Data Cleaning

# %%
#Because there is one address in "Mill Creek" (a suburb outside Seattle), we cannot assume all locations are in Seattle proper
srentprops_df.OriginalCity.unique()
# Out:
# array(['SEATTLE', nan, 'Seattle', 'seattle', 'mill creek'], dtype=object)

# %%
#value counts per unique value
srentprops_df.OriginalCity.value_counts()
# Out:
# SEATTLE       32030
# Seattle          69
# seattle          10
# mill creek        1
# Name: OriginalCity, dtype: int64

# %%
#Changing format of "mill creek"
srentprops_df['OriginalCity'].replace('mill creek', 'Mill Creek', inplace=True)

# %%
#We will assume properties are in Washington State
srentprops_df.OriginalState.unique()
# Out:
# array(['WA', nan], dtype=object)

# %%
#replace missing original state values with "WA"
srentprops_df['OriginalState'].fillna('WA', inplace=True)

# %%
#checking if all original state missing values were filled
srentprops_df.isnull().sum()
# Out:
# RegistrationNum             0
# RegisteredTypeMapped        0
# RegisteredTypeDesc          0
# RentalHousingUnits          0
# PropertyName            24002
# RegisteredDate              0
# ExpiresDate                 0
# StatusCurrent               0
# OriginalAddress1            0
# OriginalCity              532
# OriginalState               0
# OriginalZip               682
# PropertyContactName      3943
# Link                        0
# Latitude                  350
# Longitude                 350
# Location1                 350
# dtype: int64

# %%
#keeping "Seattle" consistent
srentprops_df['OriginalCity'].replace('SEATTLE', 'Seattle', inplace=True)

# %%
#keeping "Seattle" consistent
srentprops_df['OriginalCity'].replace('seattle', 'Seattle', inplace=True)

# %%
#checking unique city values
srentprops_df.OriginalCity.unique()
# Out:
# array(['Seattle', nan, 'Mill Creek'], dtype=object)

# %%
#change "location1" header name to be more descriptive
srentprops_df.rename(columns={"Location1": "Cooridinates"}, inplace=True)

# %%
#Cooridinates already in geocode
type(srentprops_df.Cooridinates)
# Out:
# pandas.core.series.Series

# %%
#####reference geocode module to fix geo dataframe
####how do we want to use machine learning for this data set? 
######KMEANS CLUSTERING OF GEOLCATION DATA

# %% [markdown]
# Finding missing zip code -
# - combine the columns into one string column
# -find the geocode for that column
# - have it find the missing zip codes

# %%
missingzip_notcs_df['FullAddress'] = list(missingzip_notcs_df[['OriginalAddress1', 
                                                   'OriginalCity', 'OriginalState',
                                                   'OriginalZip']].values)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
missingzip_notcs_df =missingzip_notcs

# %%
srentprops_df.columns
# Out:
# Index(['RegistrationNum', 'RegisteredTypeMapped', 'RegisteredTypeDesc',
#        'RentalHousingUnits', 'PropertyName', 'RegisteredDate', 'ExpiresDate',
#        'StatusCurrent', 'OriginalAddress1', 'OriginalCity', 'OriginalState',
#        'OriginalZip', 'PropertyContactName', 'Link', 'Latitude', 'Longitude',
#        'Cooridinates'],
#       dtype='object')

# %%
#make a new column to hold the longitude & latitude as a list
srentprops_df['FullAddress'] = list(srentprops_df[['OriginalAddress1', 
                                                   'OriginalCity', 'OriginalState',
                                                   'OriginalZip']].values)

# %%
srentprops_df.head()
# Out:
#   RegistrationNum RegisteredTypeMapped RegisteredTypeDesc  RentalHousingUnits  \
# 0     001-0130088      Rental Property       Registration                   1
# 1     001-0129613      Rental Property       Registration                   1
# 2     001-0129034      Rental Property       Registration                   1
# 3     001-0122782      Rental Property       Registration                   1
# 4     001-0136116      Rental Property       Registration                   1
#
#   PropertyName RegisteredDate ExpiresDate        StatusCurrent  \
# 0          NaN     2017-01-06  2022-01-06  Active Registration
# 1          NaN     2016-12-29  2021-12-29  Active Registration
# 2          NaN     2016-12-13  2021-12-13  Active Registration
# 3          NaN     2016-06-26  2021-06-26  Active Registration
# 4          NaN     2019-05-08  2021-05-08  Active Registration
#
#   OriginalAddress1 OriginalCity OriginalState  OriginalZip  \
# 0   146 NW 74TH ST      Seattle            WA      98117.0
# 1     2100 3RD AVE      Seattle            WA      98121.0
# 2  5720 37TH AVE S      Seattle            WA      98118.0
# 3    147 N 76TH ST      Seattle            WA      98103.0
# 4  2311 43RD AVE E      Seattle            WA      98112.0
#
#   PropertyContactName                                               Link  \
# 0                 NaN  https://cosaccela.seattle.gov/portal/customize...
# 1                 NaN  https://cosaccela.seattle.gov/portal/customize...
# 2                 NaN  https://cosaccela.seattle.gov/portal/customize...
# 3                 NaN  https://cosaccela.seattle.gov/portal/customize...
# 4           Marc Boyd  https://cosaccela.seattle.gov/portal/customize...
#
#     Latitude   Longitude                       Cooridinates  \
# 0  47.682748 -122.359981  POINT (-122.35998077 47.68274781)
# 1  47.613531 -122.342333   POINT (-122.3423326 47.61353093)
# 2  47.550597 -122.286020  POINT (-122.28602015 47.55059675)
# 3  47.683823 -122.355983   POINT (-122.35598277 47.6838228)
# 4  47.639513 -122.277395  POINT (-122.27739453 47.63951303)
#
#                                FullAddress
# 0   [146 NW 74TH ST, Seattle, WA, 98117.0]
# 1     [2100 3RD AVE, Seattle, WA, 98121.0]
# 2  [5720 37TH AVE S, Seattle, WA, 98118.0]
# 3    [147 N 76TH ST, Seattle, WA, 98103.0]
# 4  [2311 43RD AVE E, Seattle, WA, 98112.0]

# %%
srentprops_df.loc[srentprops_df['FullAddress'],[srentprops_df[(srentprops_df['OriginalCity'].notnull())&(srentprops_df['OriginalState'].notnull())&(srentprops_df['OriginalZip'].isnull())]]]
# Out:
#   File "<ipython-input-51-fb3c4b0fcbe7>", line 1
#     srentprops_df['FullAddress'].loc[[[[srentprops_df[(srentprops_df['OriginalCity'].notnull())&(srentprops_df['OriginalState'].notnull())&(srentprops_df['OriginalZip'].isnull())]]]
#                                                                                                                                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
#row 1 = see row where cooridinates and zip were missing
srentprops_df.loc[srentprops_df['RegistrationNum']== "001-0126582"]
# Out:
#    RegistrationNum RegisteredTypeMapped RegisteredTypeDesc  \
# 23     001-0126582      Rental Property       Registration
#
#     RentalHousingUnits PropertyName RegisteredDate ExpiresDate  \
# 23                   1          NaN     2016-12-08  2021-12-08
#
#           StatusCurrent OriginalAddress1 OriginalCity OriginalState  \
# 23  Active Registration    5102 27th AVE      Seattle            WA
#
#     OriginalZip PropertyContactName  \
# 23          NaN      Kok Lan Cheung
#
#                                                  Link  Latitude  Longitude  \
# 23  https://cosaccela.seattle.gov/portal/customize...       NaN        NaN
#
#    Cooridinates                        FullAddress
# 23          NaN  [5102 27th AVE, Seattle, WA, nan]

# %%
#row 2 = see row where city and zip were missing
srentprops_df.loc[srentprops_df['RegistrationNum']== "001-0135141"]
# Out:
#   RegistrationNum RegisteredTypeMapped RegisteredTypeDesc  RentalHousingUnits  \
# 6     001-0135141      Rental Property       Registration                   1
#
#   PropertyName RegisteredDate ExpiresDate        StatusCurrent  \
# 6          NaN     2019-04-18  2021-04-18  Active Registration
#
#    OriginalAddress1 OriginalCity OriginalState  OriginalZip  \
# 6  1214 E Hamlin ST          NaN            WA          NaN
#
#   PropertyContactName                                               Link  \
# 6       Andrea Jacobi  https://cosaccela.seattle.gov/portal/customize...
#
#     Latitude   Longitude                     Cooridinates  \
# 6  47.645789 -122.315878  POINT (-122.315878 47.64578913)
#
#                         FullAddress
# 6  [1214 E Hamlin ST, nan, WA, nan]

# %%
#link for python mapbox doc
#https://pypi.org/project/mapbox/0.3.1/

# %%
import mapbox

geocoder = mapbox.Geocoder(access_token='pk.eyJ1IjoidHBhc2FnIiwiYSI6ImNqeXRhZGIwMTAyMmkzaG4wZGNuaGZ3NTkifQ.WRpwsiq2m41ZgMJzO4NDvQ')

# %%
#see row1 (cooridinates and zip were missing)
response1 = geocoder.forward('5102 27th AVE, Seattle, WA')

#response.json() returns the geocoding result as GeoJSON.

response1.json()
# Out:
# {'type': 'FeatureCollection',
#  'query': ['5102', '27th', 'ave', 'seattle', 'wa'],
#  'features': [{'id': 'address.8289086174570868',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 0.9333333333333333,
#    'properties': {'accuracy': 'rooftop'},
#    'text': '27th Avenue Northeast',
#    'place_name': '5102 27th Avenue Northeast, Seattle, Washington 98105, United States',
#    'center': [-122.298221, 47.666537],
#    'geometry': {'type': 'Point', 'coordinates': [-122.298221, 47.666537]},
#    'address': '5102',
#    'context': [{'id': 'neighborhood.2106917', 'text': 'Ravenna'},
#     {'id': 'postcode.18348032272132340', 'text': '98105'},
#     {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#     {'id': 'region.14042645959246050',
#      'short_code': 'US-WA',
#      'wikidata': 'Q1223',
#      'text': 'Washington'},
#     {'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'address.7966679321714028',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 0.9333333333333333,
#    'properties': {'accuracy': 'interpolated'},
#    'text': '27th Avenue Northwest',
#    'place_name': '5102 27th Avenue Northwest, Seattle, Washington 98117, United States',
#    'center': [-122.390844, 47.682658],
#    'geometry': {'type': 'Point',
#     'coordinates': [-122.390844, 47.682658],
#     'interpolated': True},
#    'address': '5102',
#    'context': [{'id': 'neighborhood.2106940', 'text': 'Loyal Heights'},
#     {'id': 'postcode.7889574170355520', 'text': '98117'},
#     {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#     {'id': 'region.14042645959246050',
#      'short_code': 'US-WA',
#      'wikidata': 'Q1223',
#      'text': 'Washington'},
#     {'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'place.11115494111229470',
#    'type': 'Feature',
#    'place_type': ['place'],
#    'relevance': 0.6666666666666666,
#    'properties': {'wikidata': 'Q5083'},
#    'text': 'Seattle',
#    'place_name': 'Seattle, Washington, United States',
#    'bbox': [-122.441233019046,
#     47.3403950185547,
#     -122.216605992108,
#     47.7779392908564],
#    'center': [-122.3301, 47.6038],
#    'geometry': {'type': 'Point', 'coordinates': [-122.3301, 47.6038]},
#    'context': [{'id': 'region.14042645959246050',
#      'short_code': 'US-WA',
#      'wikidata': 'Q1223',
#      'text': 'Washington'},
#     {'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'neighborhood.2103358',
#    'type': 'Feature',
#    'place_type': ['neighborhood'],
#    'relevance': 0.6566666666666666,
#    'properties': {},
#    'text': 'Wallingford',
#    'place_name': 'Wallingford, Seattle, Washington 98103, United States',
#    'bbox': [-122.347266, 47.643513, -122.321664, 47.673115],
#    'center': [-122.3343, 47.6595],
#    'geometry': {'type': 'Point', 'coordinates': [-122.3343, 47.6595]},
#    'context': [{'id': 'postcode.12249569432717140', 'text': '98103'},
#     {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#     {'id': 'region.14042645959246050',
#      'short_code': 'US-WA',
#      'wikidata': 'Q1223',
#      'text': 'Washington'},
#     {'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'neighborhood.2105391',
#    'type': 'Feature',
#    'place_type': ['neighborhood'],
#    'relevance': 0.6566666666666666,
#    'properties': {},
#    'text': 'Waterfront',
#    'place_name': 'Waterfront, Seattle, Washington 98121, United States',
#    'bbox': [-122.361352, 47.592424, -122.335391, 47.618591],
#    'center': [-122.35, 47.61],
#    'geometry': {'type': 'Point', 'coordinates': [-122.35, 47.61]},
#    'context': [{'id': 'postcode.10618240502770410', 'text': '98121'},
#     {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#     {'id': 'region.14042645959246050',
#      'short_code': 'US-WA',
#      'wikidata': 'Q1223',
#      'text': 'Washington'},
#     {'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]}],
#  'attribution': 'NOTICE: © 2019 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %%
type(response1.json())
# Out:
# dict

# %%
resp1 =response1.json()

# %%
resp1.keys()
# Out:
# dict_keys(['type', 'query', 'features', 'attribution'])

# %%
resp1['features']
# Out:
# [{'id': 'address.8289086174570868',
#   'type': 'Feature',
#   'place_type': ['address'],
#   'relevance': 0.9333333333333333,
#   'properties': {'accuracy': 'rooftop'},
#   'text': '27th Avenue Northeast',
#   'place_name': '5102 27th Avenue Northeast, Seattle, Washington 98105, United States',
#   'center': [-122.298221, 47.666537],
#   'geometry': {'type': 'Point', 'coordinates': [-122.298221, 47.666537]},
#   'address': '5102',
#   'context': [{'id': 'neighborhood.2106917', 'text': 'Ravenna'},
#    {'id': 'postcode.18348032272132340', 'text': '98105'},
#    {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#    {'id': 'region.14042645959246050',
#     'short_code': 'US-WA',
#     'wikidata': 'Q1223',
#     'text': 'Washington'},
#    {'id': 'country.9053006287256050',
#     'short_code': 'us',
#     'wikidata': 'Q30',
#     'text': 'United States'}]},
#  {'id': 'address.7966679321714028',
#   'type': 'Feature',
#   'place_type': ['address'],
#   'relevance': 0.9333333333333333,
#   'properties': {'accuracy': 'interpolated'},
#   'text': '27th Avenue Northwest',
#   'place_name': '5102 27th Avenue Northwest, Seattle, Washington 98117, United States',
#   'center': [-122.390844, 47.682658],
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.390844, 47.682658],
#    'interpolated': True},
#   'address': '5102',
#   'context': [{'id': 'neighborhood.2106940', 'text': 'Loyal Heights'},
#    {'id': 'postcode.7889574170355520', 'text': '98117'},
#    {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#    {'id': 'region.14042645959246050',
#     'short_code': 'US-WA',
#     'wikidata': 'Q1223',
#     'text': 'Washington'},
#    {'id': 'country.9053006287256050',
#     'short_code': 'us',
#     'wikidata': 'Q30',
#     'text': 'United States'}]},
#  {'id': 'place.11115494111229470',
#   'type': 'Feature',
#   'place_type': ['place'],
#   'relevance': 0.6666666666666666,
#   'properties': {'wikidata': 'Q5083'},
#   'text': 'Seattle',
#   'place_name': 'Seattle, Washington, United States',
#   'bbox': [-122.441233019046,
#    47.3403950185547,
#    -122.216605992108,
#    47.7779392908564],
#   'center': [-122.3301, 47.6038],
#   'geometry': {'type': 'Point', 'coordinates': [-122.3301, 47.6038]},
#   'context': [{'id': 'region.14042645959246050',
#     'short_code': 'US-WA',
#     'wikidata': 'Q1223',
#     'text': 'Washington'},
#    {'id': 'country.9053006287256050',
#     'short_code': 'us',
#     'wikidata': 'Q30',
#     'text': 'United States'}]},
#  {'id': 'neighborhood.2103358',
#   'type': 'Feature',
#   'place_type': ['neighborhood'],
#   'relevance': 0.6566666666666666,
#   'properties': {},
#   'text': 'Wallingford',
#   'place_name': 'Wallingford, Seattle, Washington 98103, United States',
#   'bbox': [-122.347266, 47.643513, -122.321664, 47.673115],
#   'center': [-122.3343, 47.6595],
#   'geometry': {'type': 'Point', 'coordinates': [-122.3343, 47.6595]},
#   'context': [{'id': 'postcode.12249569432717140', 'text': '98103'},
#    {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#    {'id': 'region.14042645959246050',
#     'short_code': 'US-WA',
#     'wikidata': 'Q1223',
#     'text': 'Washington'},
#    {'id': 'country.9053006287256050',
#     'short_code': 'us',
#     'wikidata': 'Q30',
#     'text': 'United States'}]},
#  {'id': 'neighborhood.2105391',
#   'type': 'Feature',
#   'place_type': ['neighborhood'],
#   'relevance': 0.6566666666666666,
#   'properties': {},
#   'text': 'Waterfront',
#   'place_name': 'Waterfront, Seattle, Washington 98121, United States',
#   'bbox': [-122.361352, 47.592424, -122.335391, 47.618591],
#   'center': [-122.35, 47.61],
#   'geometry': {'type': 'Point', 'coordinates': [-122.35, 47.61]},
#   'context': [{'id': 'postcode.10618240502770410', 'text': '98121'},
#    {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#    {'id': 'region.14042645959246050',
#     'short_code': 'US-WA',
#     'wikidata': 'Q1223',
#     'text': 'Washington'},
#    {'id': 'country.9053006287256050',
#     'short_code': 'us',
#     'wikidata': 'Q30',
#     'text': 'United States'}]}]

# %%
type(resp1['features'])
# Out:
# list

# %%
resp1['features'][0]
# Out:
# {'id': 'address.8289086174570868',
#  'type': 'Feature',
#  'place_type': ['address'],
#  'relevance': 0.9333333333333333,
#  'properties': {'accuracy': 'rooftop'},
#  'text': '27th Avenue Northeast',
#  'place_name': '5102 27th Avenue Northeast, Seattle, Washington 98105, United States',
#  'center': [-122.298221, 47.666537],
#  'geometry': {'type': 'Point', 'coordinates': [-122.298221, 47.666537]},
#  'address': '5102',
#  'context': [{'id': 'neighborhood.2106917', 'text': 'Ravenna'},
#   {'id': 'postcode.18348032272132340', 'text': '98105'},
#   {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#   {'id': 'region.14042645959246050',
#    'short_code': 'US-WA',
#    'wikidata': 'Q1223',
#    'text': 'Washington'},
#   {'id': 'country.9053006287256050',
#    'short_code': 'us',
#    'wikidata': 'Q30',
#    'text': 'United States'}]}

# %%
# see row2 (city and zip were missing)
response2 = geocoder.reverse(lon=-122.315878, lat=47.64578913)
response2.json()
# Out:
# {'type': 'FeatureCollection',
#  'query': [-122.31588, 47.64579],
#  'features': [{'id': 'address.6121869522502732',
#    'type': 'Feature',
#    'place_type': ['address'],
#    'relevance': 1,
#    'properties': {'accuracy': 'rooftop'},
#    'text': 'East Hamlin Street',
#    'place_name': '1214 East Hamlin Street, Seattle, Washington 98102, United States',
#    'center': [-122.3158758, 47.6457825],
#    'geometry': {'type': 'Point', 'coordinates': [-122.3158758, 47.6457825]},
#    'address': '1214',
#    'context': [{'id': 'neighborhood.2106228', 'text': 'Portage Bay'},
#     {'id': 'postcode.7411368759978330', 'text': '98102'},
#     {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#     {'id': 'region.14042645959246050',
#      'short_code': 'US-WA',
#      'wikidata': 'Q1223',
#      'text': 'Washington'},
#     {'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'neighborhood.2106228',
#    'type': 'Feature',
#    'place_type': ['neighborhood'],
#    'relevance': 1,
#    'properties': {},
#    'text': 'Portage Bay',
#    'place_name': 'Portage Bay, Seattle, Washington 98102, United States',
#    'bbox': [-122.32277, 47.642329, -122.313437, 47.653128],
#    'center': [-122.3195, 47.6457],
#    'geometry': {'type': 'Point', 'coordinates': [-122.3195, 47.6457]},
#    'context': [{'id': 'postcode.7411368759978330', 'text': '98102'},
#     {'id': 'place.11115494111229470', 'wikidata': 'Q5083', 'text': 'Seattle'},
#     {'id': 'region.14042645959246050',
#      'short_code': 'US-WA',
#      'wikidata': 'Q1223',
#      'text': 'Washington'},
#     {'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'postcode.7411368759978330',
#    'type': 'Feature',
#    'place_type': ['postcode'],
#    'relevance': 1,
#    'properties': {},
#    'text': '98102',
#    'place_name': 'Seattle, Washington 98102, United States',
#    'bbox': [-122.337539862908,
#     47.6184785575414,
#     -122.31043511204,
#     47.6530258093346],
#    'center': [-122.32, 47.62],
#    'geometry': {'type': 'Point', 'coordinates': [-122.32, 47.62]},
#    'context': [{'id': 'place.11115494111229470',
#      'wikidata': 'Q5083',
#      'text': 'Seattle'},
#     {'id': 'region.14042645959246050',
#      'short_code': 'US-WA',
#      'wikidata': 'Q1223',
#      'text': 'Washington'},
#     {'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'place.11115494111229470',
#    'type': 'Feature',
#    'place_type': ['place'],
#    'relevance': 1,
#    'properties': {'wikidata': 'Q5083'},
#    'text': 'Seattle',
#    'place_name': 'Seattle, Washington, United States',
#    'bbox': [-122.441233019046,
#     47.3403950185547,
#     -122.216605992108,
#     47.7779392908564],
#    'center': [-122.3301, 47.6038],
#    'geometry': {'type': 'Point', 'coordinates': [-122.3301, 47.6038]},
#    'context': [{'id': 'region.14042645959246050',
#      'short_code': 'US-WA',
#      'wikidata': 'Q1223',
#      'text': 'Washington'},
#     {'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'region.14042645959246050',
#    'type': 'Feature',
#    'place_type': ['region'],
#    'relevance': 1,
#    'properties': {'short_code': 'US-WA', 'wikidata': 'Q1223'},
#    'text': 'Washington',
#    'place_name': 'Washington, United States',
#    'bbox': [-124.948858, 45.543541, -116.91568, 49.002418],
#    'center': [-120.5, 47.5],
#    'geometry': {'type': 'Point', 'coordinates': [-120.5, 47.5]},
#    'context': [{'id': 'country.9053006287256050',
#      'short_code': 'us',
#      'wikidata': 'Q30',
#      'text': 'United States'}]},
#   {'id': 'country.9053006287256050',
#    'type': 'Feature',
#    'place_type': ['country'],
#    'relevance': 1,
#    'properties': {'short_code': 'us', 'wikidata': 'Q30'},
#    'text': 'United States',
#    'place_name': 'United States',
#    'bbox': [-179.9, 18.765563, -66.885444, 71.540724],
#    'center': [-100, 40],
#    'geometry': {'type': 'Point', 'coordinates': [-100, 40]}}],
#  'attribution': 'NOTICE: © 2019 Mapbox and its suppliers. All rights reserved. Use of this data is subject to the Mapbox Terms of Service (https://www.mapbox.com/about/maps/). This response and the information it contains may not be retained. POI(s) provided by Foursquare.'}

# %%
geo_addr.head()

# %%
#create a geolocation dataframe type using the coordinates column as the geolocation data
geo_srprop = gpd.GeoDataFrame(srentprops_df, geometry='Cooridinates')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-7d9a3cdb66a4> in <module>
#       1 #create a geolocation dataframe type using the coordinates column as the geolocation data
# ----> 2 geo_srprop = gpd.GeoDataFrame(srentprops_df, geometry='Cooridinates')
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in __init__(self, *args, **kwargs)
#      48         self.crs = crs
#      49         if geometry is not None:
# ---> 50             self.set_geometry(geometry, inplace=True)
#      51         self._invalidate_sindex()
#      52
#
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\geodataframe.py in set_geometry(self, col, drop, inplace, crs)
#     147         # Check that we are using a listlike of geometries
#     148         if not all(isinstance(item, BaseGeometry) or pd.isnull(item) for item in level):
# --> 149             raise TypeError("Input geometry column must contain valid geometry objects.")
#     150         frame[geo_column_name] = level
#     151         frame._geometry_column_name = geo_column_name
#
# TypeError: Input geometry column must contain valid geometry objects.

# %%
geo_srprop.head()

# %%
#verify coordinates column is geolocation data type
type(geo_srprop['Cooridinates'])

# %%
srentprops_df.columns

# %%
#convert longitude and latitude into correct data type for analyzing; add new column
micro_geo = geocode("4200 150th Ave NE, Redmond, WA 98052", provider='nominatim')
micro_geo

# %%
amzn_geo = geocode("410 Terry Ave N, Seattle, WA 98109", provider='nominatim')
amzn_geo

# %%
#convert json to a dataframe to do analysis

# %%
#k-means?

# %%
#use api from class to find longitude and latitude of Microsoft and Amazon

# %%
#use Travel Time API to find apartments that are equidistant from the two offices.
